# %% [markdown]
# https://stackabuse.com/python-for-nlp-getting-started-with-the-stanfordcorenlp-library/ <br>
# https://github.com/Lynten/stanford-corenlp

# %%
from stanfordcorenlp import StanfordCoreNLP
import logging
import json
import pandas as pd

# %%
class StanfordNLP:
    def __init__(self, host='http://localhost', port=9000):
        self.nlp = StanfordCoreNLP(host, port=port,
                                   timeout=30000)  # , quiet=False, logging_level=logging.DEBUG)
        self.props = {
            'annotators': 'tokenize,ssplit,pos,lemma,ner,parse,depparse,dcoref,relation',
            'pipelineLanguage': 'en',
            'outputFormat': 'json'
        }

    def word_tokenize(self, sentence):
        return self.nlp.word_tokenize(sentence)

    def pos(self, sentence):
        return self.nlp.pos_tag(sentence)

    def ner(self, sentence):
        return self.nlp.ner(sentence)

    def parse(self, sentence):
        return self.nlp.parse(sentence)

    def dependency_parse(self, sentence):
        return self.nlp.dependency_parse(sentence)

    def annotate(self, sentence):
        return json.loads(self.nlp.annotate(sentence, properties=self.props))

    @staticmethod
    def tokens_to_dict(_tokens):
        tokens = defaultdict(dict)
        for token in _tokens:
            tokens[int(token['index'])] = {
                'word': token['word'],
                'lemma': token['lemma'],
                'pos': token['pos'],
                'ner': token['ner']
            }
        return tokens

# %%
df = pd.read_csv('newsdataset1.csv')
df.event_summary=df.event_summary.astype(str)

# %%
df['event_summary'].str.replace('(','').astype(str)
df['event_summary'].str.replace(')','').astype(str)
df['event_summary'].str.replace('[','').astype(str)
df['event_summary'].str.replace(']','').astype(str)
df['event_summary'].str.replace('"','').astype(str)
# Out:
# 0             The death toll of the suicide bombing in Ibb
# 1        A shooting kills one and injures six people in...
# 2        Lithuania adopts the euro as its official curr...
# 3        U.S. fast-food restaurant chain Chick-fil-A wa...
# 4        The Palestine Authority signs a treaty to join...
# 5               The Eurasian Economic Union between Russia
# 6              Vietnam’s new marriage law goes into effect
# 7                                              Mario Cuomo
# 8        Somali al-Shabaab militants attack an army bas...
# 9                Boko Haram militants attack a bus in Waza
# 10                                        Abu Anas al-Libi
# 11       The MS Norman Atlantic ferry fire death toll r...
# 12       The United States enacts more sanctions on Nor...
# 13       Fleeing villagers from a remote part of the Bo...
# 14       Turkey permits the building of a Syriac church...
# 15       The Singapore-registered cargo ship MV Höegh O...
# 16                                         MS Bulk Jupiter
# 17       The Cypriot-registered cargo ship Cemfjord sin...
# 18                                      A prison in Bruges
# 19                                          _January_2015]
# 20       A U.S. drone strike kills eight Uzbek people c...
# 21                                                     nan
# 22                                          /wiki/Al-Qaeda
# 23       A vehicle carrying United Nations peacekeepers...
# 24       A bombing at a local Houthi movement headquart...
# 25       A suicide car bomber detonates near a military...
# 26                A six-story building collapse in Nairobi
# 27       Pope Francis announces the appointment of 20 n...
# 28                                                In darts
# 29       A Libyan warplane bombs a Greek-operated oil t...
#                                ...
# 12787                                               _2017]
# 12788    California moves its 2020 presidential primary...
# 12789                                             Facebook
# 12790                         The University of Louisville
# 12791    The Islamic State of Iraq and the Levant relea...
# 12792                                   Whole Foods Market
# 12793                               /wiki/Hurricane_Maria]
# 12794                                        More than 134
# 12795                          At least 14 Rohingya people
# 12796                                               _2017]
# 12797                                               _2017]
# 12798    Aquatic species from Japan hitched a ride on d...
# 12799    Al-Shabaab militants attack a military base ou...
# 12800    At least 22 people are killed and over 30 are ...
# 12801    A Mexico City borough president says previous ...
# 12802                                               _2017]
# 12803    The U.S. State Department removes all families...
# 12804                                               _2017]
# 12805    Tom Price resigns as the Secretary of Health a...
# 12806    Sun Zhengcai is expelled from the Communist Pa...
# 12807    /wiki/Central_Commission_for_Discipline_Inspec...
# 12808    The journal Protein & Cell publishes Sun Yat-s...
# 12809                                          In Edmonton
# 12810             A fire at a retirement home in Bucharest
# 12811    A military transport plane crashes after take-...
# 12812    A crowd surge collapses a barrier during a soc...
# 12813    /wiki/Rohingya_persecution_in_Myanmar_(2016%E2...
# 12814    Tens of thousands of protesters march through ...
# 12815    About 600 members of the Swedish neo-Nazi grou...
# 12816    The Australian rules football club Richmond Fo...
# Name: event_summary, Length: 12817, dtype: object

# %%
df['event_summary'][1]
# Out:
# 'A shooting kills one and injures six people in Killarney'

# %%
from nltk.parse.corenlp import CoreNLPParser

# %%
if __name__ == '__main__':
    sNLP = StanfordNLP()
    for i in range(0, 50):
        text = df['event_summary'][i]
#         print ("Annotate:", sNLP.annotate(text))
        print('\n\n')
        print ("POS:", sNLP.pos(text))
        print('\n\n')
        print ("Tokens:", sNLP.word_tokenize(text))
        print('\n\n')
        print ("NER:", sNLP.ner(text))
        print('\n\n')
        print ("Parse:", sNLP.parse(text))
        sentence=sNLP.parse(text)
        parser = CoreNLPParser()
        next(parser.raw_parse(text)).pretty_print()
        print('\n\n .......................................................................... \n\n')
#         print ("Dep Parse:", sNLP.dependency_parse(text))
# Out:
# POS: [('The', 'DT'), ('death', 'NN'), ('toll', 'NN'), ('of', 'IN'), ('the', 'DT'), ('suicide', 'NN'), ('bombing', 'NN'), ('in', 'IN'), ('Ibb', 'NNP')]
#
#
#
# Tokens: ['The', 'death', 'toll', 'of', 'the', 'suicide', 'bombing', 'in', 'Ibb']
#
#
#
# NER: [('The', 'O'), ('death', 'O'), ('toll', 'O'), ('of', 'O'), ('the', 'O'), ('suicide', 'CRIMINAL_CHARGE'), ('bombing', 'CRIMINAL_CHARGE'), ('in', 'O'), ('Ibb', 'O')]
#
#
#
# Parse: (ROOT
#   (NP
#     (NP (DT The) (NN death))
#     (NP
#       (NP (NN toll))
#       (PP (IN of)
#         (NP
#           (NP (DT the) (NN suicide) (NN bombing))
#           (PP (IN in)
#             (NP (NNP Ibb))))))))
#          ROOT
#           |
#           NP
#       ____|_________
#      |              NP
#      |          ____|_________
#      |         |              PP
#      |         |     _________|_______
#      |         |    |                 NP
#      |         |    |          _______|_________
#      |         |    |         |                 PP
#      |         |    |         |              ___|___
#      NP        NP   |         NP            |       NP
#   ___|____     |    |    _____|_______      |       |
#  DT       NN   NN   IN  DT    NN      NN    IN     NNP
#  |        |    |    |   |     |       |     |       |
# The     death toll  of the suicide bombing  in     Ibb
#
#
#
#  ..........................................................................
#
#
#
#
#
# POS: [('A', 'DT'), ('shooting', 'NN'), ('kills', 'VBZ'), ('one', 'CD'), ('and', 'CC'), ('injures', 'VBZ'), ('six', 'CD'), ('people', 'NNS'), ('in', 'IN'), ('Killarney', 'NNP')]
#
#
#
# Tokens: ['A', 'shooting', 'kills', 'one', 'and', 'injures', 'six', 'people', 'in', 'Killarney']
#
#
#
# NER: [('A', 'O'), ('shooting', 'CAUSE_OF_DEATH'), ('kills', 'O'), ('one', 'NUMBER'), ('and', 'O'), ('injures', 'O'), ('six', 'NUMBER'), ('people', 'O'), ('in', 'O'), ('Killarney', 'CITY')]
#
#
#
# Parse: (ROOT
#   (S
#     (NP (DT A) (NN shooting))
#     (VP
#       (VP (VBZ kills)
#         (NP (CD one)))
#       (CC and)
#       (VP (VBZ injures)
#         (NP
#           (NP (CD six) (NNS people))
#           (PP (IN in)
#             (NP (NNP Killarney))))))))
#                                ROOT
#                                 |
#                                 S
#       __________________________|______
#      |                                 VP
#      |                   ______________|______________
#      |                  |       |                     VP
#      |                  |       |       ______________|_____
#      |                  |       |      |                    NP
#      |                  |       |      |          __________|_______
#      |                  VP      |      |         |                  PP
#      |              ____|___    |      |         |               ___|______
#      NP            |        NP  |      |         NP             |          NP
#   ___|_____        |        |   |      |      ___|____          |          |
#  DT        NN     VBZ       CD  CC    VBZ    CD      NNS        IN        NNP
#  |         |       |        |   |      |     |        |         |          |
#  A      shooting kills     one and  injures six     people      in     Killarney
#
#
#
#  ..........................................................................
#
#
#
#
#
# POS: [('Lithuania', 'NNP'), ('adopts', 'VBZ'), ('the', 'DT'), ('euro', 'NN'), ('as', 'IN'), ('its', 'PRP$'), ('official', 'JJ'), ('currency', 'NN')]
#
#
#
# Tokens: ['Lithuania', 'adopts', 'the', 'euro', 'as', 'its', 'official', 'currency']
#
#
#
# NER: [('Lithuania', 'COUNTRY'), ('adopts', 'O'), ('the', 'O'), ('euro', 'O'), ('as', 'O'), ('its', 'O'), ('official', 'O'), ('currency', 'O')]
#
#
#
# Parse: (ROOT
#   (S
#     (NP (NNP Lithuania))
#     (VP (VBZ adopts)
#       (NP
#         (NP (DT the) (NN euro))
#         (PP (IN as)
#           (NP (PRP$ its) (JJ official) (NN currency)))))))
#            ROOT
#             |
#             S
#      _______|_____
#     |             VP
#     |        _____|____________
#     |       |                  NP
#     |       |          ________|________
#     |       |         |                 PP
#     |       |         |         ________|_____
#     NP      |         NP       |              NP
#     |       |      ___|___     |    __________|________
#    NNP     VBZ    DT      NN   IN PRP$        JJ       NN
#     |       |     |       |    |   |          |        |
# Lithuania adopts the     euro  as its      official currency
#
#
#
#  ..........................................................................
#
#
#
#
#
# POS: [('U.S.', 'NNP'), ('fast-food', 'NN'), ('restaurant', 'NN'), ('chain', 'NN'), ('Chick-fil-A', 'NN'), ('warns', 'VBZ'), ('that', 'IN'), ('a', 'DT'), ('security', 'NN'), ('breach', 'NN'), ('may', 'MD'), ('have', 'VB'), ('leaked', 'VBN'), ('credit', 'NN'), ('card', 'NN'), ('details', 'NNS'), ('of', 'IN'), ('9', 'CD')]
#
#
#
# Tokens: ['U.S.', 'fast-food', 'restaurant', 'chain', 'Chick-fil-A', 'warns', 'that', 'a', 'security', 'breach', 'may', 'have', 'leaked', 'credit', 'card', 'details', 'of', '9']
#
#
#
# NER: [('U.S.', 'COUNTRY'), ('fast-food', 'O'), ('restaurant', 'O'), ('chain', 'O'), ('Chick-fil-A', 'ORGANIZATION'), ('warns', 'O'), ('that', 'O'), ('a', 'O'), ('security', 'O'), ('breach', 'O'), ('may', 'O'), ('have', 'O'), ('leaked', 'O'), ('credit', 'O'), ('card', 'O'), ('details', 'O'), ('of', 'O'), ('9', 'NUMBER')]
#
#
#
# Parse: (ROOT
#   (S
#     (NP
#       (NP (NNP U.S.) (NN fast-food) (NN restaurant) (NN chain))
#       (NP (NN Chick-fil-A)))
#     (VP (VBZ warns)
#       (SBAR (IN that)
#         (S
#           (NP (DT a) (NN security) (NN breach))
#           (VP (MD may)
#             (VP (VB have)
#               (VP (VBN leaked)
#                 (NP
#                   (NP (NN credit) (NN card) (NNS details))
#                   (PP (IN of)
#                     (NP (CD 9))))))))))))
#                                     ROOT
#                                      |
#                                      S
#                     _________________|_____________
#                    |                               VP
#                    |                           ____|____
#                    |                          |        SBAR
#                    |                          |     ____|______________
#                    |                          |    |                   S
#                    |                          |    |            _______|_________
#                    |                          |    |           |                 VP
#                    |                          |    |           |              ___|_____
#                    |                          |    |           |             |         VP
#                    |                          |    |           |             |    _____|____________
#                    |                          |    |           |             |   |                  VP
#                    |                          |    |           |             |   |      ____________|______
#                    |                          |    |           |             |   |     |                   NP
#                    |                          |    |           |             |   |     |             ______|_________
#                    NP                         |    |           |             |   |     |            |                PP
#           _________|_________________         |    |           |             |   |     |            |             ___|___
#          NP                          NP       |    |           NP            |   |     |            NP           |       NP
#   _______|__________________         |        |    |     ______|_______      |   |     |       _____|______      |       |
# NNP      NN        NN       NN       NN      VBZ   IN   DT     NN      NN    MD  VB   VBN     NN    NN    NNS    IN      CD
#  |       |         |        |        |        |    |    |      |       |     |   |     |      |     |      |     |       |
# U.S. fast-food restaurant chain Chick-fil-A warns that  a   security breach may have leaked credit card details  of      9
#
#
#
#  ..........................................................................
# POS: [('The', 'DT'), ('Palestine', 'NNP'), ('Authority', 'NNP'), ('signs', 'NNS'), ('a', 'DT'), ('treaty', 'NN'), ('to', 'TO'), ('join', 'VB'), ('and', 'CC'), ('participate', 'VB'), ('in', 'IN'), ('the', 'DT'), ('International', 'NNP'), ('Criminal', 'NNP'), ('Court', 'NNP'), ('.', '.'), ('(', '-LRB-'), ('Wall', 'NNP'), ('Street', 'NNP'), ('Journal', 'NNP'), (')', '-RRB-')]
#
#
#
# Tokens: ['The', 'Palestine', 'Authority', 'signs', 'a', 'treaty', 'to', 'join', 'and', 'participate', 'in', 'the', 'International', 'Criminal', 'Court', '.', '(', 'Wall', 'Street', 'Journal', ')']
#
#
#
# NER: [('The', 'O'), ('Palestine', 'ORGANIZATION'), ('Authority', 'ORGANIZATION'), ('signs', 'O'), ('a', 'O'), ('treaty', 'O'), ('to', 'O'), ('join', 'O'), ('and', 'O'), ('participate', 'O'), ('in', 'O'), ('the', 'O'), ('International', 'ORGANIZATION'), ('Criminal', 'ORGANIZATION'), ('Court', 'ORGANIZATION'), ('.', 'O'), ('(', 'O'), ('Wall', 'ORGANIZATION'), ('Street', 'ORGANIZATION'), ('Journal', 'ORGANIZATION'), (')', 'O')]
#
#
#
# Parse: (ROOT
#   (NP
#     (NP
#       (NP (DT The) (NNP Palestine) (NNP Authority) (NNS signs))
#       (NP (DT a) (NN treaty)))
#     (SBAR
#       (S
#         (VP (TO to)
#           (VP (VB join)
#             (CC and)
#             (VB participate)
#             (PP (IN in)
#               (NP (DT the) (NNP International) (NNP Criminal) (NNP Court)))))))
#     (. .)))
#                                                                   ROOT
#                                                                    |
#                                                                    S
#          __________________________________________________________|_____________
#         |                                                                        VP
#         |                                                   _____________________|_______________________________________
#         |                                                  NP                                                            |
#         |                       ___________________________|_______                                                      |
#         |                      |    |                              S                                                     |
#         |                      |    |                              |                                                     |
#         |                      |    |                              VP                                                    |
#         |                      |    |      ________________________|____                                                 |
#         |                      |    |     |                             VP                                               |
#         |                      |    |     |    _________________________|________                                        |
#         |                      |    |     |   |    |       |                     PP                                     PRN
#         |                      |    |     |   |    |       |        _____________|__________                   __________|______________
#         NP                     |    |     |   |    |       |       |                        NP                |          NP             |
#   ______|_________________     |    |     |   |    |       |       |     ___________________|____________     |     _____|_______       |
#  DT    NNP       NNP     NNS   DT   NN    TO  VB   CC      VB      IN   DT      NNP        NNP     NNP   .  -LRB- NNP   NNP     NNP   -RRB-
#  |      |         |       |    |    |     |   |    |       |       |    |        |          |       |    |    |    |     |       |      |
# The Palestine Authority signs  a  treaty  to join and participate  in  the International Criminal Court  .  -LRB- Wall Street Journal -RRB-
#
#
#
#  ..........................................................................
#
#
#
#
#
# POS: [('The', 'DT'), ('Eurasian', 'JJ'), ('Economic', 'NNP'), ('Union', 'NNP'), ('between', 'IN'), ('Russia', 'NNP')]
#
#
#
# Tokens: ['The', 'Eurasian', 'Economic', 'Union', 'between', 'Russia']
#
#
#
# NER: [('The', 'O'), ('Eurasian', 'O'), ('Economic', 'O'), ('Union', 'O'), ('between', 'O'), ('Russia', 'COUNTRY')]
#
#
#
# Parse: (ROOT
#   (FRAG
#     (NP (DT The) (JJ Eurasian) (NNP Economic) (NNP Union))
#     (PP (IN between)
#       (NP (NNP Russia)))))
#                ROOT
#                 |
#                FRAG
#         ________|____________________
#        |                             PP
#        |                        _____|____
#        NP                      |          NP
#   _____|________________       |          |
#  DT    JJ      NNP     NNP     IN        NNP
#  |     |        |       |      |          |
# The Eurasian Economic Union between     Russia
#
#
#
#  ..........................................................................
#
#
#
#
#
# POS: [('Vietnam', 'NNP'), ('’s', 'POS'), ('new', 'JJ'), ('marriage', 'NN'), ('law', 'NN'), ('goes', 'VBZ'), ('into', 'IN'), ('effect', 'NN')]
#
#
#
# Tokens: ['Vietnam', '’s', 'new', 'marriage', 'law', 'goes', 'into', 'effect']
#
#
#
# NER: [('Vietnam', 'COUNTRY'), ('’s', 'O'), ('new', 'O'), ('marriage', 'O'), ('law', 'O'), ('goes', 'O'), ('into', 'O'), ('effect', 'O')]
#
#
#
# Parse: (ROOT
#   (S
#     (NP
#       (NP (NNP Vietnam) (POS 's))
#       (JJ new) (NN marriage) (NN law))
#     (VP (VBZ goes)
#       (PP (IN into)
#         (NP (NN effect))))))
#                       ROOT
#                        |
#                        S
#                   _____|_______________
#                  |                     VP
#                  |                 ____|____
#                  NP               |         PP
#           _______|____________    |     ____|____
#          NP      |     |      |   |    |         NP
#     _____|___    |     |      |   |    |         |
#   NNP       POS  JJ    NN     NN VBZ   IN        NN
#    |         |   |     |      |   |    |         |
# Vietnam      's new marriage law goes into     effect
#
#
#
#  ..........................................................................
#
#
#
#
#
# POS: [('Mario', 'NNP'), ('Cuomo', 'NNP')]
#
#
#
# Tokens: ['Mario', 'Cuomo']
#
#
#
# NER: [('Mario', 'PERSON'), ('Cuomo', 'PERSON')]
#
#
#
# Parse: (ROOT
#   (NP (NNP Mario) (NNP Cuomo)))
#       ROOT
#        |
#        NP
#    ____|_____
#  NNP        NNP
#   |          |
# Mario      Cuomo
#
#
#
#  ..........................................................................
#
#
#
#
#
# POS: [('Somali', 'JJ'), ('al-Shabaab', 'JJ'), ('militants', 'NNS'), ('attack', 'VBP'), ('an', 'DT'), ('army', 'NN'), ('base', 'NN'), ('on', 'IN'), ('the', 'DT'), ('outskirts', 'NNS'), ('of', 'IN'), ('Baidoa', 'NNP')]
#
#
#
# Tokens: ['Somali', 'al-Shabaab', 'militants', 'attack', 'an', 'army', 'base', 'on', 'the', 'outskirts', 'of', 'Baidoa']
#
#
#
# NER: [('Somali', 'NATIONALITY'), ('al-Shabaab', 'O'), ('militants', 'O'), ('attack', 'O'), ('an', 'O'), ('army', 'O'), ('base', 'O'), ('on', 'O'), ('the', 'O'), ('outskirts', 'O'), ('of', 'O'), ('Baidoa', 'LOCATION')]
#
#
#
# Parse: (ROOT
#   (S
#     (NP (JJ Somali) (JJ al-Shabaab) (NNS militants))
#     (VP (VBP attack)
#       (NP (DT an) (NN army) (NN base))
#       (PP (IN on)
#         (NP
#           (NP (DT the) (NNS outskirts))
#           (PP (IN of)
#             (NP (NNP Baidoa))))))))
#                                        ROOT
#                                         |
#                                         S
#             ____________________________|_________
#            |                                      VP
#            |                   ___________________|______________
#            |                  |         |                        PP
#            |                  |         |          ______________|______
#            |                  |         |         |                     NP
#            |                  |         |         |        _____________|_______
#            |                  |         |         |       |                     PP
#            |                  |         |         |       |                  ___|____
#            NP                 |         NP        |       NP                |        NP
#    ________|__________        |      ___|____     |    ___|______           |        |
#   JJ       JJ        NNS     VBP    DT  NN   NN   IN  DT        NNS         IN      NNP
#   |        |          |       |     |   |    |    |   |          |          |        |
# Somali al-Shabaab militants attack  an army base  on the     outskirts      of     Baidoa
#
#
#
#  ..........................................................................
#
#
#
#
#
# POS: [('Boko', 'NNP'), ('Haram', 'NNP'), ('militants', 'NNS'), ('attack', 'VBP'), ('a', 'DT'), ('bus', 'NN'), ('in', 'IN'), ('Waza', 'NNP')]
#
#
#
# Tokens: ['Boko', 'Haram', 'militants', 'attack', 'a', 'bus', 'in', 'Waza']
# NER: [('Boko', 'PERSON'), ('Haram', 'PERSON'), ('militants', 'O'), ('attack', 'O'), ('a', 'O'), ('bus', 'O'), ('in', 'O'), ('Waza', 'PERSON')]
#
#
#
# Parse: (ROOT
#   (S
#     (NP (NNP Boko) (NNP Haram) (NNS militants))
#     (VP (VBP attack)
#       (NP
#         (NP (DT a) (NN bus))
#         (PP (IN in)
#           (NP (NNP Waza)))))))
#                       ROOT
#                        |
#                        S
#         _______________|_____________
#        |                             VP
#        |                _____________|___
#        |               |                 NP
#        |               |          _______|_______
#        |               |         |               PP
#        |               |         |            ___|___
#        NP              |         NP          |       NP
#   _____|_______        |      ___|___        |       |
# NNP   NNP     NNS     VBP    DT      NN      IN     NNP
#  |     |       |       |     |       |       |       |
# Boko Haram militants attack  a      bus      in     Waza
#
#
#
#  ..........................................................................
#
#
#
#
#
# POS: [('Abu', 'NNP'), ('Anas', 'NNP'), ('al-Libi', 'NNP')]
#
#
#
# Tokens: ['Abu', 'Anas', 'al-Libi']
#
#
#
# NER: [('Abu', 'PERSON'), ('Anas', 'PERSON'), ('al-Libi', 'PERSON')]
#
#
#
# Parse: (ROOT
#   (NP (NNP Abu) (NNP Anas) (NNP al-Libi)))
#     ROOT
#      |
#      NP
#   ___|______
# NNP NNP    NNP
#  |   |      |
# Abu Anas al-Libi
#
#
#
#  ..........................................................................
#
#
#
#
#
# POS: [('The', 'DT'), ('MS', 'NN'), ('Norman', 'NNP'), ('Atlantic', 'NNP'), ('ferry', 'NN'), ('fire', 'NN'), ('death', 'NN'), ('toll', 'NN'), ('rises', 'VBZ'), ('to', 'TO'), ('at', 'IN'), ('least', 'JJS'), ('eleven', 'NNS'), ('with', 'IN'), ('as', 'RB'), ('many', 'JJ'), ('as', 'IN'), ('19', 'CD'), ('people', 'NNS'), ('still', 'RB'), ('unaccounted', 'JJ'), ('for', 'IN'), ('.', '.'), ('(', '-LRB-'), ('The', 'DT'), ('Independent', 'NNP'), (')', '-RRB-')]
#
#
#
# Tokens: ['The', 'MS', 'Norman', 'Atlantic', 'ferry', 'fire', 'death', 'toll', 'rises', 'to', 'at', 'least', 'eleven', 'with', 'as', 'many', 'as', '19', 'people', 'still', 'unaccounted', 'for', '.', '(', 'The', 'Independent', ')']
#
#
#
# NER: [('The', 'O'), ('MS', 'STATE_OR_PROVINCE'), ('Norman', 'PERSON'), ('Atlantic', 'PERSON'), ('ferry', 'O'), ('fire', 'CAUSE_OF_DEATH'), ('death', 'O'), ('toll', 'O'), ('rises', 'O'), ('to', 'O'), ('at', 'O'), ('least', 'O'), ('eleven', 'NUMBER'), ('with', 'O'), ('as', 'O'), ('many', 'O'), ('as', 'O'), ('19', 'NUMBER'), ('people', 'O'), ('still', 'O'), ('unaccounted', 'O'), ('for', 'O'), ('.', 'O'), ('(', 'O'), ('The', 'O'), ('Independent', 'RELIGION'), (')', 'O')]
#
#
#
# Parse: (ROOT
#   (S
#     (NP
#       (NP (DT The) (NN MS) (NNP Norman) (NNP Atlantic) (NN ferry))
#       (NP (NN fire) (NN death) (NN toll)))
#     (VP (VBZ rises)
#       (PP (TO to)
#         (NP
#           (NP
#             (ADVP (IN at) (JJS least))
#             (NNS eleven))
#           (PP (IN with)
#             (NP
#               (NP
#                 (QP (RB as) (JJ many) (IN as) (CD 19))
#                 (NNS people))
#               (ADJP (RB still) (JJ unaccounted))))))
#       (PP (IN for)))
#     (. .)))
#                                                                                       ROOT
#                                                                                        |
#                                                                                        S
#       _________________________________________________________________________________|____
#      |                                                                                      VP
#      |                                                                            __________|____________________________________________________________
#      |                                                                           NP                                                                      |
#      |               ____________________________________________________________|_____                                                                  |
#      |              |                                                                 SBAR                                                               |
#      |              |                                                                  |                                                                 |
#      |              |                                                                 FRAG                                                               |
#      |              |                   _______________________________________________|_______________________________________________________          |
#      |              |                  |                                                    S                                                  |         |
#      |              |                  |                                                    |                                                  |         |
#      |              |                  |                                                    VP                                                 |         |
#      |              |                  |                 ___________________________________|______________________________________________    |         |
#      |              |                  |                |                                   PP                                             |   |         |
#      |              |                  |                |     ______________________________|___                                           |   |         |
#      |              |                  |                |    |                                  NP                                         |   |         |
#      |              |                  |                |    |              ____________________|____                                      |   |         |
#      |              |                  |                |    |             |                         PP                                    |   |         |
#      |              |                  |                |    |             |            _____________|___                                  |   |         |
#      |              |                  |                |    |             |           |                 NP                                |   |         |
#      |              |                  |                |    |             |           |              ___|________________                 |   |         |
#      |              |                  |                |    |             NP          |             NP                   |                |   |        PRN
#      |              |                  |                |    |        _____|_____      |         ____|________            |                |   |     ____|____________________
#      NP             NP                 NP               |    |      ADVP         |     |        QP            |          ADJP              PP  |    |        NP               |
#   ___|___      _____|_____         ____|__________      |    |    ___|_____      |     |     ___|________     |       ____|________        |   |    |     ___|_______         |
#  DT      NN  NNP         NNP      NN   NN    NN   NN   VBZ   TO  IN       JJS   NNS    IN   RB  JJ   IN  CD  NNS     RB            JJ      IN  .  -LRB-  DT         NNP     -RRB-
#  |       |    |           |       |    |     |    |     |    |   |         |     |     |    |   |    |   |    |      |             |       |   |    |    |           |        |
# The      MS Norman     Atlantic ferry fire death toll rises  to  at      least eleven with  as many  as  19 people still      unaccounted for  .  -LRB- The     Independent -RRB-
#
#
#
#  ..........................................................................
#
#
#
#
#
# POS: [('The', 'DT'), ('United', 'NNP'), ('States', 'NNPS'), ('enacts', 'VBZ'), ('more', 'JJR'), ('sanctions', 'NNS'), ('on', 'IN'), ('North', 'NNP'), ('Korea', 'NNP'), ('in', 'IN'), ('response', 'NN'), ('to', 'TO'), ('their', 'PRP$'), ('alleged', 'JJ'), ('involvement', 'NN'), ('in', 'IN'), ('the', 'DT'), ('hacking', 'NN'), ('attack', 'NN'), ('on', 'IN'), ('Sony', 'NNP'), ('.', '.'), ('The', 'DT'), ('sanctions', 'NNS'), ('target', 'VBP'), ('the', 'DT'), ('North', 'JJ'), ('Korean', 'JJ'), ('Special', 'JJ'), ('Operation', 'NNP'), ('Force', 'NNP'), ('and', 'CC'), ('10', 'CD'), ('government', 'NN'), ('officials', 'NNS'), ('.', '.'), ('(', '-LRB-'), ('Reuters', 'NNP'), (')', '-RRB-')]
#
#
#
# Tokens: ['The', 'United', 'States', 'enacts', 'more', 'sanctions', 'on', 'North', 'Korea', 'in', 'response', 'to', 'their', 'alleged', 'involvement', 'in', 'the', 'hacking', 'attack', 'on', 'Sony', '.', 'The', 'sanctions', 'target', 'the', 'North', 'Korean', 'Special', 'Operation', 'Force', 'and', '10', 'government', 'officials', '.', '(', 'Reuters', ')']
#
#
#
# NER: [('The', 'O'), ('United', 'COUNTRY'), ('States', 'COUNTRY'), ('enacts', 'O'), ('more', 'O'), ('sanctions', 'O'), ('on', 'O'), ('North', 'COUNTRY'), ('Korea', 'COUNTRY'), ('in', 'O'), ('response', 'O'), ('to', 'O'), ('their', 'O'), ('alleged', 'O'), ('involvement', 'O'), ('in', 'O'), ('the', 'O'), ('hacking', 'O'), ('attack', 'CAUSE_OF_DEATH'), ('on', 'O'), ('Sony', 'ORGANIZATION'), ('.', 'O'), ('The', 'O'), ('sanctions', 'O'), ('target', 'O'), ('the', 'O'), ('North', 'NATIONALITY'), ('Korean', 'NATIONALITY'), ('Special', 'O'), ('Operation', 'O'), ('Force', 'O'), ('and', 'O'), ('10', 'NUMBER'), ('government', 'O'), ('officials', 'O'), ('.', 'O'), ('(', 'O'), ('Reuters', 'ORGANIZATION'), (')', 'O')]
# Parse: (ROOT
#   (S
#     (NP (DT The) (NNP United) (NNPS States))
#     (VP (VBZ enacts)
#       (NP
#         (NP (JJR more) (NNS sanctions))
#         (PP (IN on)
#           (NP
#             (NP (NNP North) (NNP Korea))
#             (PP (IN in)
#               (NP (NN response))))))
#       (PP (TO to)
#         (NP
#           (NP (PRP$ their) (JJ alleged) (NN involvement))
#           (PP (IN in)
#             (NP
#               (NP (DT the) (NN hacking) (NN attack))
#               (PP (IN on)
#                 (NP (NNP Sony))))))))
#     (. .)))
#                    ROOT
#                     |
#                     S
#        _____________|________________________
#       |                                      VP
#       |              ________________________|_____________________________________________
#       |             |          |                            |                              PP
#       |             |          |                            |                          ____|________________
#       |             |          |                            |                         |                     NP
#       |             |          |                            |                         |            _________|___________
#       |             |          |                            |                         |           |                     PP
#       |             |          |                            |                         |           |                  ___|____________
#       |             |          |                            |                         |           |                 |                NP
#       |             |          |                            |                         |           |                 |          ______|_________
#       |             |          |                            |                         |           |                 |         |                PP
#       |             |          |                            |                         |           |                 |         |             ___|____________
#       |             |          |                            |                         |           |                 |         |            |                NP
#       |             |          |                            |                         |           |                 |         |            |         _______|__________________
#       |             |          |                            |                         |           |                 |         |            |        |                         SBAR
#       |             |          |                            |                         |           |                 |         |            |        |                          |
#       |             |          |                            |                         |           |                 |         |            |        |                          S
#       |             |          |                            |                         |           |                 |         |            |        |            ______________|________________
#       |             |          |                            PP                        |           |                 |         |            |        |           |                               VP
#       |             |          |              ______________|____                     |           |                 |         |            |        |           |               ________________|_____________________________
#       |             |          |             |                   NP                   |           |                 |         |            |        |           |              |                                              NP
#       |             |          |             |          _________|_______             |           |                 |         |            |        |           |              |                                          ____|________________________________________
#       |             |          |             |         |                 PP           |           |                 |         |            |        |           |              |                                         NP                                           PRN
#       |             |          |             |         |              ___|_____       |           |                 |         |            |        |           |              |                 ________________________|_________________________________      ______|______
#       NP            |          NP            |         NP            |         NP     |           NP                |         NP           |        NP          NP             |                NP                            |          NP                |    |      NP     |
#   ____|______       |      ____|______       |     ____|____         |         |      |     ______|_________        |    _____|______      |    ____|___     ___|______        |      __________|________________________     |    ______|__________       |    |      |      |
#  DT  NNP    NNPS   VBZ   JJR         NNS     IN  NNP       NNP       IN        NN     TO  PRP$    JJ        NN      IN  DT    NN     NN    IN NNP       .   DT        NNS     VBP    DT   JJ    JJ      JJ      NNP     NNP   CC  CD     NN        NNS     .  -LRB-   NNP   -RRB-
#  |    |      |      |     |           |      |    |         |        |         |      |    |      |         |       |   |     |      |     |   |        |   |          |       |     |    |     |       |        |       |    |   |      |          |      |    |      |      |
# The United States enacts more     sanctions  on North     Korea      in     response  to their alleged involvement  in the hacking attack  on Sony      .  The     sanctions target the North Korean Special Operation Force and  10 government officials  .  -LRB- Reuters -RRB-
#
#
#
#  ..........................................................................
#
#
#
#
#
# POS: [('Fleeing', 'VBG'), ('villagers', 'NNS'), ('from', 'IN'), ('a', 'DT'), ('remote', 'JJ'), ('part', 'NN'), ('of', 'IN'), ('the', 'DT'), ('Borno', 'NNP'), ('State', 'NNP'), ('report', 'NN'), ('that', 'IN'), ('Boko', 'NNP'), ('Haram', 'NNP'), ('had', 'VBD'), ('three', 'CD'), ('days', 'NNS'), ('prior', 'RB'), ('kidnapped', 'VBN'), ('around', 'IN'), ('40', 'CD'), ('boys', 'NNS'), ('and', 'CC'), ('young', 'JJ'), ('men', 'NNS'), ('.', '.'), ('(', '-LRB-'), ('BBC', 'NNP'), (')', '-RRB-')]
#
#
#
# Tokens: ['Fleeing', 'villagers', 'from', 'a', 'remote', 'part', 'of', 'the', 'Borno', 'State', 'report', 'that', 'Boko', 'Haram', 'had', 'three', 'days', 'prior', 'kidnapped', 'around', '40', 'boys', 'and', 'young', 'men', '.', '(', 'BBC', ')']
#
#
#
# NER: [('Fleeing', 'O'), ('villagers', 'O'), ('from', 'O'), ('a', 'O'), ('remote', 'O'), ('part', 'O'), ('of', 'O'), ('the', 'O'), ('Borno', 'ORGANIZATION'), ('State', 'ORGANIZATION'), ('report', 'O'), ('that', 'O'), ('Boko', 'PERSON'), ('Haram', 'PERSON'), ('had', 'O'), ('three', 'DURATION'), ('days', 'DURATION'), ('prior', 'O'), ('kidnapped', 'O'), ('around', 'O'), ('40', 'NUMBER'), ('boys', 'O'), ('and', 'O'), ('young', 'O'), ('men', 'O'), ('.', 'O'), ('(', 'O'), ('BBC', 'ORGANIZATION'), (')', 'O')]
# Parse: (ROOT
#   (NP
#     (NP (VBG Fleeing) (NNS villagers))
#     (PP (IN from)
#       (NP (DT a) (JJ remote) (NN part)))
#     (PP (IN of)
#       (NP
#         (NP (DT the) (NNP Borno) (NNP State) (NN report))
#         (SBAR (IN that)
#           (S
#             (NP (NNP Boko) (NNP Haram))
#             (VP (VBD had)
#               (ADVP
#                 (NP (CD three) (NNS days))
#                 (RB prior))
#               (VP (VBN kidnapped)
#                 (PP (IN around)
#                   (NP
#                     (NP (CD 40) (NNS boys))
#                     (CC and)
#                     (NP (JJ young) (NNS men))))))))))
#     (. .)))
#                             ROOT
#                              |
#                              S
#                              |
#                              VP
#     _________________________|__________________________________________
#    |        |                |                                         SBAR
#    |        |                |                                      ____|______________
#    |        |                |                                     |                   S
#    |        |                |                                     |          _________|_____________
#    |        |                |                                     |         |                       VP
#    |        |                |                                     |         |          _____________|___________________________
#    |        |                |                                     |         |         |             |                           VP
#    |        |                |                                     |         |         |             |              _____________|_________________
#    |        |                PP                                    |         |         |             |             |                               PP
#    |        |       _________|__________                           |         |         |             |             |        _______________________|________
#    |        |      |                    NP                         |         |         |             |             |       |                                NP
#    |        |      |          __________|___                       |         |         |             |             |       |                   _____________|_____________
#    |        |      |         |              PP                     |         |         |            ADVP           |       |                  NP                         PRN
#    |        |      |         |           ___|____                  |         |         |          ___|_____        |       |          ________|_________________      ____|____
#    |        NP     |         NP         |        NP                |         NP        |         NP        |       |       |         NP       |         NP      |    |    NP   |
#    |        |      |     ____|_____     |    ____|___________      |     ____|____     |     ____|___      |       |       |      ___|___     |     ____|___    |    |    |    |
#   VBG      NNS     IN   DT   JJ    NN   IN  DT  NNP   NNP    NN    IN  NNP       NNP  VBD   CD      NNS    RB     VBN      IN    CD     NNS   CC   JJ      NNS  .  -LRB- NNP -RRB-
#    |        |      |    |    |     |    |   |    |     |     |     |    |         |    |    |        |     |       |       |     |       |    |    |        |   |    |    |    |
# Fleeing villagers from  a  remote part  of the Borno State report that Boko     Haram had three     days prior kidnapped around  40     boys and young     men  .  -LRB- BBC -RRB-
#
#
#
#  ..........................................................................
#
#
#
#
#
# POS: [('Turkey', 'NNP'), ('permits', 'VBZ'), ('the', 'DT'), ('building', 'NN'), ('of', 'IN'), ('a', 'DT'), ('Syriac', 'JJ'), ('church', 'NN'), ('in', 'IN'), ('Istanbul', 'NNP')]
#
#
#
# Tokens: ['Turkey', 'permits', 'the', 'building', 'of', 'a', 'Syriac', 'church', 'in', 'Istanbul']
#
#
#
# NER: [('Turkey', 'COUNTRY'), ('permits', 'O'), ('the', 'O'), ('building', 'O'), ('of', 'O'), ('a', 'O'), ('Syriac', 'MISC'), ('church', 'O'), ('in', 'O'), ('Istanbul', 'CITY')]
#
#
#
# Parse: (ROOT
#   (S
#     (NP (NNP Turkey))
#     (VP (VBZ permits)
#       (NP
#         (NP (DT the) (NN building))
#         (PP (IN of)
#           (NP
#             (NP (DT a) (JJ Syriac) (NN church))
#             (PP (IN in)
#               (NP (NNP Istanbul)))))))))
#          ROOT
#           |
#           S
#    _______|_______________
#   |                       VP
#   |        _______________|__________
#   |       |                          NP
#   |       |          ________________|____
#   |       |         |                     PP
#   |       |         |             ________|______
# ...
#        |                  |           |               |           |           |       |             |           |     |     |                         VP                               |            PRN
#        |                  |           |               |           |           |       |             |           |     |     |      ___________________|______                          |     ________|___________
#        NP                 |           NP              |           NP          |       |             NP          |     |     |     |     |   |                NP                        |    |        NP          |
#   _____|________          |      _____|________       |      _____|_____      |       |       ______|_______    |     |     |     |     |   |     ___________|___________________      |    |     ___|_____      |
#  DT   NNP      NNP       VBZ    CD    JJ      NNS     IN    JJ          NN    IN     VBG     DT    NNP     NNP  IN   VBG    TO    VB    CC  VB   DT   CD    NNP    NN    NN      NN    .  -LRB- NNP NNP   NNP  -RRB-
#  |     |        |         |     |     |        |      |     |           |     |       |      |      |       |   |     |     |     |     |   |    |    |      |     |     |       |     |    |    |   |     |     |
# The Justice Department charges two American citizens  of Gambian     descent with violating the Neutrality Act  by helping  to finance and lead the  2014 Gambian coup d'état attempt  .  -LRB- New York Times -RRB-
#
#
#
#  ..........................................................................
#
#
#
#
#
# POS: [('In', 'IN'), ('ice', 'NN'), ('hockey', 'NN')]
#
#
#
# Tokens: ['In', 'ice', 'hockey']
#
#
#
# NER: [('In', 'O'), ('ice', 'O'), ('hockey', 'O')]
#
#
#
# Parse: (ROOT
#   (PP (IN In)
#     (NP (NN ice) (NN hockey))))
#     ROOT
#      |
#      PP
#   ___|____
#  |        NP
#  |    ____|____
#  IN  NN        NN
#  |   |         |
#  In ice      hockey
#
#
#
#  ..........................................................................
#
#
#
#
#
# POS: [('Clashes', 'NNS'), ('with', 'IN'), ('ISIL', 'NN'), ('in', 'IN'), ('Anbar', 'NNP'), ('province', 'NN'), ('kill', 'VB'), ('twenty-three', 'CD'), ('Iraqi', 'JJ'), ('Army', 'NNP'), ('soldiers', 'NNS'), ('and', 'CC'), ('allied', 'VBD'), ('Sunni', 'NNP'), ('fighters', 'NNS'), ('.', '.'), ('(', '-LRB-'), ('AP', 'NN'), ('via', 'IN'), ('The', 'DT'), ('Hindu', 'NN'), (')', '-RRB-')]
#
#
#
# Tokens: ['Clashes', 'with', 'ISIL', 'in', 'Anbar', 'province', 'kill', 'twenty-three', 'Iraqi', 'Army', 'soldiers', 'and', 'allied', 'Sunni', 'fighters', '.', '(', 'AP', 'via', 'The', 'Hindu', ')']
#
#
#
# NER: [('Clashes', 'O'), ('with', 'O'), ('ISIL', 'ORGANIZATION'), ('in', 'O'), ('Anbar', 'LOCATION'), ('province', 'O'), ('kill', 'O'), ('twenty-three', 'NUMBER'), ('Iraqi', 'ORGANIZATION'), ('Army', 'ORGANIZATION'), ('soldiers', 'O'), ('and', 'O'), ('allied', 'O'), ('Sunni', 'RELIGION'), ('fighters', 'O'), ('.', 'O'), ('(', 'O'), ('AP', 'ORGANIZATION'), ('via', 'O'), ('The', 'O'), ('Hindu', 'RELIGION'), (')', 'O')]
# Parse: (ROOT
#   (S
#     (NP
#       (NP (NNS Clashes))
#       (PP (IN with)
#         (NP
#           (NP (NN ISIL))
#           (PP (IN in)
#             (NP (NNP Anbar) (NN province))))))
#     (VP
#       (VP (VB kill)
#         (NP (CD twenty-three) (JJ Iraqi) (NNP Army) (NNS soldiers)))
#       (CC and)
#       (VP (VBD allied)
#         (NP (NNP Sunni) (NNS fighters))))
#     (. .)))
#                   ROOT
#                    |
#                    NP
#     _______________|___________________
#    |                                   PP
#    |      _____________________________|_____________________________________
#    |     |                                                                   NP
#    |     |     ______________________________________________________________|___________________________________________
#    |     |    |                        PP                                                                                |
#    |     |    |     ___________________|_______________________                                                          |
#    |     |    |    |                                          FRAG                                                       |
#    |     |    |    |                                           |                                                         |
#    |     |    |    |                                           NP                                                        |
#    |     |    |    |      _____________________________________|___________________________________________              |
#    |     |    |    |     |                                    SBAR                                         |             |
#    |     |    |    |     |                                     |                                           |             |
#    |     |    |    |     |                                     S                                           |            PRN
#    |     |    |    |     |       ______________________________|______                                     |     ________|______________________
#    |     |    |    |     |      |                                     VP                                   |    |            NP                 |
#    |     |    |    |     |      |                _____________________|__________________                  |    |     _______|___               |
#    |     |    |    |     |      |               VP                           |           VP                |    |    |           PP             |
#    |     |    |    |     |      |       ________|_________                   |     ______|____             |    |    |    _______|___           |
#    NP    |    NP   |     NP     NP     |                  NP                 |    |           NP           |    |    NP  |           NP         |
#    |     |    |    |     |      |      |         _________|___________       |    |       ____|_____       |    |    |   |        ___|____      |
#   NNS    IN   NN   IN   NNP     NN     VB       CD        JJ  NNP    NNS     CC  VBD    NNP        NNS     .  -LRB-  NN  IN      DT       NN  -RRB-
#    |     |    |    |     |      |      |        |         |    |      |      |    |      |          |      |    |    |   |       |        |     |
# Clashes with ISIL  in  Anbar province kill twenty-three Iraqi Army soldiers and allied Sunni     fighters  .  -LRB-  AP via     The     Hindu -RRB-
#
#
#
#  ..........................................................................
#
#
#
#
#
# POS: [('/', ':'), ('wiki/Iraqi', 'NNP'), ('_', 'NNP'), ('Army', 'NNP')]
#
#
#
# Tokens: ['/', 'wiki/Iraqi', '_', 'Army']
#
#
#
# NER: [('/', 'O'), ('wiki/Iraqi', 'O'), ('_', 'O'), ('Army', 'O')]
#
#
#
# Parse: (ROOT
#   (PRN (: /)
#     (NP
#       (NP (NNP wiki/Iraqi))
#       (NP (NNP _) (NNP Army)))))
#                ROOT
#                 |
#                PRN
#   ______________|____
#  |                   NP
#  |       ____________|___
#  |      NP               NP
#  |      |             ___|___
#  :     NNP          NNP     NNP
#  |      |            |       |
#  /  wiki/Iraqi       _      Army
#
#
#
#  ..........................................................................
#
#
#
#
#
# POS: [('A', 'DT'), ('suicide', 'NN'), ('bomber', 'NN'), ('kills', 'VBZ'), ('herself', 'PRP'), ('and', 'CC'), ('a', 'DT'), ('policeman', 'NN'), ('in', 'IN'), ('an', 'DT'), ('attack', 'NN'), ('on', 'IN'), ('a', 'DT'), ('police', 'NN'), ('station', 'NN'), ('in', 'IN'), ('a', 'DT'), ('popular', 'JJ'), ('tourist', 'NN'), ('district', 'NN'), ('in', 'IN'), ('the', 'DT'), ('Turkish', 'JJ'), ('city', 'NN'), ('of', 'IN'), ('Istanbul', 'NNP'), ('.', '.'), ('(', '-LRB-'), ('New', 'NNP'), ('York', 'NNP'), ('Times', 'NNP'), (')', '-RRB-')]
#
#
#
# Tokens: ['A', 'suicide', 'bomber', 'kills', 'herself', 'and', 'a', 'policeman', 'in', 'an', 'attack', 'on', 'a', 'police', 'station', 'in', 'a', 'popular', 'tourist', 'district', 'in', 'the', 'Turkish', 'city', 'of', 'Istanbul', '.', '(', 'New', 'York', 'Times', ')']
#
#
#
# NER: [('A', 'O'), ('suicide', 'CAUSE_OF_DEATH'), ('bomber', 'CAUSE_OF_DEATH'), ('kills', 'O'), ('herself', 'O'), ('and', 'O'), ('a', 'O'), ('policeman', 'TITLE'), ('in', 'O'), ('an', 'O'), ('attack', 'CAUSE_OF_DEATH'), ('on', 'O'), ('a', 'O'), ('police', 'O'), ('station', 'O'), ('in', 'O'), ('a', 'O'), ('popular', 'O'), ('tourist', 'O'), ('district', 'O'), ('in', 'O'), ('the', 'O'), ('Turkish', 'NATIONALITY'), ('city', 'O'), ('of', 'O'), ('Istanbul', 'CITY'), ('.', 'O'), ('(', 'O'), ('New', 'ORGANIZATION'), ('York', 'ORGANIZATION'), ('Times', 'ORGANIZATION'), (')', 'O')]
#
#
#
# Parse: (ROOT
#   (S
#     (NP (DT A) (NN suicide) (NN bomber))
#     (VP
#       (VP (VBZ kills)
#         (NP (PRP herself)))
#       (CC and)
#       (VP
#         (NP
#           (NP (DT a) (NN policeman))
#           (PP (IN in)
#             (NP
#               (NP (DT an) (NN attack))
#               (PP (IN on)
#                 (NP (DT a) (NN police) (NN station))))))
#         (PP (IN in)
#           (NP
#             (NP (DT a) (JJ popular) (NN tourist) (NN district))
#             (PP (IN in)
#               (NP
#                 (NP (DT the) (JJ Turkish) (NN city))
#                 (PP (IN of)
#                   (NP (NNP Istanbul)))))))))
#     (. .)))
#                                                                                                          ROOT
#                                                                                                           |
#                                                                                                           S
#         __________________________________________________________________________________________________|__________
#        |                                                                                                             VP
#        |                   __________________________________________________________________________________________|_______
#        |                  |           |                                                                                      VP
#        |                  |           |               _______________________________________________________________________|_______
#        |                  |           |              |                                                                               PP
#        |                  |           |              |                                                     __________________________|______________________
#        |                  |           |              |                                                    |                                                 NP
#        |                  |           |              |                                                    |           ______________________________________|__________
#        |                  |           |              |                                                    |          |                                                 PP
#        |                  |           |              |                                                    |          |                       __________________________|__________
#        |                  |           |              NP                                                   |          |                      |                                     NP
#        |                  |           |        ______|__________                                          |          |                      |          ___________________________|____
#        |                  |           |       |                 PP                                        |          |                      |         |                                PP
#        |                  |           |       |              ___|______________                           |          |                      |         |           _____________________|____
#        |                  |           |       |             |                  NP                         |          |                      |         |          |                          NP
#        |                  |           |       |             |        __________|_______                   |          |                      |         |          |             _____________|___
#        |                  VP          |       |             |       |                  PP                 |          |                      |         |          |            |                PRN
#        |              ____|_____      |       |             |       |           _______|____              |          |                      |         |          |            |         ________|___________
#        NP            |          NP    |       NP            |       NP         |            NP            |          NP                     |         NP         |            NP       |        NP          |
#   _____|______       |          |     |    ___|______       |    ___|____      |    ________|_______      |     _____|_______________       |    _____|_____     |      ______|___     |     ___|_____      |
#  DT    NN     NN    VBZ        PRP    CC  DT         NN     IN  DT       NN    IN  DT       NN      NN    IN   DT    JJ      NN      NN     IN  DT    JJ    NN   IN   NNP         .  -LRB- NNP NNP   NNP  -RRB-
#  |     |      |      |          |     |   |          |      |   |        |     |   |        |       |     |    |     |       |       |      |   |     |     |    |     |          |    |    |   |     |     |
#  A  suicide bomber kills     herself and  a      policeman  in  an     attack  on  a      police station  in   a  popular tourist district  in the Turkish city  of Istanbul      .  -LRB- New York Times -RRB-
#
#
#
#  ..........................................................................

# %%
 text = df['event_summary'][1]

# %%
text
# Out:
# 'A shooting kills one and injures six people in Killarney'

# %%
from nltk.tree import Tree
parsestr=sNLP.parse(text)
parsestr
# Out:
# '(ROOT\r\n  (S\r\n    (NP (DT A) (NN shooting))\r\n    (VP\r\n      (VP (VBZ kills)\r\n        (NP (CD one)))\r\n      (CC and)\r\n      (VP (VBZ injures)\r\n        (NP\r\n          (NP (CD six) (NNS people))\r\n          (PP (IN in)\r\n            (NP (NNP Killarney))))))))'

# %% [markdown]
# # Printing noun phrases

# %%
import math
for i in Tree.fromstring(parsestr).subtrees():
    if i.label() == 'NP':
        print (i)
        
#         ptempty_list.append(i)
#A shooting kills one and injures six people in Killarney'
# Out:
# (NP (DT A) (NN shooting))
# (NP (CD one))
# (NP (NP (CD six) (NNS people)) (PP (IN in) (NP (NNP Killarney))))
# (NP (CD six) (NNS people))
# (NP (NNP Killarney))

# %% [markdown]
# # Printing noun phrases leaves

# %%
for i in Tree.fromstring(parsestr).subtrees():
    if i.label() == 'VP':
        print (i.leaves())
# Out:
# ['kills', 'one', 'and', 'injures', 'six', 'people', 'in', 'Killarney']
# ['kills', 'one']
# ['injures', 'six', 'people', 'in', 'Killarney']

# %% [markdown]
# # Creating a new file to convert tree into string

# %%
#!/usr/bin/python
fo = open('NP', 'w')
for i in Tree.fromstring(parsestr).subtrees():
    if i.label() == 'NP':
#         print (i)
#         print (i.leaves())
        fo.write(str(i )+ ';'+ str(i.leaves())+ ';')
#         fo.write(str(i.leaves())+ ';')
#         fo.write("\n")
                 
#         print ("\n\n\n________________________________________________________________________\n\n\n")
fo.flush()
fo.close()

# %% [markdown]
# # Reading text file and converting it into one string

# %%
with open('NP', 'r') as file:
    data = file.read().replace('\n', '')
# print(data)

# %%
df['event_summary'][1]
# Out:
# 'A shooting kills one and injures six people in Killarney'

# %% [markdown]
# # Full code for all dataset. Extracting all NP, VP, PP for all dataset

# %%
df['event_summary'][1]
parsestr
# Out:
# '(ROOT\r\n  (S\r\n    (NP (DT A) (NN shooting))\r\n    (VP\r\n      (VP (VBZ kills)\r\n        (NP (CD one)))\r\n      (CC and)\r\n      (VP (VBZ injures)\r\n        (NP\r\n          (NP (CD six) (NNS people))\r\n          (PP (IN in)\r\n            (NP (NNP Killarney))))))))'

# %%
df['event_summary'].count()
# Out:
# 12817

# %%
for i in range(0,12817):
    df['Nounphrases'+ str(i)]="NULL VALUE"

# %%
for j in range(0,12817):
    fo = open('verbphrase', 'w', encoding="utf-8")
    text = df['event_summary'][j]
    print(text+"\n")
    parsestr=sNLP.parse(text)
    for i in Tree.fromstring(parsestr).subtrees():
        if i.label() == 'NP':
            fo.write(str(i)+ ';') 
    fo.close()        
    with open('verbphrase', 'r',encoding="utf8") as file:
        data = file.read().replace('\n', '')
#         data = file.read()
        split_data=data.split(';')
        print (split_data[0])
        print(len(split_data))
        
        for k in range(0,len(split_data)):
#             df['Nounphrases'+ str(k) ]="random"
            df['Nounphrases'+ str(k)][j]=split_data[k]
#             print(df['Nounphrases'+ str(k)][j])

#         df['Verb_Phrases'][j]=data
#         print( df['Verb_Phrases'][j])
        file.seek(0)
    fo = open('verbphrase', 'w').close()
#     fo.write("")
# Out:
# The death toll of the suicide bombing in Ibb
#
# (NP  (NP (DT The) (NN death))  (NP    (NP (NN toll))    (PP      (IN of)      (NP        (NP (DT the) (NN suicide) (NN bombing))        (PP (IN in) (NP (NNP Ibb)))))))
# 8
# A shooting kills one and injures six people in Killarney
#
# (NP (DT A) (NN shooting))
# 6
# Lithuania adopts the euro as its official currency
#
# (NP (NNP Lithuania))
# 5
# U.S. fast-food restaurant chain Chick-fil-A warns that a security breach may have leaked credit card details of 9
#
# (NP  (NP (NNP U.S.) (NN fast-food) (NN restaurant) (NN chain))  (NP (NN Chick-fil-A)))
# 8
# The Palestine Authority signs a treaty to join and participate in the International Criminal Court. (Wall Street Journal)
#
# (NP  (NP    (NP (DT The) (NNP Palestine) (NNP Authority) (NNS signs))    (NP (DT a) (NN treaty)))  (SBAR    (S      (VP        (TO to)        (VP          (VB join)          (CC and)          (VB participate)          (PP            (IN in)            (NP              (DT the)              (NNP International)              (NNP Criminal)              (NNP Court)))))))  (. .))
# 6
# The Eurasian Economic Union between Russia
#
# (NP (DT The) (JJ Eurasian) (NNP Economic) (NNP Union))
# 3
# Vietnam’s new marriage law goes into effect
#
# (NP (NP (NNP Vietnam) (POS 's)) (JJ new) (NN marriage) (NN law))
# 4
# Mario Cuomo
#
# (NP (NNP Mario) (NNP Cuomo))
# 2
# Somali al-Shabaab militants attack an army base on the outskirts of Baidoa
#
# (NP (JJ Somali) (JJ al-Shabaab) (NNS militants))
# 6
# Boko Haram militants attack a bus in Waza
#
# (NP (NNP Boko) (NNP Haram) (NNS militants))
# 5
# Abu Anas al-Libi
#
# (NP (NNP Abu) (NNP Anas) (NNP al-Libi))
# 2
# The MS Norman Atlantic ferry fire death toll rises to at least eleven with as many as 19 people still unaccounted for. (The Independent)
#
# (NP  (NP (DT The) (NN MS) (NNP Norman) (NNP Atlantic) (NN ferry))  (NP (NN fire) (NN death) (NN toll)))
# 8
# The United States enacts more sanctions on North Korea in response to their alleged involvement in the hacking attack on Sony. The sanctions target the North Korean Special Operation Force and 10 government officials. (Reuters)
#
# (NP (DT The) (NNP United) (NNPS States))
# 12
# Fleeing villagers from a remote part of the Borno State report that Boko Haram had three days prior kidnapped around 40 boys and young men. (BBC)
#
# (NP  (NP (VBG Fleeing) (NNS villagers))  (PP (IN from) (NP (DT a) (JJ remote) (NN part)))  (PP    (IN of)    (NP      (NP (DT the) (NNP Borno) (NNP State) (NN report))      (SBAR        (IN that)        (S          (NP (NNP Boko) (NNP Haram))          (VP            (VBD had)            (ADVP (NP (CD three) (NNS days)) (RB prior))            (VP              (VBN kidnapped)              (PP                (IN around)                (NP                  (NP (CD 40) (NNS boys))                  (CC and)                  (NP (JJ young) (NNS men))))))))))  (. .))
# 11
# Turkey permits the building of a Syriac church in Istanbul
#
# (NP (NNP Turkey))
# 7
# The Singapore-registered cargo ship MV Höegh Osaka runs aground on Bramble Bank off the coast of the Isle of Wight
#
# (NP  (DT The)  (JJ Singapore-registered)  (NN cargo)  (NN ship)  (NN MV)  (NNP Höegh)  (NNP Osaka))
# 9
# MS Bulk Jupiter
#
# (NP (NP (NN MS)) (NP (NNP Bulk) (NNP Jupiter)))
# 4
# The Cypriot-registered cargo ship Cemfjord sinks off the northern coast of Scotland leaving eight onboard missing. (BBC News)
#
# (NP  (DT The)  (JJ Cypriot-registered)  (NN cargo)  (NN ship)  (NN Cemfjord))
# 8
# A prison in Bruges
#
# (NP (NP (DT A) (NN prison)) (PP (IN in) (NP (NNP Bruges))))
# 4
# _January_2015"]"
#
# (NP (CD 2015))
# 2
# A U.S. drone strike kills eight Uzbek people claimed to be linked with al-Qaeda in Pakistan. (Channel 9 News)
#
# (NP (DT A) (NNP U.S.) (NN drone) (NN strike))
# 5
# nan
#
# (NP (NN nan))
# 2
# /wiki/Al-Qaeda
#
# (NP (: /) (NN wiki/Al-Qaeda))
# 2
# A vehicle carrying United Nations peacekeepers hits a roadside bomb in northern Mali
#
# (NP  (NP (DT A) (NN vehicle))  (VP    (VBG carrying)    (NP (NNP United) (NNPS Nations) (NNS peacekeepers))))
# 7
# A bombing at a local Houthi movement headquarters in Dhamar Governorate
#
# (NP  (NP    (NP (DT A) (NN bombing))    (PP      (IN at)      (NP        (DT a)        (JJ local)        (NNP Houthi)        (NN movement)        (NN headquarters))))  (PP (IN in) (NP (NNP Dhamar) (NNP Governorate))))
# 6
# A suicide car bomber detonates near a military convoy in Mogadishu
#
# (NP (DT A) (NN suicide) (NN car) (NN bomber))
# 5
# A six-story building collapse in Nairobi
#
# (NP  (NP (DT A) (JJ six-story) (NN building))  (NP (NP (NN collapse)) (PP (IN in) (NP (NNP Nairobi)))))
# 6
# Pope Francis announces the appointment of 20 new Cardinals
#
# (NP (NNP Pope) (NNP Francis))
# 5
# In darts
#
# (NP (NN darts))
# 2
# A Libyan warplane bombs a Greek-operated oil tanker anchored offshore the city of Derna
#
# (NP  (NP (DT A) (JJ Libyan) (NN warplane) (NNS bombs))  (NP (DT a) (JJ Greek-operated) (NN oil) (NN tanker)))
# 7
# News emerges that two days prior hundreds of Boko Haram militants had overrun several towns in northeast Nigeria and captured the military base in Baga. (Wall Street Journal)
#
# (NP (NNP News))
# 11
# Two militants
#
# (NP (CD Two) (NNS militants))
# 2
# Bangladeshi police report that two opposition Bangladesh Nationalist Party activists are shot dead in clashes with members of the ruling Awami League in the town of Natore on the first anniversary of disputed general election. (BBC)
#
# (NP (JJ Bangladeshi) (NNS police))
# 18
# A suicide car bomber hits the headquarters of EUPOL Afghanistan in Kabul
#
# (NP (DT A) (NN suicide) (NN car) (NN bomber))
# 7
# A Czech archaeological team discovers the tomb of formerly unknown Ancient Egyptian queen Khentakawess III who lived during the Fifth Dynasty. (CNN)
#
# (NP (DT A) (JJ Czech) (JJ archaeological) (NN team))
# 8
# The site where Jesus may have been tried
#
# (NP (DT The) (NN site))
# 3
# China relaxes controls over the export of rare earth elements after losing a case brought by the United States at the World Trade Organization. (AP)
#
# (NP (NNP China))
# 11
# Ireland becomes the first European nation to be allowed to export beef to the United States since the mad cow disease scare 15 years ago. (AP via Star Tribune)
#
# (NP (NNP Ireland))
# 8
# For the second day in a row a multi-story residential building in Nairobi
#
# (NP  (NP (DT the) (JJ second) (NN day))  (PP (IN in) (NP (DT a) (NN row))))
# 7
# An avalanche near the Rettenbach glacier in the Austrian Alps
#
# (NP  (NP    (NP (DT An) (NN avalanche))    (PP (IN near) (NP (DT the) (NNP Rettenbach) (NN glacier))))  (PP (IN in) (NP (DT the) (JJ Austrian) (NNP Alps))))
# 6
# After being grounded in Abu Dhabi for over 12 hours with all passengers on board
#
# (NP  (NP (NNP Abu) (NNP Dhabi))  (PP (IN for) (NP (IN over) (CD 12) (NNS hours))))
# 7
# South Korea announces that it will repatriate the remains of Chinese Peoples Liberation Army soldiers killed in the Korean War. (Yonhap)
#
# (NP (NNP South) (NNP Korea))
# 9
# Lebanon implements stricter immigration rules on its Syrian border in response to the refugee crisis caused by the Syrian Civil War. (Reuters)
#
# (NP (NNP Lebanon))
# 10
# Taiwan's justice ministry releases former President Chen Shui-bian from jail on a one-month medical parole. (BBC)
#
# (NP (NP (NNP Taiwan) (POS 's)) (NN justice) (NN ministry))
# 7
# The anti-graft body of the Communist Party of China detains Yang Weize
#
# (NP  (NP (DT The) (JJ anti-graft) (NN body))  (PP (IN of) (NP (DT the) (NNP Communist) (NNP Party)))  (PP (IN of) (NP (NNP China))))
# 6
# The Justice Department charges two American citizens of Gambian descent with violating the Neutrality Act by helping to finance and lead the 2014 Gambian coup d'état attempt. (New York Times)
#
# (NP (DT The) (NNP Justice) (NNP Department))
# 7
# In ice hockey
#
# (NP (NN ice) (NN hockey))
# 2
# Clashes with ISIL in Anbar province kill twenty-three Iraqi Army soldiers and allied Sunni fighters. (AP via The Hindu)
#
# (NP  (NP (NNS Clashes))  (PP    (IN with)    (NP (NP (NN ISIL)) (PP (IN in) (NP (NNP Anbar) (NN province))))))
# 8
# /wiki/Iraqi_Army
#
# (NP (NP (NNP wiki/Iraqi)) (NP (NNP _) (NNP Army)))
# 4
# A suicide bomber kills herself and a policeman in an attack on a police station in a popular tourist district in the Turkish city of Istanbul. (New York Times)
#
# (NP (DT A) (NN suicide) (NN bomber))
# 13
# Officials in the American state of Massachusetts open a time capsule left behind by founding fathers Paul Revere and Samuel Adams. (Reuters via Yahoo! News)
#
# (NP  (NP (NNS Officials))  (PP    (IN in)    (NP      (NP (DT the) (JJ American) (NN state))      (PP (IN of) (NP (NNP Massachusetts))))))
# 11
# American luxury fashion company Coach
#
# (NP (JJ American) (NN luxury) (NN fashion) (NN company))
# 2
# The price of crude oil drops to $48 per barrel
#
# (NP (NP (DT The) (NN price)) (PP (IN of) (NP (JJ crude) (NN oil))))
# 7
# A military truck collides with a bus carrying members of the National Guard of Ukraine in Ukraine
#
# (NP (DT A) (JJ military) (NN truck))
# 10
# Two commuter trains collide at Mesquita
#
# (NP (CD Two) (NN commuter) (NNS trains))
# 3
# Scientists at Oxford University begin a new Ebola vaccine trial on 72 healthy volunteers. (BBC)
#
# (NP  (NP (NNS Scientists))  (PP (IN at) (NP (NNP Oxford) (NNP University))))
# 6
# 43 US states report an epidemic of influenza
#
# (NP (CD 43) (NNP US) (NNS states))
# 5
# Cuba starts releasing political prisoners as part of an historic agreement with the United States announced last month. (The Guardian)
#
# (NP (NNP Cuba))
# 8
# Thai police arrest Gurmeet Singh convicted of involvement in a bombing in Chandigarh that killed 18 people in 1996
#
# (NP (NNP Thai) (NN police) (NN arrest) (NNP Gurmeet) (NNP Singh))
# 8
# Various California state district attorneys fine Safeway a total of $10 million for the illegal dumping of electronics and pharmaceuticals into landfills. (KPIX)
#
# (NP  (JJ Various)  (NNP California)  (NN state)  (NN district)  (NNS attorneys))
# 11
# A man claiming to be the Lord's Resistance Army top commander Ugandan Dominic Ongwen turns himself in to United States forces in the Central African Republic. (AP)
#
# (NP  (NP (DT A) (NN man))  (VP    (VBG claiming)    (S      (VP        (TO to)        (VP          (VB be)          (NP            (NP (NP (DT the) (NNP Lord) (POS 's)) (NN Resistance))            (NP              (NNP Army)              (JJ top)              (NN commander)              (NNP Ugandan)              (NNP Dominic)              (NNP Ongwen))))))))
# 10
# A U.S. District Judge sentences former Virginia Governor Bob McDonnell to two years in prison for corruption. (AP via FOX News)
#
# (NP  (NP (DT A) (NNP U.S.) (NNP District) (NNP Judge) (NNS sentences))  (NP    (NP      (JJ former)      (NNP Virginia)      (NNP Governor)      (NNP Bob)      (NNP McDonnell))    (PP      (TO to)      (NP        (NP (CD two) (NNS years))        (PP          (IN in)          (NP (NP (NN prison)) (PP (IN for) (NP (NN corruption))))))))  (. .))
# 10
# A gunman shoots a doctor at the William Beaumont Army Medical Center in El Paso
#
# (NP (DT A) (NN gunman))
# 6
# An improvised device explodes outside of the Colorado Springs chapter of the NAACP with no injuries. (ABC News)
#
# (NP (DT An) (VBN improvised) (NN device))
# 6
# The 114th United States Congress begins. (ABC News)
#
# (NP (DT The) (JJ 114th) (NNP United) (NNPS States) (NNP Congress))
# 2
# The US Congress re-elects John Boehner to his third term as Speaker. (USA Today)
#
# (NP (DT The) (NNP US) (NNP Congress))
# 6
# NASA's Kepler space observatory announces the discovery of three new planets in the Goldilocks zone capable of supporting life. (News Limited)
#
# (NP  (NP (NNP NASA) (POS 's))  (NNP Kepler)  (NN space)  (NN observatory))
# 9
# A proposal to change the demolition of Candlestick Park in San Francisco
#
# (NP  (DT A)  (NN proposal)  (S    (VP      (TO to)      (VP        (VB change)        (NP          (NP (DT the) (NN demolition))          (PP            (IN of)            (NP              (NP (NNP Candlestick) (NNP Park))              (PP (IN in) (NP (NNP San) (NNP Francisco))))))))))
# 7
# /wiki/San_Francisco,_California
#
# (NP  (NP (NNP wiki/San) (NNP _) (NNP Francisco))  (, ,)  (NP (NNP _) (NNP California)))
# 4
# Gunmen attack the Paris office of the French satirical magazine Charlie Hebdo
#
# (NP (NNS Gunmen))
# 5
#  and Hamyd Mourad
#
# (NP (NNP Hamyd) (NNP Mourad))
# 2
# A car bomb explodes outside a police college in the Yemeni capital Sana'a with at least 38 people reported dead and more than 50 wounded. (Reuters)
#
# (NP (DT A) (NN car) (NN bomb))
# 11
# Archaeologists in China uncover 2
#
# (NP (NP (NNS Archaeologists)) (PP (IN in) (NP (NNP China))))
# 5
# An Andhra Pradesh State Road Transport Corporation bus falls into a ravine near the town of Penukonda in the Indian state of Andhra Pradesh killing at least 20 people. (DNA)
#
# (NP  (DT An)  (NNP Andhra)  (NNP Pradesh)  (NNP State)  (NNP Road)  (NNP Transport)  (NNP Corporation)  (NN bus))
# 12
# Nature publishes the findings of Northeastern University scientists that a new class of drug can kill antibiotic-resistant bacteria. (Reuters)
#
# (NP (NNP Nature))
# 9
# The California Department of Public Health investigates at least nine measles cases linked to Disneyland attendance. (The LA Times)
#
# (NP  (NP (DT The) (NNP California) (NNP Department))  (PP (IN of) (NP (NNP Public) (NNP Health))))
# 7
# Philippines President Benigno Aquino III demands an investigation after a drone purportedly belonging to the United States Navy is found in the Philippine province of Quezon
#
# (NP  (NNP Philippines)  (NNP President)  (NNP Benigno)  (NNP Aquino)  (NNP III))
# 9
# The United States denounces a flag-raising ceremony at Taiwan's de facto embassy in Washington DC
#
# (NP (DT The) (NNP United) (NNPS States))
# 7
# One of the suspects in the killings
#
# (NP  (NP (CD One))  (PP    (IN of)    (NP      (NP (DT the) (NNS suspects))      (PP (IN in) (NP (DT the) (NNS killings))))))
# 6
# [https://www.nytimes.com/2015/01/08/world/europe/charlie-hebdo-paris-shooting.html?smid=tw-nytimes&_r=0"
#
# (NP  (-LRB- -LSB-)  (NN    https://www.nytimes.com/2015/01/08/world/europe/charlie-hebdo-paris-shooting.html?smid=tw-nytimes&_r=0"))
# 2
# Boko Haram militants raze the entire town of Baga in north-east Nigeria. Bodies lay strewn on Baga's streets with as many as 2
#
# (NP (NNP Boko) (NNP Haram) (NNS militants))
# 7
# A suicide bomber targets a police checkpoint in the town of Youssifiyah
#
# (NP (DT A) (NN suicide) (NN bomber))
# 6
# Dunkin' Donuts signs a franchise agreement for 1
#
# (NP  (NP (NNP Dunkin') (NNP Donuts) (NNS signs))  (NP    (NP (DT a) (NN franchise) (NN agreement))    (PP (IN for) (NP (CD 1)))))
# 6
# Coca-Cola announces that it plans to cut 1
#
# (NP (NNP Coca-Cola))
# 4
# Subaru recalls 199
#
# (NP (NNP Subaru))
# 3
# Schools in the Midwestern and Northeast United States close for a second successive day due to bitterly cold temperatures. (Reuters via Yahoo! News)
#
# (NP  (NP (NNS Schools))  (PP    (IN in)    (NP      (NP (DT the) (NN Midwestern))      (CC and)      (NP (NNP Northeast) (NNP United) (NNPS States)))))
# 9
# A Princess Tours catamaran
#
# (NP (NP (DT A) (NNP Princess) (NNP Tours)) (NP (NN catamaran)))
# 4
# An unknown gunman shoots dead Nerlita Ledesma
#
# (NP (DT An) (JJ unknown) (NN gunman))
# 3
# The Obama administration fines Honda $70 million for failing to report deaths and injury complaints from 2003 to 2014. (KNTV)
#
# (NP  (NP    (NP (DT The) (NNP Obama) (NN administration) (NNS fines))    (NNP Honda))  (NP    (NP (QP ($ $) (CD 70) (CD million)))    (PP      (IN for)      (S        (VP          (VBG failing)          (S            (VP              (TO to)              (VP                (VB report)                (NP                  (NNS deaths)                  (CC and)                  (NN injury)                  (NNS complaints))                (PP (IN from) (NP (CD 2003) (TO to) (CD 2014))))))))))  (. .))
# 8
# Brunei officially bans all future public celebrations of Christmas
#
# (NP (NNP Brunei))
# 5
# _2015"]"
#
# (NP (CD 2015))
# 2
# The US Olympic Committee chooses the city of Boston as the American bid city to host the 2024 Summer Olympics. (The New York Times)
#
# (NP (DT The) (NNP US) (NNP Olympic) (NNP Committee))
# 8
# /wiki/France
#
# (NP (: /) (NN wiki/France))
# 2
# Refugees flee Nigeria's Borno State following the Boko Haram massacre in the town of Baga. 7
#
# (NP (NNS Refugees))
# 10
# The People's Republic of China plans to soon permit the online sale of prescription drugs. (Reuters)
#
# (NP  (NP (NP (DT The) (NNPS People) (POS 's)) (NN Republic))  (PP (IN of) (NP (NNP China))))
# 8
# A 193-vehicle pileup along a snowy Interstate 94 highway in Kalamazoo County
#
# (NP  (NP (DT A) (JJ 193-vehicle) (NN pileup))  (PP    (IN along)    (NP      (NP (DT a) (JJ snowy) (NNP Interstate) (CD 94) (NN highway))      (PP (IN in) (NP (NNP Kalamazoo) (NNP County))))))
# 6
# Former Prime Minister of Thailand Yingluck Shinawatra appears to face impeachment charges over a failed rice subsidy scheme. (BBC)
#
# (NP  (NP (JJ Former) (NNP Prime) (NNP Minister))  (PP (IN of) (NP (NNP Thailand) (NNP Yingluck) (NNP Shinawatra))))
# 6
# Russia lists transsexual and transgender individuals among those with "personality and behavioural disorders" who will be banned from obtaining driving licenses. (BBC) (The Moscow Times)
#
# (NP (NNP Russia))
# 11
# At a court in New York City
#
# (NP  (NP (DT a) (NN court))  (PP (IN in) (NP (NNP New) (NNP York) (NNP City))))
# 4
# In Jeddah
#
# (NP (NNP Jeddah))
# 2
# A shooting into a car in San Francisco
#
# (NP (DT A) (NN shooting))
# 4
# _2015"]"
# (NP (CD 2015))
# 2
# Barack Obama proposes a new program to waive tuition at community colleges in the United States for the first two years. (The New York Times)
#
# (NP (NNP Barack) (NNP Obama))
# 8
# Stockholm University cuts its ties with the Confucius Institute citing concerns about foreign interference in academic freedom. (South China Morning Post)
#
# (NP (NNP Stockholm) (NNP University))
# 8
# The Lovejoy Comet enters its brightest phase to roughly magnitude 4 or 5. (Sydney Morning Herald)
#
# (NP (DT The) (NNP Lovejoy) (NNP Comet))
# 5
# The AFC Asian Cup holds the opening ceremony
#
# (NP (DT The) (NNP AFC) (NNP Asian) (NNP Cup))
# 3
# A suicide bomb attack on a Shiite mosque in Rawalpindi
#
# (NP  (NP (DT A) (NN suicide))  (NP    (NP (NN bomb) (NN attack))    (PP      (IN on)      (NP        (NP (DT a) (JJ Shiite) (NN mosque))        (PP (IN in) (NP (NNP Rawalpindi)))))))
# 8
# A female suicide bomber
#
# (NP (NP (DT A) (JJ female) (NN suicide)) (NP (NN bomber)))
# 4
# A suicide attack by al-Nusra Front (al-Qaeda's official affiliate in Syria) at a café in Tripoli
#
# (NP  (NP    (NP (DT A) (NN suicide) (NN attack))    (PP (IN by) (NP (NNP al-Nusra))))  (NP    (NP      (NP (NN Front))      (PRN        (-LRB- -LRB-)        (NP          (NP            (NP (NNP al-Qaeda) (POS 's))            (JJ official)            (NN affiliate))          (PP (IN in) (NP (NNP Syria))))        (-RRB- -RRB-)))    (PP      (IN at)      (NP (NP (DT a) (NN café)) (PP (IN in) (NP (NNP Tripoli)))))))
# 15
# A traffic accident between an oil tanker truck and passenger coach en route to Shikarpur from Karachi on the Pakistan National Highway Link Road near Gulshan-e-Hadeed
#
# (NP  (NP (DT A) (NN traffic) (NN accident))  (PP    (IN between)    (NP      (NP        (DT an)        (NN oil)        (NN tanker)        (NN truck)        (CC and)        (NN passenger)        (NN coach))      (PP (IN en) (NP (NN route)))))  (PP (TO to) (NP (NNP Shikarpur))))
# 11
# A bomb threat on Tigerair Flight 539 at Melbourne Airport
#
# (NP  (NP    (NP (DT A) (NN bomb) (NN threat))    (PP (IN on) (NP (NNP Tigerair) (NNP Flight))))  (NP (NP (CD 539)) (PP (IN at) (NP (NNP Melbourne) (NNP Airport)))))
# 8
# A shooting spree in Moscow
#
# (NP  (NP (DT A) (JJ shooting) (NN spree))  (PP (IN in) (NP (NNP Moscow))))
# 4
# A mass poisoning at a funeral in Mozambique involves beer that was deliberately contaminated with crocodile bile leaving at least 56 dead and 146 hospitailized. (FOX8LIVE)
#
# (NP  (NP (DT A) (NN mass) (NN poisoning))  (PP    (IN at)    (NP (NP (DT a) (NN funeral)) (PP (IN in) (NP (NNP Mozambique))))))
# 13
# SpaceX successfully launches a Falcon 9 rocket from Cape Canaveral
#
# (NP (NNP SpaceX))
# 5
# The Golden Gate Bridge Highway and Transportation District temporarily closes the Golden Gate Bridge until Monday to install a $30 million moveable barrier between opposite traffic flows. (SF Gate)
#
# (NP  (DT The)  (NNP Golden)  (NNP Gate)  (NNP Bridge)  (NNP Highway)  (CC and)  (NNP Transportation)  (NNP District))
# 7
# In American football
#
# (NP (JJ American) (NN football))
# 2
# Thousands of police and military personnel prepare to secure a Paris unity rally with up to a million people expected to attend. (Daily Mail)
#
# (NP  (NP (NNS Thousands))  (PP    (IN of)    (NP (NN police) (CC and) (JJ military) (NNS personnel))))
# 8
# FALSE
#
#
# 1
# More female suicide bombers
#
# (NP  (NP (NP (ADJP (RBR More) (JJ female))) (NP (NN suicide)))  (NP (NNS bombers)))
# 6
# Divers retrieve the flight data recorder from the crashed jet. (AP)
#
# (NP (NNS Divers))
# 5
# The death toll from the Karachi traffic accident rises to 62. (Indian Express)
#
# (NP  (NP (DT The) (NN death) (NN toll))  (PP    (IN from)    (NP (DT the) (NNP Karachi) (NN traffic) (NN accident))))
# 5
# _2014%E2%80%9315"]"
#
# (NP (NP (CD 2014)) (: --) (NP (CD 15)) ('' ''))
# 4
# _2015"]"
#
# (NP (CD 2015))
# 2
# Public photographs become available of SpaceX's Falcon 9 rocket after the experimental recovery attempt of the first stage fails and crash-lands on a floating platform in the SpaceX CRS-5 resupply mission. (Space Flight Now)
#
# (NP (JJ Public) (NNS photographs))
# 12
# Apparent ISIL computer hackers attack the feeds for the United States Central Command for Twitter and YouTube. (Reuters)
#
# (NP (JJ Apparent) (NN ISIL) (NN computer) (NNS hackers))
# 6
# Cameroon kills 143 Boko Haram fighters in clashes. (Reuters)
#
# (NP (NNP Cameroon))
# 5
# The eruption of the Hunga Tonga volcano disrupts flights to and from Tonga. (Radio New Zealand)
#
# (NP  (NP (DT The) (NN eruption))  (PP (IN of) (NP (DT the) (NNP Hunga) (NNP Tonga) (NN volcano))))
# 6
# A school bus plunges off of a cliff on the Caribbean island of St. Vincent leaving at least five people dead and two missing. (AP)
#
# (NP (DT A) (NN school) (NN bus))
# 12
# An electrical malfunction causes a fire in the Washington
#
# (NP (DT An) (JJ electrical) (NN malfunction))
# 5
# In Rovinari
#
# (NP (NNP Rovinari))
# 2
# Chinese police kill six attacking militants wearing explosive devices in Xinjiang. (Reuters)
#
# (NP (JJ Chinese) (NN police))
# 6
# A serviceman stationed at the Russian 102nd Military Base
#
# (NP (DT A) (NN serviceman))
# 3
# District Attorney Kari Brandenburg of New Mexico's Second Judicial Circuit federally charges two Albuquerque Police Department officers with murder in the March 16
#
# (NP  (NP (NNP District) (NNP Attorney) (NNP Kari) (NNP Brandenburg))  (PP    (IN of)    (NP      (NP (NNP New) (NNP Mexico) (POS 's))      (JJ Second)      (NNP Judicial)      (NNP Circuit))))
# 9
# The death toll from poisoned beer in the Mozambique rises to at least 69 with 169 in hospital. Further
#
# (NP  (NP (DT The) (NN death) (NN toll))  (PP    (IN from)    (NP      (NP (VBN poisoned) (NN beer))      (PP (IN in) (NP (DT the) (NNP Mozambique))))))
# 10
# The SpaceX CRS-5 supply ship arrives at the ISS with groceries and Christmas gifts. (AP)
#
# (NP (DT The) (NNP SpaceX) (NN CRS-5) (NN supply) (NN ship))
# 7
# In association football
#
# (NP (NN association) (NN football))
# 2
# In American football
#
# (NP (JJ American) (NN football))
# 2
# France announces plans to deploy 10
#
# (NP (NNP France))
# 4
# A passenger bus comes under heavy fire near a check point in eastern Ukraine leading to at least ten civilians killed and many others injured. (ABC News Australia)
#
# (NP (DT A) (NN passenger) (NN bus))
# 12
# Rob Wainwright
#
# (NP (NNP Rob) (NNP Wainwright))
# 2
# Divers recover the cockpit voice recorder from the crashed jet. The Indonesian National Transportation Safety Committee states that by using the now collected recorders a preliminary report on the accident will be produced within a month and a final report after a year. (AFP/Reuters via ABC News Australia)
#
# (NP (NNS Divers))
# 4
# The death toll from contaminated beer in the Mozambique rises to at least 72. (AP via Business Week)
#
# (NP  (NP (DT The) (NN death) (NN toll))  (PP    (IN from)    (NP      (NP (VBN contaminated) (NN beer))      (PP (IN in) (NP (DT the) (NNP Mozambique))))))
# 7
# The World Health Organization monitors an avian flu outbreak in Taiwan
#
# (NP (DT The) (NNP World) (NNP Health) (NNP Organization))
# 5
# China sends an additional 232 People's Liberation Army medical workers to West Africa to combat the outbreak (in addition to the 78 that had previously been stationed). (AP)
#
# (NP (NNP China))
# 10
# Pope Francis arrives in Sri Lanka to begin a six day Asian tour. (BBC)
#
# (NP (NNP Pope) (NNP Francis))
# 5
# Egypt's highest court overturns and initiates a retrial on the only remaining conviction against former President Hosni Mubarak (a May 2014 sentencing of three years in prison for embezzlement). (Reuters)
#
# (NP (NP (NNP Egypt) (POS 's)) (JJS highest) (NN court))
# 15
# The U.S. Supreme Court rules 9–0 in favor of homeowners that the Truth in Lending Act clearly states that a simple notice by the homeowner to the bank within three years seeking to rescind their mortgage suffices over an actual court-filed lawsuit. (Reuters)
#
# (NP  (NP    (NP (DT The) (NNP U.S.) (NNP Supreme) (NNP Court) (NNS rules))    (NP (CD 9)))  (: --)  (NP    (NP (CD 0))    (PP      (IN in)      (NP        (NP (NN favor))        (PP          (IN of)          (NP            (NP (NNS homeowners))            (SBAR              (IN that)              (S                (NP                  (NP (DT the) (NN Truth))                  (PP (IN in) (NP (NNP Lending) (NNP Act))))                (ADVP (RB clearly))                (VP                  (VBZ states)                  (SBAR                    (IN that)                    (S                      (NP                        (NP (DT a) (JJ simple) (NN notice))                        (PP                          (IN by)                          (NP                            (NP (DT the) (NN homeowner))                            (PP                              (TO to)                              (NP                                (NP (DT the) (NN bank))                                (PP                                  (IN within)                                  (NP                                    (NP (CD three) (NNS years))                                    (VP                                      (VBG seeking)                                      (S                                        (VP                                          (TO to)                                          (VP                                            (VB rescind)                                            (NP                                              (PRP$ their)                                              (NN mortgage)))))))))))))                      (VP                        (VBZ suffices)                        (PP                          (IN over)                          (NP                            (DT an)                            (JJ actual)                            (JJ court-filed)                            (NN lawsuit))))))))))))))  (. .))
# 24
# A bomb destroys a transmission tower in Pagalungan leaving much of the Philippine provinces of Maguindanao and North Cotabato without power. (Rappler)
#
# (NP (DT A) (NN bomb))
# 11
# Charlie Hebdo publishes an edition as a counterpoint to the Charlie Hebdo shootings. (BBC)
#
# (NP (NNP Charlie) (NNP Hebdo))
# 6
# Caesars Entertainment Corporation operating unit will file for bankruptcy on Thursday in Chicago. (Reuters)
#
# (NP  (NP (NNP Caesars) (NNP Entertainment) (NNP Corporation))  (VP (VBG operating) (NP (NN unit))))
# 8
# A collision between a train and a prison transport bus near Penwell
#
# (NP  (NP    (NP (DT A) (NN collision))    (PP      (IN between)      (NP (NP (DT a) (NN train)) (CC and) (NP (DT a) (NN prison)))))  (NP (NP (NN transport) (NN bus)) (PP (IN near) (NP (NNP Penwell)))))
# 10
# Floods devastate Mozambique and Malawi
#
# (NP (NNS Floods))
# 3
# The cabinet of Prime Minister of Japan Shinzo Abe approves a record defence budget with a plan to buy surveillance aircraft and Lockheed Martin F-35 Lightning II fighter jets to improve security of uninhabited islands in the East China Sea claimed by both Japan and China. (AP)
#
# (NP  (NP (DT The) (NN cabinet))  (PP    (IN of)    (NP      (NP (NNP Prime) (NNP Minister))      (PP (IN of) (NP (NNP Japan) (NNP Shinzo) (NNP Abe))))))
# 19
# Taiwan protests China’s new air routes near the median line of the Taiwan Strait and vows to step up surveillance of aviation activity. (Bloomberg)(Reuters)
#
# (NP (NNP Taiwan) (NNS protests))
# 10
# On the second day of his papal visit to Sri Lanka
#
# (NP  (NP (DT the) (JJ second) (NN day))  (PP    (IN of)    (NP      (NP (PRP$ his) (JJ papal) (NN visit))      (PP (TO to) (NP (NNP Sri) (NNP Lanka))))))
# 6
# The U.S. state of Georgia executes Vietnam War veteran Andrew Brannan for the 1998 murder of Laurens County sheriff's deputy Kyle Dinkheller. (Huffington Post)
#
# (NP  (NP (DT The) (NNP U.S.) (NN state))  (PP (IN of) (NP (NNP Georgia))))
# 10
# Police charge Indianapolis Colts linebacker Josh McNary with a December 1
#
# (NP (NNS Police))
# 5
# President of Italy Giorgio Napolitano will announce his resignation today. (Bloomberg via Business Week)
#
# (NP  (NP (NNP President))  (PP (IN of) (NP (NNP Italy) (NNP Giorgio) (NNP Napolitano))))
# 5
# The San Francisco Municipal Transportation Agency rules that anti-Muslim advertisements placed on Muni buses must be permitted because of freedom of speech. (KNTV)
#
# (NP  (NP    (DT The)    (NNP San)    (NNP Francisco)    (NNP Municipal)    (NNP Transportation)    (NNP Agency)    (NNS rules))  (SBAR    (WHNP (WDT that))    (S      (NP (JJ anti-Muslim) (NNS advertisements))      (VP (VBN placed) (PP (IN on) (NP (JJ Muni) (NNS buses)))))))
# 8
# The U.S. Secret Service removes four of its highest-ranking leaders while a fifth one retires. The continuing restructuring and fallout stem from a string of public security lapses beginning with the misconduct at the 6th Summit of the Americas. The most recent stage of the restructuring began in October 2014 with the resignation of then-Director Julia Pierson. (The Washington Post via MSN)
#
# (NP (DT The) (NNP U.S.) (NNP Secret) (NNP Service))
# 6
# In rock climbing
#
# (NP (NN rock) (NN climbing))
# 2
# Afghan security officials arrest five men in Kabul in relation to their suspected involvement in the Pakistan school massacre. (ABC News Australia)
#
# (NP (NNP Afghan) (NN security) (NNS officials))
# 10
# Police in eastern Belgium kill two suspected terrorists during an anti-terrorism raid near Verviers. (AP via News24) (CNN) (BBC)
#
# (NP (NP (NNS Police)) (PP (IN in) (NP (JJ eastern) (NNP Belgium))))
# 9
# Pope Francis arrives in Manila and meets Philippines President Benigno Aquino III. (The New York Times)
#
# (NP (NNP Pope) (NNP Francis))
# 4
# The Motion Picture Academy announces the nominees for the 87th Academy Awards best picture at the Samuel Goldwyn Theater in Beverly Hills
#
# (NP (DT The) (NNP Motion) (NNP Picture) (NNP Academy))
# 9
# The World Bank states that the Philippines can end poverty in a single generation. (AP via The Philippine Star)
#
# (NP (DT The) (NNP World) (NNP Bank))
# 5
# The Swiss franc to euro exchange rate jumps by 30% immediately following a Swiss National Bank announcement. The bank will abandon its three-year-old cap on the swiss franc's value against the euro as well as lower the interest rate on sight deposits (instant access accounts) to -0.75% (the negative number meaning that the depositor has to pay the bank 0.75% per year to hold the depositor's money). (BBC) (Bloomberg)
#
# (NP  (NP (DT The) (JJ Swiss) (NN franc))  (PP (TO to) (NP (NN euro) (NN exchange) (NN rate))))
# 7
# Target will close all of its 133 stores in Canada and put Target Canada into bankruptcy. (Reuters)
#
# (NP (NN Target))
# 8
# Electronics retailer RadioShack Corp will file for bankruptcy protection by next month. (Reuters)
#
# (NP (NNP Electronics) (NN retailer) (NNP RadioShack) (NNP Corp))
# 4
# A tour bus overturns and catches fire on the North-South Expressway in the Malaysian town of Tapah leaving at least eight people killed and 21 others injured. (The Straits Times)
#
# (NP (DT A) (NN tour) (NN bus))
# 13
# A newly manufactured tug boat capsizes during a test run in the Yangtze River in east China's Jiangsu Province leaving at least 20 people missing. (Xinhua)
#
# (NP (DT A) (ADJP (RB newly) (VBN manufactured)) (NN tug) (NN boat))
# 10
# The Morbidity and Mortality Weekly Report estimates the effectiveness of the influenza vaccination in 2014–2015 at 23% which is the lowest since 2006. (CDC)
#
# (NP  (NP (DT The) (NN Morbidity))  (CC and)  (NP (NN Mortality) (NNP Weekly) (NNP Report)))
# 15
# Philippine authorities in Manila concentrate street children in cages with some even chained in anticipation of Pope Francis' pastoral visit. (The Daily Mail)
#
# (NP  (NP (JJ Philippine) (NNS authorities))  (PP    (IN in)    (NP (NNP Manila) (NN concentrate) (NN street) (NNS children)))  (PP    (IN in)    (NP      (NP (NNS cages))      (PP (IN with) (NP (DT some) (RB even) (JJ chained)))))  (PP    (IN in)    (NP      (NP (NN anticipation))      (PP        (IN of)        (NP          (NP (NNP Pope) (NNP Francis) (POS '))          (JJ pastoral)          (NN visit)))))  (. .))
# 11
# Clashes in Gyumri
#
# (NP (NP (NNS Clashes)) (PP (IN in) (NP (NNP Gyumri))))
# 4
# The United States Department of Defense announces that it will send 400 troops to train moderate Syrian rebels in the spring of 2015. (AP)
#
# (NP  (NP (DT The) (NNP United) (NNP States) (NNP Department))  (PP (IN of) (NP (NNP Defense))))
# 10
# A hostage crisis at a post office in Colombes
#
# (NP (DT A) (NN hostage) (NN crisis))
# 4
# The Military of Chad enters Cameroon to assist in fighting against Boko Haram insurgents. (Reuters)
#
# (NP (NP (DT The) (NNP Military)) (PP (IN of) (NP (NNP Chad))))
# 6
# U.S. federal magistrate Carl Barbier's ruling caps BP's fine under the Clean Water Act for its 2010 Deepwater Horizon oil spill in the Gulf of Mexico at $13.7 billion. (Reuters)
#
# (NP  (NP (NNP U.S.))  (NP    (NP (JJ federal) (NN magistrate))    (NP      (NP (NNP Carl) (NNP Barbier) (POS 's))      (NN ruling)      (NNS caps)))  (NP    (NP (NP (NNP BP) (POS 's)) (NN fine))    (PP      (IN under)      (NP        (NP (DT the) (JJ Clean) (NN Water) (NN Act))        (PP          (IN for)          (NP            (NP              (PRP$ its)              (CD 2010)              (NNP Deepwater)              (NNP Horizon)              (NN oil)              (NN spill))            (PP              (IN in)              (NP                (NP (DT the) (NNP Gulf))                (PP                  (IN of)                  (NP                    (NP (NNP Mexico))                    (PP                      (IN at)                      (NP (QP ($ $) (CD 13.7) (CD billion)))))))))))))  (. .))
# 19
# The Obama Administration eases trade restrictions with Cuba
#
# (NP (DT The) (NNP Obama) (NNP Administration))
# 4
# An explosion of the Hunga Tonga submerged volcano in the South Pacific Ocean
#
# (NP  (NP (DT An) (NN explosion))  (PP (IN of) (NP (DT the) (NNP Hunga) (NNP Tonga))))
# 6
# Flash flooding continues since January 14 in the African nation of Malawi with at least 176 people killed and 110
#
# (NP (NN Flash) (NN flooding))
# 10
# Chinese officials impose an emergency ban on tourists approaching pandas subsequent to the death of two pandas from a canine distemper virus. (USA Today)
#
# (NP (JJ Chinese) (NNS officials))
# 10
# Polk County
#
# (NP (NNP Polk) (NNP County))
# 2
# Mexican authorities arrest an alleged hitman for the Guerreros Unidos drug cartel
#
# (NP (JJ Mexican) (NNS authorities))
# 6
# The U.S. Supreme Court agrees to consolidate and hear four appellate rulings whether there is a constitutional right to same-sex marriage. It is currently allowed in Washington
#
# (NP (DT The) (NNP U.S.) (NNP Supreme) (NNP Court))
# 7
# Pittsburgh police arrest Ryan Williams for the October 18
#
# (NP  (NP    (NNP Pittsburgh)    (NN police)    (NN arrest)    (NNP Ryan)    (NNP Williams))  (PP (IN for) (NP (DT the) (NNP October) (CD 18))))
# 4
# The Obama Administration imposes restrictions on state and local police's ability to seize personal property under the guidelines of the Equitable Sharing federal program. (Washington Post)
# (NP (DT The) (NNP Obama) (NNP Administration))
# 11
# NASA and National Oceanic and Atmospheric Administration researchers state that 2014 is the hottest year since record keeping began in 1880. (Xinhua)(NASA)(NOAA)(The New York Times)(Russia Today)(The Guardian)(The Wall Street Journal)
#
# (NP  (NNP NASA)  (CC and)  (NNP National)  (NNP Oceanic)  (CC and)  (NNP Atmospheric)  (NNP Administration)  (NNS researchers))
# 8
# NASA's Mars Reconnaissance Orbiter finds the Beagle 2 spacecraft that disappeared in 2003 intact on the surface of Mars. An error had stopped the spacecraft's solar panels from working and communicating back to Earth. (TNN via Times of India)
#
# (NP  (NP (NNP NASA) (POS 's))  (NNP Mars)  (NNP Reconnaissance)  (NNP Orbiter))
# 9
# Public video emerges of the January 10 SpaceX CRS-5 mission Falcon 9 failed landing. (The Telegraph)
#
# (NP (NNP Public) (NN video))
# 6
# St. Louis
#
# (NP (NNP St.) (NNP Louis))
# 2
# Gunmen abduct the chief of staff to Yemen's president in the center of the capital
#
# (NP (NNS Gunmen))
# 11
# Violence surrounding various protests against Charlie Hebdo leaves five protesters dead as well as some churches set ablaze in Niger. (BBC)
#
# (NP  (NP (NN Violence))  (VP    (VBG surrounding)    (NP (JJ various) (NNS protests))    (PP      (IN against)      (NP        (NP          (NP (NNP Charlie) (NNP Hebdo))          (SBAR            (S              (VP                (VBZ leaves)                (ADJP (NP (CD five) (NNS protesters)) (JJ dead))))))        (CONJP (RB as) (RB well) (IN as))        (NP (DT some) (NNS churches))))))
# 11
# Following the January 16 Chad authorities decision to send troops to Nigeria and Cameroon to fight Boko Haram militants
#
# (NP  (DT the)  (NNP January)  (CD 16)  (NNP Chad)  (NNS authorities)  (NN decision))
# 5
# Clashes between the Ukrainian army and pro-Russia rebels over Donetsk International Airport intensifies. (Al Jazeera)
#
# (NP  (NP (NNS Clashes))  (PP    (IN between)    (NP      (NP (DT the) (JJ Ukrainian) (NN army))      (CC and)      (NP        (NP (JJ pro-Russia) (NNS rebels))        (PP          (IN over)          (NP (NNP Donetsk) (NNP International) (NNP Airport)))))))
# 8
# Greek anti-terror police arrest four people in Athens
#
# (NP  (NP (JJ Greek) (JJ anti-terror) (NN police) (NN arrest))  (NP (NP (CD four) (NNS people)) (PP (IN in) (NP (NNP Athens)))))
# 6
# Pope Francis celebrates mass at Typhoon Haiyan (Yolanda)-hit city of Tacloban with an audience of half-a-million people. (BBC)
#
# (NP (NNP Pope) (NNP Francis))
# 11
# /wiki/Tacloban]"
#
# (NP (NP (NN wiki/Tacloban)) (VP (-RRB- -RSB-) ('' '')))
# 3
# The rescue and recovery efforts at the wreckage of the January 15 capsized tugboat on China's Yangtze River near the city of Jingjiang finds that twenty-one people are dead while three are rescued. (Straits Times)
#
# (NP  (NP (DT The) (NN rescue) (CC and) (NN recovery) (NNS efforts))  (PP    (IN at)    (NP      (NP (DT the) (NN wreckage))      (PP        (IN of)        (NP          (NP (DT the) (NNP January) (CD 15))          (VP            (VBN capsized)            (NP              (NP (NN tugboat))              (PP                (IN on)                (NP                  (NP (NNP China) (POS 's))                  (NNP Yangtze)                  (NNP River))))            (PP              (IN near)              (NP                (NP (DT the) (NN city))                (PP (IN of) (NP (NNP Jingjiang)))))))))))
# 16
# An entourage plane accompanying the Pope and carrying government officials experiences high winds and blows off the runway minutes after the pontiff's aircraft takes off safely in the Philippines. (The Independent)
#
# (NP  (NP (DT An) (NN entourage) (NN plane))  (VP    (VP (VBG accompanying) (NP (DT the) (NNP Pope)))    (CC and)    (VP (VBG carrying) (NP (NN government) (NNS officials)))))
# 10
# The Bridger Pipeline Company spills up to 50
#
# (NP (DT The) (NNP Bridger) (NNP Pipeline) (NNP Company))
# 3
# Pemberton Township
#
# (NP (NNP Pemberton) (NNP Township))
# 2
# In football
#
# (NP (NN football))
# 2
# An Israeli helicopter strike near the border with Syria kills two senior IRGC figures and six members of Hezbollah. (Reuters)
#
# (NP  (NP (DT An) (JJ Israeli) (NN helicopter) (NN strike))  (PP    (IN near)    (NP (NP (DT the) (NN border)) (PP (IN with) (NP (NNP Syria))))))
# 11
# Boko Haram militants kidnap 80 people and kill three others from villages in north Cameroon. (Daily Mirror)
#
# (NP (NNP Boko) (NNP Haram) (NNS militants))
# 7
# A clash with Hindu villagers in Sarayian village in India's Bihar state leaves at least three Muslim villagers burned to death. (AP)
#
# (NP  (NP (DT A) (NN clash))  (PP    (IN with)    (NP      (NP (NN Hindu) (NNS villagers))      (PP        (IN in)        (NP          (NP (JJ Sarayian) (NN village))          (PP            (IN in)            (NP (NP (NNP India) (POS 's)) (JJ Bihar) (NN state))))))))
# 12
# State-sponsored army and Islamist-sponsored opposition declare a ceasefire. (AFP via Al-Arabiya)
#
# (NP  (NP (JJ State-sponsored) (NN army))  (CC and)  (NP (JJ Islamist-sponsored) (NN opposition)))
# 5
# Pope Francis celebrates Holy Mass in Manila to a crowd of 6 to 7 million
#
# (NP (NNP Pope) (NNP Francis))
# 8
# [/wiki/Pope_Francis"
#
# (NP (PRN (: /) (NP (NNP wiki/Pope))))
# 4
# Icy roads from a freezing-rain storm cause at least four deaths in the Philadelphia
#
# (NP  (NP    (NP (NN Icy) (NNS roads))    (PP      (IN from)      (NP (DT a) (JJ freezing-rain) (NN storm) (NN cause))))  (NP    (NP (QP (IN at) (JJS least) (CD four)) (NNS deaths))    (PP (IN in) (NP (DT the) (NNP Philadelphia)))))
# 8
# Indonesia executes six people for drug trafficking including foreign citizens from Brazil
#
# (NP (NNP Indonesia))
# 9
# Chinese police shoot dead two ethnic Uighurs in Pingxiang
#
# (NP  (NP    (NP (JJ Chinese) (NN police) (NN shoot))    (ADJP (JJ dead) (NP-TMP (CD two))))  (NP    (NP (JJ ethnic) (NNPS Uighurs))    (PP (IN in) (NP (NNP Pingxiang)))))
# 7
# AB de Villiers made the fastest century in ODI cricket history
#
# (NP (NNP AB) (NNP de) (NNP Villiers))
# 5
# Lennar Urban cancels their demolition plans to implode Candlestick Park due to concerns over public health issues from the concrete dust and pollution. (KTVU)
#
# (NP (NNP Lennar) (NNP Urban))
# 9
# The Seattle Seahawks and New England Patriots win their respective conference championships to advance to the February 1 Super Bowl XLIX. (NFL.com)
#
# (NP  (NP (DT The) (NNP Seattle) (NNPS Seahawks))  (CC and)  (NP (NNP New) (NNP England) (NNPS Patriots)))
# 6
# Kurdish fighters battling Islamic State militants in the town of Kobanî
#
# (NP (JJ Kurdish) (NNS fighters))
# 6
# Clashes in the Yemeni capital Sana'a leave at least nine dead and 67 injured. (AP)
#
# (NP  (NP (NNS Clashes))  (PP (IN in) (NP (DT the) (JJ Yemeni) (NN capital) (NNP Sana'a))))
# 8
# [http://bigstory.ap.org/article/81fe934743c6474b9d2d671ef4ec8cd4/houthis-military-battle-near-yemens-presidential-palace"
#
# (NP  (-LRB- -LSB-)  (NN    http://bigstory.ap.org/article/81fe934743c6474b9d2d671ef4ec8cd4/houthis-military-battle-near-yemens-presidential-palace"))
# 2
# Police in the Democratic Republic of Congo's capital Kinshasa fire on protesters opposing efforts by President Joseph Kabila to delay presidential and parliamentary elections due in 2016 leaving at least four people dead and ten injured. (Al-Jazeera)
#
# (NP  (NP (NNS Police))  (PP    (IN in)    (NP      (NP (DT the) (JJ Democratic) (NN Republic))      (PP (IN of) (NP (NP (NNP Congo) (POS 's)) (NN capital)))      (SBAR        (WHNP          (NP (NNP Kinshasa) (NN fire))          (PP            (IN on)            (S              (NP (NNS protesters))              (VP                (VBG opposing)                (NP (NNS efforts))                (PP                  (IN by)                  (NP (NNP President) (NNP Joseph) (NNP Kabila)))))))        (S          (VP            (TO to)            (VP              (VB delay)              (S                (NP                  (JJ presidential)                  (CC and)                  (JJ parliamentary)                  (NNS elections))                (ADJP (JJ due) (PP (IN in) (NP (CD 2016))))                (S                  (VP                    (VBG leaving)                    (UCP                      (ADJP                        (NP                          (QP (IN at) (JJS least) (CD four))                          (NNS people))                        (JJ dead))                      (CC and)                      (NP (CD ten)))))))))))))
# 15
# The Anne Arundel County
#
# (NP (NP (DT The) (NNP Anne)) (NP (NNP Arundel) (NNP County)))
# 4
# Argentine federal prosecutor Alberto Nisman
#
# (NP  (NP (JJ Argentine) (JJ federal) (NN prosecutor))  (NP (NNP Alberto) (NNP Nisman)))
# 4
# London's Southwark Crown Court hears evidence in the first trial on female genital mutilation in the United Kingdom
#
# (NP  (NP (NNP London) (POS 's))  (NNP Southwark)  (NNP Crown)  (NNP Court))
# 9
# A six-month-old boy dies in hospital of his wounds
#
# (NP (DT A) (JJ six-month-old) (NN boy))
# 5
# Seminole County
# (NP (NNP Seminole) (NNP County))
# 2
# The city of Grozny in the Russian republic of Chechnya holds a protest with 60% of the population in attendance in opposition to the Charlie Hebdo cartoons. (Reuters)
#
# (NP  (NP (DT The) (NN city))  (PP    (IN of)    (NP      (NP (NNP Grozny))      (PP        (IN in)        (NP          (NP (DT the) (JJ Russian) (NN republic))          (PP (IN of) (NP (NNP Chechnya))))))))
# 18
# NASA releases new pictures from the Dawn spacecraft as it approaches from a distance of 238
#
# (NP (NNP NASA))
# 8
# In alpine skiing
#
# (NP (JJ alpine) (NN skiing))
# 2
# Houthi rebels take over the residence of the President amidst calls by the rebel leader for negotiations to adjust the country's power structure. (The Washington Post)
#
# (NP (JJ Houthi) (NNS rebels))
# 12
# The Islamic State of Iraq and the Levant threatens to kill two Japanese citizens unless it receives a ransom of $200 million. (Reuters)
#
# (NP  (NP (DT The) (JJ Islamic) (NN State))  (PP    (IN of)    (NP (NP (NNP Iraq)) (CC and) (NP (DT the) (NNP Levant)))))
# 11
# Boko Haram leader Abubakar Shekau claims responsibility for the attack on the town of Baga
#
# (NP (NNP Boko) (NNP Haram) (NN leader) (NNP Abubakar) (NNP Shekau))
# 9
# Oil services company Baker Hughes will lay off 7
#
# (NP  (NP (NN Oil) (NNS services))  (SBAR    (S      (NP (NN company) (NNP Baker) (NNP Hughes))      (VP (MD will) (VP (VB lay) (PRT (RP off)) (NP (CD 7)))))))
# 5
# A fire in a bowling alley causes a roof collapse in Taoyuan City
#
# (NP  (NP (DT A) (NN fire))  (PP (IN in) (NP (DT a) (NN bowling) (NN alley))))
# 7
# An overpass of I-75 in Cincinnati
#
# (NP  (NP (NP (DT An) (NN overpass)) (PP (IN of) (NP (NN I-75))))  (PP (IN in) (NP (NNP Cincinnati))))
# 6
# According to preliminary tests at the Glendive
#
# (NP  (NP (JJ preliminary) (NNS tests))  (PP (IN at) (NP (DT the) (NNP Glendive))))
# 4
# A gunman shoots a cardiovascular surgeon to death at Harvard Medical School's Brigham and Women's Hospital in Boston
#
# (NP (DT A) (NN gunman))
# 12
# _2015"]"
#
# (NP (CD 2015))
# 2
# The President of the United States Barack Obama delivers a State of the Union address to the United States Congress. (AP)
#
# (NP  (NP (DT The) (NNP President))  (PP    (IN of)    (NP (DT the) (NNP United) (NNPS States) (NNP Barack) (NNP Obama))))
# 8
# A Palestinian man from the West Bank
#
# (NP  (NP (DT A) (JJ Palestinian) (NN man))  (PP (IN from) (NP (DT the) (NNP West) (NNP Bank))))
# 4
# The President of Ukraine Petro Poroshenko accuses Russia of sending 9
#
# (NP  (NP (DT The) (NNP President))  (PP (IN of) (NP (NNP Ukraine) (NNP Petro) (NNP Poroshenko))))
# 7
# Lutz Bachmann resigns as a leader of PEGIDA
#
# (NP (NNP Lutz) (NNP Bachmann))
# 5
# eBay announces plans to spin off its PayPal business and fire 2
#
# (NP (NNP eBay))
# 6
# American Express plans to cut more than 4
#
# (NP (NNP American) (NNP Express))
# 3
# Mexico's Volcán de Colima erupts. (ABC News Australia)
#
# (NP  (NP (NP (NNP Mexico) (POS 's)) (NNP Volcán))  (PP (IN de) (NP (NNP Colima))))
# 5
# For the second time (previous was August 2000) the Avalon at Edgewater apartments in Edgewater
#
# ...
#
# (NP  (NP (NNS Tens))  (PP    (IN of)    (NP      (NP (NNS thousands))      (PP        (IN of)        (NP          (NP (NNS people))          (PP (IN in) (NP (JJ northern) (NNP Puerto) (NNP Rico))))))))
# 12
# The Movie Premiere of The Lego Ninjago Movie
#
# (NP  (NP (DT The) (NNP Movie) (NNP Premiere))  (PP (IN of) (NP (DT The) (NNP Lego) (NNP Ninjago) (NN Movie))))
# 4
# From the Team Assembled The Lego Movie and The Lego Batman Movie
#
# (NP  (NP    (DT the)    (NNP Team)    (NNP Assembled)    (NNP The)    (NNP Lego)    (NNP Movie))  (CC and)  (NP (DT The) (NNP Lego) (NNP Batman) (NN Movie)))
# 4
# _2017"]"
#
# (NP (CD 2017))
# 2
# A new study shows that Neanderthal brains developed more slowly than those of modern humans
#
# (NP (DT A) (JJ new) (NN study))
# 6
# The Venerable Rev. Father Stanley Rother
#
# (NP (NNP Rev.) (NNP Father) (NNP Stanley) (NNP Rother))
# 2
# Conspiracy theorist and book author David Meade predicted that a mythological rogue planet known as Nibiru (sometimes known as Planet X) would collide with Earth and that the world would end on this day.(FoxNews)
# (NP  (NP (NNP Conspiracy) (NN theorist))  (CC and)  (NP (NN book) (NN author) (NNP David) (NNP Meade)))
# 12
# Thousands of people on the Indonesian island of Bali flee from their homes due to concerns over Mount Agung erupting. The alert status for the volcano was increased to the highest level possible yesterday. (AP via Fox News)
#
# (NP  (NP (NNS Thousands))  (PP    (IN of)    (NP      (NP (NNS people))      (PP        (IN on)        (NP          (NP (DT the) (JJ Indonesian) (NN island))          (PP (IN of) (NP (NNP Bali))))))))
# 13
# A magnitude 6.2 earthquake strikes the central Mexican state of Oaxaca killing at least five people and damaging housing and infrastructure already damaged by Tuesday's 2017 Central Mexico earthquake. (Sky News)
#
# (NP (DT A) (NN magnitude) (CD 6.2) (NN earthquake))
# 12
# /wiki/China]"
#
# (NP (NP (NN wiki/China)) (VP (-RRB- -RSB-) ('' '')))
# 3
# [/wiki/China"
#
# (NP (NNP wiki/China))
# 2
# Iran successfully tests the Khorramshahr missile. (AFP via Yahoo! News)
#
# (NP (NNP Iran))
# 3
# Acid attacks around a mall and tube station in Stratford
#
# (NP  (NP (NN Acid) (NNS attacks))  (PP    (IN around)    (NP      (NP (DT a) (NN mall) (CC and) (NN tube) (NN station))      (PP (IN in) (NP (NNP Stratford))))))
# 6
# _2017"]"
#
# (NP (CD 2017))
# 2
# [/wiki/New_Zealand"
#
# (NP (PRN (: /) (NP (NNP wiki/New))))
# 4
# A Russian lieutenant general
#
# (NP (NP (DT A) (JJ Russian) (NN lieutenant)) (NP (NN general)))
# 4
# Iranian forces launch a military exercise near the border of Iraqi Kurdistan
#
# (NP (JJ Iranian) (NNS forces))
# 7
# FALSE
#
#
# 1
# The White House announces that citizens of North Korea
#
# (NP (DT The) (NNP White) (NNP House))
# 5
# A shooting at a church in Nashville
#
# (NP  (NP (DT A) (NN shooting))  (PP    (IN at)    (NP (NP (DT a) (NN church)) (PP (IN in) (NP (NNP Nashville))))))
# 6
# Indiana gerontophobe and prolific serial killer Orville Lynn Majors
#
# (NP  (NP (NNP Indiana))  (NP    (NP (NN gerontophobe))    (CC and)    (NP      (JJ prolific)      (JJ serial)      (NN killer)      (NNP Orville)      (NNP Lynn)      (NNP Majors))))
# 6
# _2017"]"
#
# (NP (CD 2017))
# 2
# /wiki/Chancellor_of_Germany
#
# (NP  (NP (NN wiki/Chancellor) (NN _))  (PP (IN of) (NP (NNP _) (NNP Germany))))
# 4
# Amid criticism of U.S. national anthem protests by U.S. President Donald Trump
#
# (NP (NP (NN criticism)) (PP (IN of) (NP (NNP U.S.))))
# 7
# City officials in Dubai
#
# (NP  (NP (NNP City))  (NP (NP (NNS officials)) (PP (IN in) (NP (NNP Dubai)))))
# 6
# A mass grave of 28 Hindus
#
# (NP  (NP (DT A) (NN mass))  (NP (NP (NN grave)) (PP (IN of) (NP (CD 28) (NNS Hindus)))))
# 6
# North Korea says that the recent flight of U.S. aircraft off the coast of North Korea amounts to a declaration of war. (BBC)
#
# (NP (NNP North) (NNP Korea))
# 12
# The first ever female United States Marine Corps Infantry officer graduates. (NPR)
#
# (NP  (NP (DT The) (JJ first))  (NP    (NP      (RB ever)      (JJ female)      (NNP United)      (NNPS States)      (NNP Marine)      (NNP Corps)      (NNP Infantry))    (NP (NN officer) (NNS graduates)))  (. .))
# 6
# The BBC plans to launch a service in Korean. (BBC)
#
# (NP (DT The) (NNP BBC))
# 3
# /wiki/Hurricane_Maria]"
#
# (NP  (NP (NN wiki/Hurricane) (CD _) (NNP Maria))  (VP (-RRB- -RSB-) ('' '')))
# 3
# Gunmen attack the Ogba Zoo in Benin City
#
# (NP (NNS Gunmen))
# 5
# Russian police arrest a couple  from the southern Krasnodar region that has allegedly murdered as many as 30 people since 1999 and consumed parts of the human bodies. (CNN) (International Business Times)
#
# (NP  (NP (JJ Russian) (NN police) (NN arrest))  (PP    (NP (DT a) (NN couple))    (IN from)    (NP      (NP (DT the) (JJ southern) (NNP Krasnodar) (NN region))      (SBAR        (WHNP (WDT that))        (S          (VP            (VBZ has)            (ADVP (RB allegedly))            (VP              (VP                (VBN murdered)                (PP                  (IN as)                  (NP                    (NP (QP (JJ many) (IN as) (CD 30)) (NNS people))                    (PP (IN since) (NP (CD 1999))))))              (CC and)              (VP                (VBN consumed)                (NP                  (NP (NNS parts))                  (PP (IN of) (NP (DT the) (JJ human) (NNS bodies)))))))))))  (. .))
# 12
# _2017"]"
#
# (NP (CD 2017))
# 2
# _2017"]"
#
# (NP (CD 2017))
# 2
# _2017"]"
#
# (NP (CD 2017))
# 2
# United States Senator Susan Collins says she will vote "no" on the Graham–Cassidy bill joining Senators John McCain and Rand Paul and possibly ending the most recent effort to repeal Obamacare. (The Hill)
#
# (NP  (NNP United)  (NNPS States)  (NNP Senator)  (NNP Susan)  (NNP Collins))
# 11
# At the International Astronautical Congress in Adelaide
#
# (NP  (NP    (DT the)    (NNP International)    (NNP Astronautical)    (NNP Congress))  (PP (IN in) (NP (NNP Adelaide))))
# 4
# Three Israelis are killed and one other is wounded after a Palestinian gunman opens fire in an entrance to the Israeli settlement of Har Adar in the West Bank. (Reuters)
#
# (NP  (NP (CD Three) (NNPS Israelis))  (SBAR    (S      (VP        (VBP are)        (UCP          (VP (VBN killed))          (CC and)          (ADJP (NP (CD one)) (JJ other)))))))
# 13
# The United States Department of Homeland Security plans to collect the social media information of all immigrants
#
# (NP  (NP (DT The) (NNP United) (NNP States) (NNP Department))  (PP (IN of) (NP (NNP Homeland) (NNP Security))))
# 7
# Twitter is experimenting with doubling its 140 character limit to 280 characters for all languages except Japanese
#
# (NP (NNP Twitter))
# 8
# The U.S. Commerce Department imposes preliminary anti-subsidy duties on Bombardier Inc. CSeries jets following American rival Boeing's claims of unfair Canadian subsidies.  The penalty is on hold pending the U.S. International Trade Commission's final decision
#
# (NP (DT The) (NNP U.S.) (NNP Commerce) (NNP Department))
# 5
# The king of Saudi Arabia issues a decree allowing women to be issued driving licenses by June 2018. Saudi Arabia is the world's last sovereign state that does not allow women to drive. (The Guardian)
#
# (NP  (NP (DT The) (NN king))  (PP (IN of) (NP (NNP Saudi) (NNP Arabia))))
# 9
# The office of the United States Attorney for the Southern District of New York announces that 10 individuals
#
# (NP  (NP (DT The) (NN office))  (PP    (IN of)    (NP      (NP (DT the) (NNP United) (NNPS States) (NNP Attorney))      (PP        (IN for)        (NP          (NP (DT the) (NNP Southern) (NNP District))          (PP (IN of) (NP (NNP New) (NNP York))))))))
# 9
# _2017"]"
#
# (NP (CD 2017))
# 2
# nan
#
# (NP (NN nan))
# 2
# [http://www.aljazeera.com/news/2017/09/iraqi-kurds-count-independence-referendum-170925174221276.html"
#
# (NP  (-LRB- -LSB-)  (NN    http://www.aljazeera.com/news/2017/09/iraqi-kurds-count-independence-referendum-170925174221276.html"))
# 2
# /wiki/United_States_Senate_special_election_in_Alabama,_2017]"
#
# (NP (NNPS States))
# 12
# Russian President Vladimir Putin dismisses Nizhny Novgorod Oblast governor Valery Shantsev from his post
#
# (NP (NNP Russian) (NNP President) (NNP Vladimir) (NNP Putin))
# 5
# Acting U.S. Drug Enforcement Administration chief Chuck Rosenberg announces his resignation
#
# (NP  (NNP Acting)  (NNP U.S.)  (NNP Drug)  (NNP Enforcement)  (NNP Administration)  (NN chief)  (NNP Chuck)  (NNP Rosenberg))
# 3
# Africa's Great Green Wall is successfully reversing desertification. (BBC)
#
# (NP (NP (NNP Africa) (POS 's)) (NNP Great) (NNP Green) (NNP Wall))
# 4
# Russian aircraft carry out air strikes on the Christian-majority Qaina and Yaqobia villages
#
# (NP (JJ Russian) (NN aircraft))
# 5
#  and causing large number of civilians to flee. (Iraqi News)
#
# (NP (CC and))
# 5
# Russia announces it has completed the destruction of all of its chemical weapons under the terms of the Chemical Weapons Convention. (New York Times)
#
# (NP (NNP Russia))
# 11
# Thirty thousand people are evacuated from Kalynivka
#
# (NP (QP (CD Thirty) (CD thousand)) (NNS people))
# 3
# /wiki/Hurricane_Maria]"
#
# (NP  (NP (NN wiki/Hurricane) (CD _) (NNP Maria))  (VP (-RRB- -RSB-) ('' '')))
# 3
# /wiki/United_States_Department_of_Homeland_Security
#
# (NP (NNPS States) (NNP _) (NNP Department))
# 4
# Along with the Solomon Islands
#
# (NP (DT the) (NNP Solomon) (NNPS Islands))
# 2
# Uzbekistan dissident writer Nurulloh Muhammad Raufkhon is arrested on his return to the Central Asian country from exile. (Reuters)
#
# (NP  (NNP Uzbekistan)  (JJ dissident)  (NN writer)  (NNP Nurulloh)  (NNP Muhammad)  (NNP Raufkhon))
# 6
# Former Thai Prime Minister Yingluck Shinawatra is sentenced to five years in prison in absentia. (BBC)
# (NP  (JJ Former)  (NNP Thai)  (NNP Prime)  (NNP Minister)  (NNP Yingluck)  (NNP Shinawatra))
# 6
# _2017"]"
#
# (NP (CD 2017))
# 2
# The Republic of Ireland announces a referendum on abortion will be held between May and June 2018. (The Telegraph)
#
# (NP (NP (DT The) (NNP Republic)) (PP (IN of) (NP (NNP Ireland))))
# 10
# _2017"]"
#
# (NP (CD 2017))
# 2
# https://www.bbc.com/news/world-middle-east-41413999]"
#
# (NP (NN https://www.bbc.com/news/world-middle-east-41413999))
# 2
# _2017"]"
#
# (NP (CD 2017))
# 2
# California moves its 2020 presidential primary to March 3
#
# (NP (NNP California))
# 7
# Facebook
#
# (NP (NNP Facebook))
# 2
# The University of Louisville
#
# (NP  (NP (DT The) (NNP University))  (PP (IN of) (NP (NNP Louisville))))
# 4
# The Islamic State of Iraq and the Levant releases footage which apparently show its leader Abu Bakr al-Baghdadi urging his followers to expand their attacks against "crusaders and apostates". (Los Angeles Times)
#
# (NP  (NP (DT The) (JJ Islamic) (NN State))  (PP    (IN of)    (NP (NP (NNP Iraq)) (CC and) (NP (DT the) (NN Levant)))))
# 14
# Whole Foods Market
#
# (NP (NP (JJ Whole)) (NP (NNP Foods) (NNP Market)))
# 4
# /wiki/Hurricane_Maria]"
#
# (NP  (NP (NN wiki/Hurricane) (CD _) (NNP Maria))  (VP (-RRB- -RSB-) ('' '')))
# 3
# More than 134
#
# (NP (NP (JJR More)) (PP (IN than) (NP (CD 134))))
# 4
# At least 14 Rohingya people
#
# (NP (QP (IN At) (JJS least) (CD 14)) (JJ Rohingya) (NNS people))
# 2
# _2017"]"
#
# (NP (CD 2017))
# 2
# _2017"]"
#
# (NP (CD 2017))
# 2
# Aquatic species from Japan hitched a ride on debris from the 2011 Tōhoku earthquake and tsunami and were able to reach the West Coast of the United States alive. (Phys.org)
#
# (NP (NP (JJ Aquatic) (NNS species)) (PP (IN from) (NP (NNP Japan))))
# 12
# Al-Shabaab militants attack a military base outside the Somalian capital Mogadishu
#
# (NP (JJ Al-Shabaab) (NNS militants))
# 5
# At least 22 people are killed and over 30 are seriously injured in a rush hour stampede on a footbridge between the Parel and Elphinstone Road railway stations in the Indian city of Mumbai. (Reuters)
#
# (NP (QP (IN At) (JJS least) (CD 22)) (NNS people))
# 10
# A Mexico City borough president says previous officials ignored warnings that unauthorized construction work had damaged the structural integrity of several buildings in the city. The overall death toll from the magnitude 7.1 quake which hit Sept. 19 now stands at at least 358 people. (AP)
#
# (NP (DT A) (NNP Mexico) (NNP City) (NN borough) (NN president))
# 11
# _2017"]"
#
# (NP (CD 2017))
# 2
# The U.S. State Department removes all families of employees and nonessential personnel from Cuba following apparent sonic attacks that injured 21 personnel on the island. Cuba denies any involvement and has authorized the FBI to travel to the island to help the ongoing investigation into the causes. (CNN)
#
# (NP (DT The) (NNP U.S.) (NNP State) (NNP Department))
# 13
# _2017"]"
#
# (NP (CD 2017))
# 2
# Tom Price resigns as the Secretary of Health and Human Services in the midst of a scandal over his use of private planes. (CNN)
#
# (NP (NNP Tom) (NNP Price))
# 12
# Sun Zhengcai is expelled from the Communist Party of China after the results into the internal disciplinary investigation are announced by the Central Commission for Discipline Inspection. (The Washington Post)
#
# (NP (NNP Sun) (NNP Zhengcai))
# 11
# /wiki/Central_Commission_for_Discipline_Inspection]"
#
# (NP  (NP    (PRN (: /) (NP (NNP wiki/Central) (NNP _)))    (NNP Commission)    (NNP _))  (PP    (IN for)    (NP (NNP _) (NNP Discipline) (NNP _) (NNP Inspection)))  (-RRB- -RSB-)  ('' ''))
# 5
# The journal Protein & Cell publishes Sun Yat-sen University research describing the use of gene therapy in the removal of a version of the inherited blood disorder beta-thalassemia from an artificially-created nuclear transfer-type of cloning-model system of human oocytes. Collectively
#
# (NP (NP (DT The) (NN journal) (NN Protein)) (CC &) (NP (NN Cell)))
# 20
# In Edmonton
#
# (NP (NNP Edmonton))
# 2
# A fire at a retirement home in Bucharest
#
# (NP  (NP (DT A) (NN fire))  (PP    (IN at)    (NP      (NP (DT a) (NN retirement) (NN home))      (PP (IN in) (NP (NNP Bucharest))))))
# 6
# A military transport plane crashes after take-off from N'djili Airport in Kinshasa
#
# (NP  (NP (DT A) (JJ military) (NN transport))  (NP    (NP (NN plane) (NNS crashes))    (PP      (IN after)      (NP        (NP (NN take-off))        (PP          (IN from)          (NP            (NP (NNP N'djili) (NNP Airport))            (PP (IN in) (NP (NNP Kinshasa)))))))))
# 10
# A crowd surge collapses a barrier during a soccer match at Stade de la Licorne in Amiens
#
# (NP (DT A) (NN crowd) (NN surge))
# 9
# /wiki/Rohingya_persecution_in_Myanmar_(2016%E2%80%93present)]"
#
# (NP  (NP (NN wiki/Rohingya) (NN _) (NN persecution) (NN _))  (PP    (IN in)    (NP      (NP (NNP _) (NNP Myanmar) (NN _))      (PRN        (-LRB- -LRB-)        (NP (NP (CD 2016)) (: --) (NP (JJ present)))        (-RRB- -RRB-))      (-RRB- -RSB-)      ('' ''))))
# 8
# Tens of thousands of protesters march through Dublin to demand Ireland to change its abortion laws
#
# (NP  (NP (NNS Tens))  (PP    (IN of)    (NP      (NP (NNS thousands))      (PP        (IN of)        (NP          (NNS protesters)          (S            (VP              (VB march)              (PP (IN through) (NP (NNP Dublin)))              (S                (VP                  (TO to)                  (VP                    (VB demand)                    (S                      (NP (NNP Ireland))                      (VP                        (TO to)                        (VP                          (VB change)                          (NP (PRP$ its) (NN abortion) (NNS laws)))))))))))))))
# 9
# About 600 members of the Swedish neo-Nazi group Nordic Resistance Movement march through Gothenburg
#
# (NP  (NP (CD 600) (NNS members))  (PP    (IN of)    (NP      (NP (DT the) (JJ Swedish) (JJ neo-Nazi) (NN group))      (SBAR        (S          (NP (JJ Nordic) (NN Resistance) (NNP Movement))          (VP (VB march) (PP (IN through) (NP (NNP Gothenburg)))))))))
# 7
# The Australian rules football club Richmond Football Club defeats the Adelaide Football Club in the 2017 AFL Grand Final by 108 points to 60. Dustin Martin won the Norm Smith Medal for best on ground after having won the 2017 Brownlow Medal for the best and fairest player in the competition. (ABC Australia)
#
# (NP  (NP (DT The) (JJ Australian) (NNS rules) (NN football) (NN club))  (NP (NNP Richmond) (NNP Football) (NNP Club)))
# 10

# %%
df
# Out:
#                                                      _id  \
# 0                   ObjectId("5d056c5bb5f3a01b25e85fd2")
# 1                   ObjectId("5d056c5bb5f3a01b25e85fd3")
# 2                   ObjectId("5d056c5bb5f3a01b25e85fd4")
# 3                   ObjectId("5d056c5bb5f3a01b25e85fd5")
# 4                   ObjectId("5d056c5bb5f3a01b25e85fd6")
# 5                   ObjectId("5d056c5bb5f3a01b25e85fd7")
# 6                   ObjectId("5d056c5bb5f3a01b25e85fd8")
# 7                   ObjectId("5d056c5bb5f3a01b25e85fd9")
# 8                   ObjectId("5d056c5bb5f3a01b25e85fda")
# 9                   ObjectId("5d056c5bb5f3a01b25e85fdb")
# 10                  ObjectId("5d056c5bb5f3a01b25e85fdc")
# 11                  ObjectId("5d056c5bb5f3a01b25e85fdd")
# 12                  ObjectId("5d056c5bb5f3a01b25e85fde")
# 13                  ObjectId("5d056c5bb5f3a01b25e85fdf")
# 14                  ObjectId("5d056c5bb5f3a01b25e85fe0")
# 15                  ObjectId("5d056c5bb5f3a01b25e85fe1")
# 16                  ObjectId("5d056c5bb5f3a01b25e85fe2")
# 17                  ObjectId("5d056c5bb5f3a01b25e85fe3")
# 18                  ObjectId("5d056c5bb5f3a01b25e85fe4")
# 19                  ObjectId("5d056c5bb5f3a01b25e85fe5")
# 20                  ObjectId("5d056c5bb5f3a01b25e85fe6")
# 21     The Pakistan Air Force strikes Pakistani Talib...
# 22     A bomb detonates at a volleyball match in Orak...
# 23                  ObjectId("5d056c5bb5f3a01b25e85fe7")
# 24                  ObjectId("5d056c5bb5f3a01b25e85fe8")
# 25                  ObjectId("5d056c5bb5f3a01b25e85fe9")
# 26                  ObjectId("5d056c5bb5f3a01b25e85fea")
# 27                  ObjectId("5d056c5bb5f3a01b25e85feb")
# 28                  ObjectId("5d056c5bb5f3a01b25e85fec")
# 29                  ObjectId("5d056c5bb5f3a01b25e85fed")
# ...                                                  ...
# 12787               ObjectId("5d056c7ab5f3a01b25e88db9")
# 12788               ObjectId("5d056c7ab5f3a01b25e88dba")
# 12789               ObjectId("5d056c7ab5f3a01b25e88dbb")
# 12790               ObjectId("5d056c7ab5f3a01b25e88dbc")
# 12791               ObjectId("5d056c7ab5f3a01b25e88dbd")
# 12792               ObjectId("5d056c7ab5f3a01b25e88dbe")
# 12793               ObjectId("5d056c7ab5f3a01b25e88dbf")
# 12794               ObjectId("5d056c7ab5f3a01b25e88dc0")
# 12795               ObjectId("5d056c7ab5f3a01b25e88dc1")
# 12796               ObjectId("5d056c7ab5f3a01b25e88dc2")
# 12797               ObjectId("5d056c7ab5f3a01b25e88dc3")
# 12798               ObjectId("5d056c7ab5f3a01b25e88dc4")
# 12799               ObjectId("5d056c7ab5f3a01b25e88dc5")
# 12800               ObjectId("5d056c7ab5f3a01b25e88dc6")
# 12801               ObjectId("5d056c7ab5f3a01b25e88dc7")
# 12802               ObjectId("5d056c7ab5f3a01b25e88dc8")
# 12803               ObjectId("5d056c7ab5f3a01b25e88dc9")
# 12804               ObjectId("5d056c7ab5f3a01b25e88dca")
# 12805               ObjectId("5d056c7ab5f3a01b25e88dcb")
# 12806               ObjectId("5d056c7ab5f3a01b25e88dcc")
# 12807  Reverberations from the Sun Zhengcai case are ...
# 12808               ObjectId("5d056c7ab5f3a01b25e88dcd")
# 12809               ObjectId("5d056c7ab5f3a01b25e88dce")
# 12810               ObjectId("5d056c7ab5f3a01b25e88dcf")
# 12811               ObjectId("5d056c7ab5f3a01b25e88dd0")
# 12812               ObjectId("5d056c7ab5f3a01b25e88dd1")
# 12813               ObjectId("5d056c7ab5f3a01b25e88dd2")
# 12814               ObjectId("5d056c7ab5f3a01b25e88dd3")
# 12815               ObjectId("5d056c7ab5f3a01b25e88dd4")
# 12816               ObjectId("5d056c7ab5f3a01b25e88dd5")
#
#                                                     date  \
# 0                             2015-01-01T00:00:00.000Z""
# 1                             2015-01-01T00:00:00.000Z""
# 2                             2015-01-01T00:00:00.000Z""
# 3                             2015-01-01T00:00:00.000Z""
# 4                             2015-01-01T00:00:00.000Z""
# 5                             2015-01-01T00:00:00.000Z""
# 6                             2015-01-01T00:00:00.000Z""
# 7                             2015-01-01T00:00:00.000Z""
# 8                             2015-01-02T00:00:00.000Z""
# 9                             2015-01-02T00:00:00.000Z""
# 10                            2015-01-02T00:00:00.000Z""
# 11                            2015-01-02T00:00:00.000Z""
# 12                            2015-01-02T00:00:00.000Z""
# 13                            2015-01-03T00:00:00.000Z""
# 14                            2015-01-03T00:00:00.000Z""
# 15                            2015-01-03T00:00:00.000Z""
# 16                            2015-01-03T00:00:00.000Z""
# 17                            2015-01-03T00:00:00.000Z""
# 18                            2015-01-03T00:00:00.000Z""
# 19                            2015-01-03T00:00:00.000Z""
# 20                            2015-01-04T00:00:00.000Z""
# 21                                              Pakistan
# 22                                              Pakistan
# 23                            2015-01-04T00:00:00.000Z""
# 24                            2015-01-04T00:00:00.000Z""
# 25                            2015-01-04T00:00:00.000Z""
# 26                            2015-01-04T00:00:00.000Z""
# 27                            2015-01-04T00:00:00.000Z""
# 28                            2015-01-04T00:00:00.000Z""
# 29                            2015-01-05T00:00:00.000Z""
# ...                                                  ...
# 12787                         2017-09-27T00:00:00.000Z""
# 12788                         2017-09-27T00:00:00.000Z""
# 12789                         2017-09-27T00:00:00.000Z""
# 12790                         2017-09-27T00:00:00.000Z""
# 12791                         2017-09-28T00:00:00.000Z""
# 12792                         2017-09-28T00:00:00.000Z""
# 12793                         2017-09-28T00:00:00.000Z""
# 12794                         2017-09-28T00:00:00.000Z""
# 12795                         2017-09-28T00:00:00.000Z""
# 12796                         2017-09-28T00:00:00.000Z""
# 12797                         2017-09-28T00:00:00.000Z""
# 12798                         2017-09-28T00:00:00.000Z""
# 12799                         2017-09-29T00:00:00.000Z""
# 12800                         2017-09-29T00:00:00.000Z""
# 12801                         2017-09-29T00:00:00.000Z""
# 12802                         2017-09-29T00:00:00.000Z""
# 12803                         2017-09-29T00:00:00.000Z""
# 12804                         2017-09-29T00:00:00.000Z""
# 12805                         2017-09-29T00:00:00.000Z""
# 12806                         2017-09-29T00:00:00.000Z""
# 12807   including former Organization Department head...
# 12808                         2017-09-29T00:00:00.000Z""
# 12809                         2017-09-30T00:00:00.000Z""
# 12810                         2017-09-30T00:00:00.000Z""
# 12811                         2017-09-30T00:00:00.000Z""
# 12812                         2017-09-30T00:00:00.000Z""
# 12813                         2017-09-30T00:00:00.000Z""
# 12814                         2017-09-30T00:00:00.000Z""
# 12815                         2017-09-30T00:00:00.000Z""
# 12816                         2017-09-30T00:00:00.000Z""
#
#                                                 category  \
# 0                            Armed conflicts and attacks
# 1                            Armed conflicts and attacks
# 2                                   Business and economy
# 3                                   Business and economy
# 4                                International relations
# 5                                International relations
# 6                                          Law and crime
# 7                                 Politics and elections
# 8                            Armed conflicts and attacks
# 9                            Armed conflicts and attacks
# 10                           Armed conflicts and attacks
# 11                               Disasters and accidents
# 12                               International relations
# 13                           Armed conflicts and attacks
# 14                                      Arts and culture
# 15                               Disasters and accidents
# 16                               Disasters and accidents
# 17                               Disasters and accidents
# 18                                         Law and crime
# 19                                Politics and elections
# 20                           Armed conflicts and attacks
# 21                killing 31 militants. (Channel 9 News)
# 22      killing four people and injuring eight. (AFP ...
# 23                           Armed conflicts and attacks
# 24                           Armed conflicts and attacks
# 25                           Armed conflicts and attacks
# 26                               Disasters and accidents
# 27                                              Religion
# 28                                                 Sport
# 29                           Armed conflicts and attacks
# ...                                                  ...
# 12787                             Politics and elections
# 12788                             Politics and elections
# 12789                             Politics and elections
# 12790                                             Sports
# 12791                        Armed conflicts and attacks
# 12792                               Business and economy
# 12793                            Disasters and accidents
# 12794                            Disasters and accidents
# 12795                            Disasters and accidents
# 12796                             Politics and elections
# 12797                             Politics and elections
# 12798                             Science and technology
# 12799                        Armed conflicts and attacks
# 12800                            Disasters and accidents
# 12801                            Disasters and accidents
# 12802                            International relations
# 12803                            International relations
# 12804                             Politics and elections
# 12805                             Politics and elections
# 12806                             Politics and elections
# 12807                               [/wiki/Sun_Zhengcai"
# 12808                             Science and technology
# 12809                        Armed attacks and conflicts
# 12810                            Disasters and accidents
# 12811                            Disasters and accidents
# 12812                            Disasters and accidents
# 12813                            International relations
# 12814                             Politics and elections
# 12815                             Politics and elections
# 12816                                             Sports
#
#                                              event_title  \
# 0                           [/wiki/Terrorism_in_Yemen"]"
# 1                                                  FALSE
# 2                                                  FALSE
# 3                                                  FALSE
# 4                                                  FALSE
# 5                                                  FALSE
# 6                                                  FALSE
# 7                                                  FALSE
# 8      [/wiki/Somali_Civil_War_(2009%E2%80%93present)"]"
# 9               [/wiki/Islamist_insurgency_in_Nigeria"]"
# 10         [/wiki/1998_United_States_embassy_bombings"]"
# 11                                                 FALSE
# 12     [/wiki/North_Korea%E2%80%93United_States_relat...
# 13                                  [/wiki/Boko_Haram"]"
# 14                                                 FALSE
# 15                                                 FALSE
# 16                                                 FALSE
# 17                                                 FALSE
# 18                                                 FALSE
# 19                     [/wiki/Greek_legislative_election
# 20                  [/wiki/War_in_North-West_Pakistan"]"
# 21                                                   NaN
# 22                                    [/wiki/Uzbekistan"
# 23                      [/wiki/Northern_Mali_conflict"]"
# 24                    [/wiki/Shia_insurgency_in_Yemen"]"
# 25                            [/wiki/Somali_Civil_War"]"
# 26                                                 FALSE
# 27                                                 FALSE
# 28                                                 FALSE
# 29     [/wiki/Libyan_Civil_War_(2014%E2%80%93present)"]"
# ...                                                  ...
# 12787                     [/wiki/German_federal_election
# 12788       [/wiki/United_States_presidential_primary"]"
# 12789  [/wiki/Russian_interference_in_the_2016_United...
# 12790  [/wiki/2017_NCAA_Division_I_men%27s_basketball...
# 12791                         [/wiki/Syrian_Civil_War"]"
# 12792                        [/wiki/Credit_card_fraud"]"
# 12793             [/wiki/2017_Atlantic_hurricane_season"
# 12794                             [/wiki/Ring_of_Fire"]"
# 12795           [/wiki/Northern_Rakhine_State_clashes"]"
# 12796                   [/wiki/Japanese_general_election
# 12797             [/wiki/Catalan_independence_referendum
# 12798  [/wiki/Aftermath_of_the_2011_T%C5%8Dhoku_earth...
# 12799  [/wiki/Somali_Civil_War_(2009%E2%80%93present)"]"
# 12800                     [/wiki/2017_Mumbai_stampede"]"
# 12801           [/wiki/2017_Central_Mexico_earthquake"]"
# 12802     [/wiki/Iraqi_Kurdistan_independence_referendum
# 12803     [/wiki/Cuba%E2%80%93United_States_relations"]"
# 12804   [/wiki/UK_Independence_Party_leadership_election
# 12805               [/wiki/Presidency_of_Donald_Trump"]"
# 12806  [/wiki/Anti-corruption_campaign_under_Xi_Jinpi...
# 12807                     /wiki/Communist_Party_of_China
# 12808                             [/wiki/Gene_therapy"]"
# 12809                     [/wiki/2017_Edmonton_attack"]"
# 12810                          [/wiki/2017_in_Romania"]"
# 12811  [/wiki/2017_in_the_Democratic_Republic_of_the_...
# 12812                           [/wiki/Human_stampede"]"
# 12813              [/wiki/Foreign_relations_of_Thailand"
# 12814      [/wiki/Abortion_in_the_Republic_of_Ireland"]"
# 12815                         [/wiki/Nazism_in_Sweden"]"
# 12816                     [/wiki/2017_AFL_Grand_Final"]"
#
#                                            event_summary  \
# 0           The death toll of the suicide bombing in Ibb
# 1      A shooting kills one and injures six people in...
# 2      Lithuania adopts the euro as its official curr...
# 3      U.S. fast-food restaurant chain Chick-fil-A wa...
# 4      The Palestine Authority signs a treaty to join...
# 5             The Eurasian Economic Union between Russia
# 6            Vietnam’s new marriage law goes into effect
# 7                                            Mario Cuomo
# 8      Somali al-Shabaab militants attack an army bas...
# 9              Boko Haram militants attack a bus in Waza
# 10                                      Abu Anas al-Libi
# 11     The MS Norman Atlantic ferry fire death toll r...
# 12     The United States enacts more sanctions on Nor...
# 13     Fleeing villagers from a remote part of the Bo...
# 14     Turkey permits the building of a Syriac church...
# 15     The Singapore-registered cargo ship MV Höegh O...
# 16                                       MS Bulk Jupiter
# 17     The Cypriot-registered cargo ship Cemfjord sin...
# 18                                    A prison in Bruges
# 19                                      _January_2015"]"
# 20     A U.S. drone strike kills eight Uzbek people c...
# 21                                                   nan
# 22                                        /wiki/Al-Qaeda
# 23     A vehicle carrying United Nations peacekeepers...
# 24     A bombing at a local Houthi movement headquart...
# 25     A suicide car bomber detonates near a military...
# 26              A six-story building collapse in Nairobi
# 27     Pope Francis announces the appointment of 20 n...
# 28                                              In darts
# 29     A Libyan warplane bombs a Greek-operated oil t...
# ...                                                  ...
# 12787                                           _2017"]"
# 12788  California moves its 2020 presidential primary...
# 12789                                           Facebook
# 12790                       The University of Louisville
# 12791  The Islamic State of Iraq and the Levant relea...
# 12792                                 Whole Foods Market
# 12793                            /wiki/Hurricane_Maria]"
# 12794                                      More than 134
# 12795                        At least 14 Rohingya people
# 12796                                           _2017"]"
# 12797                                           _2017"]"
# 12798  Aquatic species from Japan hitched a ride on d...
# 12799  Al-Shabaab militants attack a military base ou...
# 12800  At least 22 people are killed and over 30 are ...
# 12801  A Mexico City borough president says previous ...
# 12802                                           _2017"]"
# 12803  The U.S. State Department removes all families...
# 12804                                           _2017"]"
# 12805  Tom Price resigns as the Secretary of Health a...
# 12806  Sun Zhengcai is expelled from the Communist Pa...
# 12807  /wiki/Central_Commission_for_Discipline_Inspec...
# 12808  The journal Protein & Cell publishes Sun Yat-s...
# 12809                                        In Edmonton
# 12810           A fire at a retirement home in Bucharest
# 12811  A military transport plane crashes after take-...
# 12812  A crowd surge collapses a barrier during a soc...
# 12813  /wiki/Rohingya_persecution_in_Myanmar_(2016%E2...
# 12814  Tens of thousands of protesters march through ...
# 12815  About 600 members of the Swedish neo-Nazi grou...
# 12816  The Australian rules football club Richmond Fo...
#
#                                                 entities  \
# 0                                                  Yemen
# 1                                                Calgary
# 2        becoming the 19th member of the Eurozone. (CNN)
# 3             000 customers in five states. (Daily Mail)
# 4                                  [Palestine Authority"
# 5                                             Kazakhstan
# 6       abolishing regulations that “prohibit marriag...
# 7          former governor of the U.S. state of New York
# 8       killing seven soldiers. (Reuters via Daily Ti...
# 9                                               Cameroon
# 10               a one-time associate of Osama bin Laden
# 11                                [MS Norman Atlantic"]"
# 12                                   [/wiki/North_Korea"
# 13                                 [/wiki/Borno_State"]"
# 14      the first construction of a Christian house o...
# 15      in the entrance to Southampton Water. (BBC News)
# 16                          a Norwegian-owned cargo ship
# 17                                              [Cyprus"
# 18                                               Belgium
# 19     Former Prime Minister George Papandreou announ...
# 20                                                   NaN
# 21                                                   NaN
# 22                                      /wiki/Pakistan]"
# 23                      injuring six soldiers. (Reuters)
# 24                                                 Yemen
# 25                                               Somalia
# 26                                                 Kenya
# 27      many of them coming from outside of Europe. (...
# 28      Gary Anderson of Scotland defeats Phil Taylor...
# 29                                   killing two sailors
# ...                                                  ...
# 12787  Former members of the Alternative für Deutschl...
# 12788   making it  fifth in the nominating process af...
# 12789                                             Google
# 12790   whose men's basketball team was linked to ill...
# 12791       [/wiki/Islamic_State_of_Iraq_and_the_Levant"
# 12792                        recently acquired by Amazon
# 12793  U.S. President Donald Trump waives the Jones A...
# 12794                   000 people on the island of Bali
# 12795                              including 10 children
# 12796  Prime Minister Shinzō Abe dissolves the lower ...
# 12797  The President of Catalonia vows to continue on...
# 12798                                      [/wiki/Japan"
# 12799          with 15 soldiers reported dead. (Reuters)
# 12800                                             (NDTV)
# 12801                              [/wiki/Mexico_City"]"
# 12802  Iraq's federal government halts all internatio...
# 12803          [/wiki/United_States_Department_of_State"
# 12804                  Henry Bolton wins UKIP leadership
# 12805            [/wiki/Tom_Price_(American_politician)"
# 12806                                                NaN
# 12807                                              FALSE
# 12808   this study demonstrated the feasibility of cu...
# 12809                                            Alberta
# 12810                                            Romania
# 12811                   Democratic Republic of the Congo
# 12812                                             France
# 12813  Thailand's Ministry of Foreign Affairs says it...
# 12814   and anti-abortion activists stage counter-dem...
# 12815                                             and 10
# 12816                                    (ABC Australia)
#
#                                                   person  \
# 0       that occurred on December 31 rises to 49 with...
# 1                                                 Canada
# 2                               [Lithuania and the euro"
# 3                                        [Chick-fil-A"]"
# 4                         International Criminal Court]"
# 5                                                Belarus
# 6                                              [Vietnam"
# 7                       dies at the age of 82. (Reuters)
# 8                                        [/wiki/Somalia"
# 9       killing eleven people and injuring six. (CNN ...
# 10                                      dies in New York
# 11                                                 FALSE
# 12                /wiki/Sony_Pictures_Entertainment_hack
# 13                                                 FALSE
# 14                                              [Turkey"
# 15                                           [Singapore"
# 16                        sinks off the coast of Vietnam
# 17                                           MV Cemfjord
# 18      will euthanise serial rapist and murderer Fra...
# 19                     Movement of Democratic Socialists
# 20                                                   NaN
# 21                                                   NaN
# 22                                                 FALSE
# 23                                [/wiki/United_Nations"
# 24      kills five people and wounds 25. (AP via The ...
# 25                            killing four people. (BBC)
# 26      kills one person and leaves several others in...
# 27                                        [Pope Francis"
# 28                                               [Darts"
# 29      one Greek and one Romanian. The Greek governm...
# ...                                                  ...
# 12787           [/wiki/Alternative_f%C3%BCr_Deutschland"
# 12788                                      New Hampshire
# 12789   and Twitter executives have been asked to tes...
# 12790   places head coach Rick Pitino and athletic di...
# 12791                       /wiki/Abu_Bakr_al-Baghdadi]"
# 12792   announces hacking of payment card information...
# 12793   citing shipping industry business interests. ...
# 12794                                          Indonesia
# 12795   fleeing violence in Myanmar are killed when t...
# 12796                            [/wiki/Shinz%C5%8D_Abe"
# 12797  [/wiki/President_of_the_Generalitat_of_Catalonia"
# 12798      /wiki/2011_T%C5%8Dhoku_earthquake_and_tsunami
# 12799                [/wiki/Al-Shabaab_(militant_group)"
# 12800                      [/wiki/Parel_railway_station"
# 12801                                              FALSE
# 12802                                       [/wiki/Iraq"
# 12803                                 /wiki/Sonic_weapon
# 12804         taking over the position from Paul Nuttall
# 12805     /wiki/Secretary_of_Health_and_Human_Services]"
# 12806                                                NaN
# 12807  [https://www.washingtonpost.com/world/asia_pac...
# 12808                                   (Protein & Cell)
# 12809                                             Canada
# 12810   leaves one person dead and 19 others injured....
# 12811   killing all 12 Russian crew members. (Deutsch...
# 12812                        injuring twenty-nine people
# 12813                                   [/wiki/Thailand"
# 12814                                     [/wiki/Dublin"
# 12815  000 people hold a counter-demonstration. More ...
# 12816                  [/wiki/Australian_rules_football"
#
#                                            external_link  \
# 0                               [/wiki/2014_Ibb_bombing"
# 1         with police making no arrests. (National Post)
# 2                                             Eurozone]"
# 3                                                  FALSE
# 4                                                  FALSE
# 5       Kyrgyzstan and Armenia comes into effect (Nov...
# 6                         Same-sex marriage in Vietnam]"
# 7                                          [Mario Cuomo"
# 8                      /wiki/Al-Shabaab_(militant_group)
# 9                                     [/wiki/Boko_Haram"
# 10                                         United States
# 11     [http://www.independent.ie/world-news/europe/i...
# 12                                            /wiki/Sony
# 13     [https://www.bbc.com/news/world-africa-3066601...
# 14                                   Assyrians in Turkey
# 15                                        MV Höegh Osaka
# 16           with eighteen dead and one survivor. (KRON)
# 17                                            Scotland]"
# 18                                              [Bruges"
# 19      threatening to push the long-dominant PASOK u...
# 20                                                   NaN
# 21                                                   NaN
# 22     [http://www.9news.com.au/world/2015/01/04/19/3...
# 23                                          /wiki/Mali]"
# 24                                       [/wiki/Houthis"
# 25                                     [/wiki/Mogadishu"
# 26                                             [Nairobi"
# 27                          Cardinals created by Francis
# 28                          Gary Anderson (darts player)
# 29                                         [/wiki/Libya"
# ...                                                  ...
# 12787                                 /wiki/Frauke_Petry
# 12788                                             Nevada
# 12789          according to committee sources. (Reuters)
# 12790   pending further university action. Pitino's a...
# 12791                                              FALSE
# 12792                         [/wiki/Whole_Foods_Market"
# 12793                                              water
# 12794   have been taken to shelters as the Mount Agun...
# 12795                            [/wiki/Rohingya_people"
# 12796           /wiki/House_of_Representatives_(Japan)]"
# 12797                                    /wiki/Catalonia
# 12798            /wiki/West_Coast_of_the_United_States]"
# 12799                                      /wiki/Somalia
# 12800             /wiki/Elphinstone_Road_railway_station
# 12801  [https://www.apnews.com/4d56fc67f60d47c3874a43...
# 12802                   /wiki/Federal_government_of_Iraq
# 12803         /wiki/Embassy_of_the_United_States,_Havana
# 12804   who resigned after the party's poor performan...
# 12805                                              FALSE
# 12806                                                NaN
# 12807  http://www.scmp.com/news/china/policies-politi...
# 12808                           [/wiki/Protein_%26_Cell"
# 12809                          near Commonwealth Stadium
# 12810                                  [/wiki/Bucharest"
# 12811                          [/wiki/N%27djili_Airport"
# 12812    five of them seriously. (AFP via Yahoo! Sports)
# 12813       /wiki/Ministry_of_Foreign_Affairs_(Thailand)
# 12814                                   /wiki/Pro-choice
# 12815                                     [/wiki/Sweden"
# 12816                       /wiki/Richmond_Football_Club
#
#                                               Unnamed: 8  \
# 0                                              /wiki/Ibb
# 1                                             [Killarney
# 2                                                  FALSE
# 3      [http://www.dailymail.co.uk/news/article-28936...
# 4      [https://www.wsj.com/articles/abbas-oks-palest...
# 5                              [Eurasian Economic Union"
# 6                                                  FALSE
# 7                                     New York (state)]"
# 8                                         /wiki/Baidoa]"
# 9                               /wiki/Waza_National_Park
# 10      while awaiting trial for allegedly plotting t...
# 11                                                   NaN
# 12          /wiki/North_Korean_Special_Operation_Force]"
# 13                                                   NaN
# 14                                     Church (building)
# 15                                         Isle of Wight
# 16                                     [MS Bulk Jupiter"
# 17                                                 FALSE
# 18                                               Belgium
# 19                                             (Reuters)
# 20                                                   NaN
# 21                                                   NaN
# 22     http://www.9news.com.au/world/2015/01/04/19/32...
# 23                                                 FALSE
# 24                              /wiki/Dhamar_Governorate
# 25                                       /wiki/Somalia]"
# 26                                               Kenya]"
# 27                                Cardinal (Catholicism)
# 28                                              Scotland
# 29                                    /wiki/Derna,_Libya
# ...                                                  ...
# 12787                            /wiki/Marcus_Pretzell]"
# 12788   and South Carolina. The 2016 primary was held...
# 12789                                   [/wiki/Facebook"
# 12790                                The Courier-Journal
# 12791  [http://www.latimes.com/world/la-fg-islamic-st...
# 12792                             /wiki/Amazon_(company)
# 12793   and other emergency supplies too high in Puer...
# 12794                                     4. In addition
# 12795                                      /wiki/Myanmar
# 12796                                              FALSE
# 12797                                      /wiki/Spain]"
# 12798                                              FALSE
# 12799                                    /wiki/Mogadishu
# 12800                                        /wiki/India
# 12801                                                NaN
# 12802                              /wiki/Iraqi_Kurdistan
# 12803            /wiki/Federal_Bureau_of_Investigation]"
# 12804          [/wiki/Henry_Bolton_(British_politician)"
# 12805  [http://www.cnn.com/2017/09/29/politics/tom-pr...
# 12806                                                NaN
# 12807                                                NaN
# 12808                       /wiki/Sun_Yat-sen_University
# 12809   a man drives into a police officer and then s...
# 12810                                    /wiki/Romania]"
# 12811                                     /wiki/Kinshasa
# 12812                                     [/wiki/Soccer"
# 12813                                /wiki/Rakhine_State
# 12814                    /wiki/Irish_embassy_in_London]"
# 12815                                     /wiki/Neo-Nazi
# 12816                       /wiki/Adelaide_Football_Club
#
#                                               Unnamed: 9  ...  \
# 0                                          /wiki/Yemen]"  ...
# 1                                             Calgary"]"  ...
# 2      [http://money.cnn.com/2014/12/31/news/economy/...  ...
# 3                                                    NaN  ...
# 4                                                    NaN  ...
# 5                                                 Russia  ...
# 6      [https://www.bloomberg.com/news/2015-01-07/gay...  ...
# 7                                                  FALSE  ...
# 8                                                  FALSE  ...
# 9                                       /wiki/Cameroon]"  ...
# 10                              [/wiki/Abu_Anas_al-Libi"  ...
# 11                                                   NaN  ...
# 12                                                 FALSE  ...
# 13                                                   NaN  ...
# 14                                              Istanbul  ...
# 15                                   Southampton Water]"  ...
# 16                                                Norway  ...
# 17     [https://www.bbc.co.uk/news/uk-scotland-north-...  ...
# 18                                             Euthanise  ...
# 19                             [/wiki/George_Papandreou"  ...
# 20                                                   NaN  ...
# 21                                                   NaN  ...
# 22     http://dailystar.com.lb/News/World/2015/Jan-04...  ...
# 23     [http://ca.reuters.com/article/topNews/idCAKBN...  ...
# 24                                         /wiki/Yemen]"  ...
# 25                                                 FALSE  ...
# 26                                                 FALSE  ...
# 27                                              Europe]"  ...
# 28                            Phil Taylor (darts player)  ...
# 29                                    /wiki/Greek_people  ...
# ...                                                  ...  ...
# 12787                                              FALSE  ...
# 12788                                 [/wiki/California"  ...
# 12789                                       /wiki/Google  ...
# 12790           that Pitino has been "effectively fired"  ...
# 12791                                                NaN  ...
# 12792                                 /wiki/Cybercrime]"  ...
# 12793                            [/wiki/Hurricane_Maria"  ...
# 12794     the entire population of Vanuatu's Aoba Island  ...
# 12795                                 /wiki/Bangladesh]"  ...
# 12796  [https://www.bloomberg.com/news/articles/2017-...  ...
# 12797                                              FALSE  ...
# 12798  [https://phys.org/news/2017-09-tsunami-enabled...  ...
# 12799                        /wiki/Somali_Armed_Forces]"  ...
# 12800                                     /wiki/Mumbai]"  ...
# 12801                                                NaN  ...
# 12802                  /wiki/Erbil_International_Airport  ...
# 12803                                              FALSE  ...
# 12804                                 /wiki/Paul_Nuttall  ...
# 12805                                                NaN  ...
# 12806                                                NaN  ...
# 12807                                                NaN  ...
# 12808                                 /wiki/Gene_therapy  ...
# 12809   where four pedestrians were hit by the suspec...  ...
# 12810                                              FALSE  ...
# 12811             /wiki/Democratic_Republic_of_the_Congo  ...
# 12812                          /wiki/Stade_de_la_Licorne  ...
# 12813                                      /wiki/Myanmar  ...
# 12814                                              FALSE  ...
# 12815                   /wiki/Nordic_Resistance_Movement  ...
# 12816                              /wiki/AFL_Grand_Final  ...
#
#       Nounphrases12807 Nounphrases12808 Nounphrases12809 Nounphrases12810  \
# 0           NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 1           NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 2           NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 3           NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 4           NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 5           NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 6           NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 7           NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 8           NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 9           NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 10          NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 11          NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12          NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 13          NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 14          NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 15          NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 16          NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 17          NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 18          NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 19          NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 20          NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 21          NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 22          NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 23          NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 24          NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 25          NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 26          NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 27          NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 28          NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 29          NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# ...                ...              ...              ...              ...
# 12787       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12788       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12789       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12790       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12791       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12792       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12793       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12794       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12795       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12796       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12797       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12798       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12799       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12800       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12801       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12802       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12803       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12804       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12805       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12806       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12807       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12808       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12809       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12810       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12811       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12812       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12813       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12814       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12815       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12816       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
#
#       Nounphrases12811 Nounphrases12812 Nounphrases12813 Nounphrases12814  \
# 0           NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 1           NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 2           NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 3           NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 4           NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 5           NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 6           NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 7           NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 8           NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 9           NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 10          NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 11          NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12          NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 13          NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 14          NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 15          NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 16          NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 17          NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 18          NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 19          NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 20          NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 21          NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 22          NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 23          NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 24          NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 25          NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 26          NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 27          NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 28          NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 29          NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# ...                ...              ...              ...              ...
# 12787       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12788       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12789       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12790       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12791       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12792       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12793       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12794       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12795       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12796       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12797       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12798       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12799       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12800       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12801       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12802       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12803       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12804       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12805       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12806       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12807       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12808       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12809       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12810       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12811       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12812       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12813       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12814       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12815       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
# 12816       NULL VALUE       NULL VALUE       NULL VALUE       NULL VALUE
#
#       Nounphrases12815 Nounphrases12816
# 0           NULL VALUE       NULL VALUE
# 1           NULL VALUE       NULL VALUE
# 2           NULL VALUE       NULL VALUE
# 3           NULL VALUE       NULL VALUE
# 4           NULL VALUE       NULL VALUE
# 5           NULL VALUE       NULL VALUE
# 6           NULL VALUE       NULL VALUE
# 7           NULL VALUE       NULL VALUE
# 8           NULL VALUE       NULL VALUE
# 9           NULL VALUE       NULL VALUE
# 10          NULL VALUE       NULL VALUE
# 11          NULL VALUE       NULL VALUE
# 12          NULL VALUE       NULL VALUE
# 13          NULL VALUE       NULL VALUE
# 14          NULL VALUE       NULL VALUE
# 15          NULL VALUE       NULL VALUE
# 16          NULL VALUE       NULL VALUE
# 17          NULL VALUE       NULL VALUE
# 18          NULL VALUE       NULL VALUE
# 19          NULL VALUE       NULL VALUE
# 20          NULL VALUE       NULL VALUE
# 21          NULL VALUE       NULL VALUE
# 22          NULL VALUE       NULL VALUE
# 23          NULL VALUE       NULL VALUE
# 24          NULL VALUE       NULL VALUE
# 25          NULL VALUE       NULL VALUE
# 26          NULL VALUE       NULL VALUE
# 27          NULL VALUE       NULL VALUE
# 28          NULL VALUE       NULL VALUE
# 29          NULL VALUE       NULL VALUE
# ...                ...              ...
# 12787       NULL VALUE       NULL VALUE
# 12788       NULL VALUE       NULL VALUE
# 12789       NULL VALUE       NULL VALUE
# 12790       NULL VALUE       NULL VALUE
# 12791       NULL VALUE       NULL VALUE
# 12792       NULL VALUE       NULL VALUE
# 12793       NULL VALUE       NULL VALUE
# 12794       NULL VALUE       NULL VALUE
# 12795       NULL VALUE       NULL VALUE
# 12796       NULL VALUE       NULL VALUE
# 12797       NULL VALUE       NULL VALUE
# 12798       NULL VALUE       NULL VALUE
# 12799       NULL VALUE       NULL VALUE
# 12800       NULL VALUE       NULL VALUE
# 12801       NULL VALUE       NULL VALUE
# 12802       NULL VALUE       NULL VALUE
# 12803       NULL VALUE       NULL VALUE
# 12804       NULL VALUE       NULL VALUE
# 12805       NULL VALUE       NULL VALUE
# 12806       NULL VALUE       NULL VALUE
# 12807       NULL VALUE       NULL VALUE
# 12808       NULL VALUE       NULL VALUE
# 12809       NULL VALUE       NULL VALUE
# 12810       NULL VALUE       NULL VALUE
# 12811       NULL VALUE       NULL VALUE
# 12812       NULL VALUE       NULL VALUE
# 12813       NULL VALUE       NULL VALUE
# 12814       NULL VALUE       NULL VALUE
# 12815       NULL VALUE       NULL VALUE
# 12816       NULL VALUE       NULL VALUE
#
# [12817 rows x 12876 columns]

# %%
df1=df

# %%
df1[['event_summary','Nounphrases0','Nounphrases1','Nounphrases2','Nounphrases3','Nounphrases4','Nounphrases5','Nounphrases6','Nounphrases7','Nounphrases8','Nounphrases9','Nounphrases10','Nounphrases11','Nounphrases12']]
# Out:
#                                            event_summary  \
# 0           The death toll of the suicide bombing in Ibb
# 1      A shooting kills one and injures six people in...
# 2      Lithuania adopts the euro as its official curr...
# 3      U.S. fast-food restaurant chain Chick-fil-A wa...
# 4      The Palestine Authority signs a treaty to join...
# 5             The Eurasian Economic Union between Russia
# 6            Vietnam’s new marriage law goes into effect
# 7                                            Mario Cuomo
# 8      Somali al-Shabaab militants attack an army bas...
# 9              Boko Haram militants attack a bus in Waza
# 10                                      Abu Anas al-Libi
# 11     The MS Norman Atlantic ferry fire death toll r...
# 12     The United States enacts more sanctions on Nor...
# 13     Fleeing villagers from a remote part of the Bo...
# 14     Turkey permits the building of a Syriac church...
# 15     The Singapore-registered cargo ship MV Höegh O...
# 16                                       MS Bulk Jupiter
# 17     The Cypriot-registered cargo ship Cemfjord sin...
# 18                                    A prison in Bruges
# 19                                      _January_2015"]"
# 20     A U.S. drone strike kills eight Uzbek people c...
# 21                                                   nan
# 22                                        /wiki/Al-Qaeda
# 23     A vehicle carrying United Nations peacekeepers...
# 24     A bombing at a local Houthi movement headquart...
# 25     A suicide car bomber detonates near a military...
# 26              A six-story building collapse in Nairobi
# 27     Pope Francis announces the appointment of 20 n...
# 28                                              In darts
# 29     A Libyan warplane bombs a Greek-operated oil t...
# ...                                                  ...
# 12787                                           _2017"]"
# 12788  California moves its 2020 presidential primary...
# 12789                                           Facebook
# 12790                       The University of Louisville
# 12791  The Islamic State of Iraq and the Levant relea...
# 12792                                 Whole Foods Market
# 12793                            /wiki/Hurricane_Maria]"
# 12794                                      More than 134
# 12795                        At least 14 Rohingya people
# 12796                                           _2017"]"
# 12797                                           _2017"]"
# 12798  Aquatic species from Japan hitched a ride on d...
# 12799  Al-Shabaab militants attack a military base ou...
# 12800  At least 22 people are killed and over 30 are ...
# 12801  A Mexico City borough president says previous ...
# 12802                                           _2017"]"
# 12803  The U.S. State Department removes all families...
# 12804                                           _2017"]"
# 12805  Tom Price resigns as the Secretary of Health a...
# 12806  Sun Zhengcai is expelled from the Communist Pa...
# 12807  /wiki/Central_Commission_for_Discipline_Inspec...
# 12808  The journal Protein & Cell publishes Sun Yat-s...
# 12809                                        In Edmonton
# 12810           A fire at a retirement home in Bucharest
# 12811  A military transport plane crashes after take-...
# 12812  A crowd surge collapses a barrier during a soc...
# 12813  /wiki/Rohingya_persecution_in_Myanmar_(2016%E2...
# 12814  Tens of thousands of protesters march through ...
# 12815  About 600 members of the Swedish neo-Nazi grou...
# 12816  The Australian rules football club Richmond Fo...
#
#                                             Nounphrases0  \
# 0      (NP  (NP (DT The) (NN death))  (NP    (NP (NN ...
# 1                              (NP (DT A) (NN shooting))
# 2                                   (NP (NNP Lithuania))
# 3      (NP  (NP (NNP U.S.) (NN fast-food) (NN restaur...
# 4      (NP  (NP    (NP (DT The) (NNP Palestine) (NNP ...
# 5      (NP (DT The) (JJ Eurasian) (NNP Economic) (NNP...
# 6      (NP (NP (NNP Vietnam) (POS 's)) (JJ new) (NN m...
# 7                           (NP (NNP Mario) (NNP Cuomo))
# 8       (NP (JJ Somali) (JJ al-Shabaab) (NNS militants))
# 9            (NP (NNP Boko) (NNP Haram) (NNS militants))
# 10               (NP (NNP Abu) (NNP Anas) (NNP al-Libi))
# 11     (NP  (NP (DT The) (NN MS) (NNP Norman) (NNP At...
# 12              (NP (DT The) (NNP United) (NNPS States))
# 13     (NP  (NP (VBG Fleeing) (NNS villagers))  (PP (...
# 14                                     (NP (NNP Turkey))
# 15     (NP  (DT The)  (JJ Singapore-registered)  (NN ...
# 16       (NP (NP (NN MS)) (NP (NNP Bulk) (NNP Jupiter)))
# 17     (NP  (DT The)  (JJ Cypriot-registered)  (NN ca...
# 18     (NP (NP (DT A) (NN prison)) (PP (IN in) (NP (N...
# 19                                        (NP (CD 2015))
# 20         (NP (DT A) (NNP U.S.) (NN drone) (NN strike))
# 21                                         (NP (NN nan))
# 22                         (NP (: /) (NN wiki/Al-Qaeda))
# 23     (NP  (NP (DT A) (NN vehicle))  (VP    (VBG car...
# 24     (NP  (NP    (NP (DT A) (NN bombing))    (PP   ...
# 25         (NP (DT A) (NN suicide) (NN car) (NN bomber))
# 26     (NP  (NP (DT A) (JJ six-story) (NN building)) ...
# 27                         (NP (NNP Pope) (NNP Francis))
# 28                                       (NP (NN darts))
# 29     (NP  (NP (DT A) (JJ Libyan) (NN warplane) (NNS...
# ...                                                  ...
# 12787                                     (NP (CD 2017))
# 12788                              (NP (NNP California))
# 12789                                (NP (NNP Facebook))
# 12790  (NP  (NP (DT The) (NNP University))  (PP (IN o...
# 12791  (NP  (NP (DT The) (JJ Islamic) (NN State))  (P...
# 12792  (NP (NP (JJ Whole)) (NP (NNP Foods) (NNP Marke...
# 12793  (NP  (NP (NN wiki/Hurricane) (CD _) (NNP Maria...
# 12794  (NP (NP (JJR More)) (PP (IN than) (NP (CD 134))))
# 12795  (NP (QP (IN At) (JJS least) (CD 14)) (JJ Rohin...
# 12796                                     (NP (CD 2017))
# 12797                                     (NP (CD 2017))
# 12798  (NP (NP (JJ Aquatic) (NNS species)) (PP (IN fr...
# 12799               (NP (JJ Al-Shabaab) (NNS militants))
# 12800  (NP (QP (IN At) (JJS least) (CD 22)) (NNS peop...
# 12801  (NP (DT A) (NNP Mexico) (NNP City) (NN borough...
# 12802                                     (NP (CD 2017))
# 12803  (NP (DT The) (NNP U.S.) (NNP State) (NNP Depar...
# 12804                                     (NP (CD 2017))
# 12805                         (NP (NNP Tom) (NNP Price))
# 12806                      (NP (NNP Sun) (NNP Zhengcai))
# 12807  (NP  (NP    (PRN (: /) (NP (NNP wiki/Central) ...
# 12808  (NP (NP (DT The) (NN journal) (NN Protein)) (C...
# 12809                                (NP (NNP Edmonton))
# 12810  (NP  (NP (DT A) (NN fire))  (PP    (IN at)    ...
# 12811  (NP  (NP (DT A) (JJ military) (NN transport)) ...
# 12812                  (NP (DT A) (NN crowd) (NN surge))
# 12813  (NP  (NP (NN wiki/Rohingya) (NN _) (NN persecu...
# 12814  (NP  (NP (NNS Tens))  (PP    (IN of)    (NP   ...
# 12815  (NP  (NP (CD 600) (NNS members))  (PP    (IN o...
# 12816  (NP  (NP (DT The) (JJ Australian) (NNS rules) ...
#
#                                             Nounphrases1  \
# 0                               (NP (DT The) (NN death))
# 1                                          (NP (CD one))
# 2      (NP  (NP (DT the) (NN euro))  (PP (IN as) (NP ...
# 3      (NP (NNP U.S.) (NN fast-food) (NN restaurant) ...
# 4      (NP  (NP (DT The) (NNP Palestine) (NNP Authori...
# 5                                      (NP (NNP Russia))
# 6                            (NP (NNP Vietnam) (POS 's))
# 7
# 8                       (NP (DT an) (NN army) (NN base))
# 9      (NP (NP (DT a) (NN bus)) (PP (IN in) (NP (NNP ...
# 10
# 11     (NP (DT The) (NN MS) (NNP Norman) (NNP Atlanti...
# 12     (NP  (NP (JJR more) (NNS sanctions))  (PP    (...
# 13                    (NP (VBG Fleeing) (NNS villagers))
# 14     (NP  (NP (DT the) (NN building))  (PP    (IN o...
# 15     (NP  (NP (NNP Bramble) (NNP Bank))  (PP    (IN...
# 16                                          (NP (NN MS))
# 17     (NP  (NP (DT the) (JJ northern) (NN coast))  (...
# 18                               (NP (DT A) (NN prison))
# 19
# 20               (NP (CD eight) (JJ Uzbek) (NNS people))
# 21
# 22
# 23                              (NP (DT A) (NN vehicle))
# 24     (NP  (NP (DT A) (NN bombing))  (PP    (IN at) ...
# 25     (NP  (NP (DT a) (JJ military) (NN convoy))  (P...
# 26              (NP (DT A) (JJ six-story) (NN building))
# 27     (NP  (NP (DT the) (NN appointment))  (PP (IN o...
# 28
# 29     (NP (DT A) (JJ Libyan) (NN warplane) (NNS bombs))
# ...                                                  ...
# 12787
# 12788  (NP  (NP    (PRP$ its)    (NP (ADJP (NP (CD 20...
# 12789
# 12790                     (NP (DT The) (NNP University))
# 12791              (NP (DT The) (JJ Islamic) (NN State))
# 12792                                    (NP (JJ Whole))
# 12793        (NP (NN wiki/Hurricane) (CD _) (NNP Maria))
# 12794                                    (NP (JJR More))
# 12795
# 12796
# 12797
# 12798                    (NP (JJ Aquatic) (NNS species))
# 12799  (NP  (NP (DT a) (JJ military) (NN base))  (PP ...
# 12800                             (NP (IN over) (CD 30))
# 12801  (NP  (NP (JJ previous) (NNS officials))  (VP  ...
# 12802
# 12803  (NP  (NP (DT all) (NNS families))  (PP    (IN ...
# 12804
# 12805  (NP  (NP (DT the) (NNP Secretary))  (PP    (IN...
# 12806  (NP  (NP (DT the) (NNP Communist) (NNP Party))...
# 12807  (NP  (PRN (: /) (NP (NNP wiki/Central) (NNP _)...
# 12808            (NP (DT The) (NN journal) (NN Protein))
# 12809
# 12810                              (NP (DT A) (NN fire))
# 12811           (NP (DT A) (JJ military) (NN transport))
# 12812                           (NP (DT a) (NN barrier))
# 12813  (NP (NN wiki/Rohingya) (NN _) (NN persecution)...
# 12814                                    (NP (NNS Tens))
# 12815                        (NP (CD 600) (NNS members))
# 12816  (NP (DT The) (JJ Australian) (NNS rules) (NN f...
#
#                                             Nounphrases2  \
# 0      (NP  (NP (NN toll))  (PP    (IN of)    (NP    ...
# 1      (NP (NP (CD six) (NNS people)) (PP (IN in) (NP...
# 2                                (NP (DT the) (NN euro))
# 3                                  (NP (NN Chick-fil-A))
# 4      (NP (DT The) (NNP Palestine) (NNP Authority) (...
# 5
# 6                                       (NP (NN effect))
# 7                                             NULL VALUE
# 8      (NP (NP (DT the) (NNS outskirts)) (PP (IN of) ...
# 9                                   (NP (DT a) (NN bus))
# 10                                            NULL VALUE
# 11                   (NP (NN fire) (NN death) (NN toll))
# 12                       (NP (JJR more) (NNS sanctions))
# 13                     (NP (DT a) (JJ remote) (NN part))
# 14                           (NP (DT the) (NN building))
# 15                         (NP (NNP Bramble) (NNP Bank))
# 16                         (NP (NNP Bulk) (NNP Jupiter))
# 17                (NP (DT the) (JJ northern) (NN coast))
# 18                                     (NP (NNP Bruges))
# 19                                            NULL VALUE
# 20                                   (NP (NNP al-Qaeda))
# 21                                            NULL VALUE
# 22                                            NULL VALUE
# 23     (NP (NNP United) (NNPS Nations) (NNS peacekeep...
# 24                              (NP (DT A) (NN bombing))
# 25                 (NP (DT a) (JJ military) (NN convoy))
# 26     (NP (NP (NN collapse)) (PP (IN in) (NP (NNP Na...
# 27                        (NP (DT the) (NN appointment))
# 28                                            NULL VALUE
# 29     (NP (DT a) (JJ Greek-operated) (NN oil) (NN ta...
# ...                                                  ...
# 12787                                         NULL VALUE
# 12788  (NP  (PRP$ its)  (NP (ADJP (NP (CD 2020)) (JJ ...
# 12789                                         NULL VALUE
# 12790                              (NP (NNP Louisville))
# 12791  (NP (NP (NNP Iraq)) (CC and) (NP (DT the) (NN ...
# 12792                      (NP (NNP Foods) (NNP Market))
# 12793
# 12794                                      (NP (CD 134))
# 12795                                         NULL VALUE
# 12796                                         NULL VALUE
# 12797                                         NULL VALUE
# 12798                                   (NP (NNP Japan))
# 12799                (NP (DT a) (JJ military) (NN base))
# 12800      (NP (DT a) (NN rush) (NN hour) (NN stampede))
# 12801                 (NP (JJ previous) (NNS officials))
# 12802                                         NULL VALUE
# 12803                       (NP (DT all) (NNS families))
# 12804                                         NULL VALUE
# 12805                      (NP (DT the) (NNP Secretary))
# 12806          (NP (DT the) (NNP Communist) (NNP Party))
# 12807                    (NP (NNP wiki/Central) (NNP _))
# 12808                                     (NP (NN Cell))
# 12809                                         NULL VALUE
# 12810  (NP  (NP (DT a) (NN retirement) (NN home))  (P...
# 12811  (NP  (NP (NN plane) (NNS crashes))  (PP    (IN...
# 12812  (NP  (NP (DT a) (NN soccer) (NN match))  (PP  ...
# 12813  (NP  (NP (NNP _) (NNP Myanmar) (NN _))  (PRN  ...
# 12814  (NP  (NP (NNS thousands))  (PP    (IN of)    (...
# 12815  (NP  (NP (DT the) (JJ Swedish) (JJ neo-Nazi) (...
# 12816      (NP (NNP Richmond) (NNP Football) (NNP Club))
#
#                                             Nounphrases3  \
# 0                                         (NP (NN toll))
# 1                             (NP (CD six) (NNS people))
# 2            (NP (PRP$ its) (JJ official) (NN currency))
# 3                  (NP (DT a) (NN security) (NN breach))
# 4                                (NP (DT a) (NN treaty))
# 5                                             NULL VALUE
# 6
# 7                                             NULL VALUE
# 8                          (NP (DT the) (NNS outskirts))
# 9                                        (NP (NNP Waza))
# 10                                            NULL VALUE
# 11     (NP  (NP (ADVP (IN at) (JJS least)) (NNS eleve...
# 12     (NP (NP (NNP North) (NNP Korea)) (PP (IN in) (...
# 13     (NP  (NP (DT the) (NNP Borno) (NNP State) (NN ...
# 14     (NP  (NP (DT a) (JJ Syriac) (NN church))  (PP ...
# 15     (NP  (NP (DT the) (NN coast))  (PP    (IN of) ...
# 16
# 17     (NP  (NP (NNP Scotland))  (VP    (VBG leaving)...
# 18
# 19                                            NULL VALUE
# 20                                   (NP (NNP Pakistan))
# 21                                            NULL VALUE
# 22                                            NULL VALUE
# 23     (NP  (NP (DT a) (NN roadside) (NN bomb))  (PP ...
# 24     (NP (DT a) (JJ local) (NNP Houthi) (NN movemen...
# 25                                  (NP (NNP Mogadishu))
# 26                                    (NP (NN collapse))
# 27         (NP (ADJP (CD 20) (JJ new)) (NNPS Cardinals))
# 28                                            NULL VALUE
# 29     (NP (NP (DT the) (NN city)) (PP (IN of) (NP (N...
# ...                                                  ...
# 12787                                         NULL VALUE
# 12788  (NP (ADJP (NP (CD 2020)) (JJ presidential)) (J...
# 12789                                         NULL VALUE
# 12790
# 12791                                    (NP (NNP Iraq))
# 12792
# 12793                                         NULL VALUE
# 12794
# 12795                                         NULL VALUE
# 12796                                         NULL VALUE
# 12797                                         NULL VALUE
# 12798                              (NP (DT a) (NN ride))
# 12799  (NP (DT the) (JJ Somalian) (NN capital) (NNP M...
# 12800  (NP  (NP (DT a) (NN footbridge))  (PP    (IN b...
# 12801  (NP  (NP (NNS warnings))  (SBAR    (WHNP (WDT ...
# 12802                                         NULL VALUE
# 12803  (NP  (NP (NNS employees))  (CC and)  (NP (JJ n...
# 12804                                         NULL VALUE
# 12805  (NP (UCP (NNP Health) (CC and) (NNP Human)) (N...
# 12806                                   (NP (NNP China))
# 12807  (NP (NNP _) (NNP Discipline) (NNP _) (NNP Insp...
# 12808  (NP  (NP (NNP Sun) (NNP Yat-sen) (NNP Universi...
# 12809                                         NULL VALUE
# 12810              (NP (DT a) (NN retirement) (NN home))
# 12811                      (NP (NN plane) (NNS crashes))
# 12812                 (NP (DT a) (NN soccer) (NN match))
# 12813                  (NP (NNP _) (NNP Myanmar) (NN _))
# 12814                               (NP (NNS thousands))
# 12815  (NP (DT the) (JJ Swedish) (JJ neo-Nazi) (NN gr...
# 12816  (NP  (NP (DT the) (NNP Adelaide) (NNP Football...
#
#                                             Nounphrases4  \
# 0      (NP  (NP (DT the) (NN suicide) (NN bombing))  ...
# 1                                   (NP (NNP Killarney))
# 2
# 3      (NP  (NP (NN credit) (NN card) (NNS details)) ...
# 4      (NP (DT the) (NNP International) (NNP Criminal...
# 5                                             NULL VALUE
# 6                                             NULL VALUE
# 7                                             NULL VALUE
# 8                                      (NP (NNP Baidoa))
# 9
# 10                                            NULL VALUE
# 11          (NP (ADVP (IN at) (JJS least)) (NNS eleven))
# 12                          (NP (NNP North) (NNP Korea))
# 13     (NP (DT the) (NNP Borno) (NNP State) (NN report))
# 14                   (NP (DT a) (JJ Syriac) (NN church))
# 15                              (NP (DT the) (NN coast))
# 16                                            NULL VALUE
# 17                                   (NP (NNP Scotland))
# 18                                            NULL VALUE
# 19                                            NULL VALUE
# 20
# 21                                            NULL VALUE
# 22                                            NULL VALUE
# 23                   (NP (DT a) (NN roadside) (NN bomb))
# 24                   (NP (NNP Dhamar) (NNP Governorate))
# 25
# 26                                    (NP (NNP Nairobi))
# 27
# 28                                            NULL VALUE
# 29                               (NP (DT the) (NN city))
# ...                                                  ...
# 12787                                         NULL VALUE
# 12788                                     (NP (CD 2020))
# 12789                                         NULL VALUE
# 12790                                         NULL VALUE
# 12791                          (NP (DT the) (NN Levant))
# 12792                                         NULL VALUE
# 12793                                         NULL VALUE
# 12794                                         NULL VALUE
# 12795                                         NULL VALUE
# 12796                                         NULL VALUE
# 12797                                         NULL VALUE
# 12798                                   (NP (NN debris))
# 12799
# 12800                        (NP (DT a) (NN footbridge))
# 12801                                (NP (NNS warnings))
# 12802                                         NULL VALUE
# 12803                               (NP (NNS employees))
# 12804                                         NULL VALUE
# 12805  (NP  (NP (DT the) (NN midst))  (PP    (IN of) ...
# 12806  (NP  (NP (DT the) (NNS results))  (PP    (IN i...
# 12807
# 12808  (NP (NNP Sun) (NNP Yat-sen) (NNP University) (...
# 12809                                         NULL VALUE
# 12810                               (NP (NNP Bucharest))
# 12811  (NP  (NP (NN take-off))  (PP    (IN from)    (...
# 12812  (NP  (NNP Stade)  (NP    (NP (FW de) (FW la) (...
# 12813       (NP (NP (CD 2016)) (: --) (NP (JJ present)))
# 12814  (NP  (NNS protesters)  (S    (VP      (VB marc...
# 12815    (NP (JJ Nordic) (NN Resistance) (NNP Movement))
# 12816  (NP (DT the) (NNP Adelaide) (NNP Football) (NN...
#
#                                             Nounphrases5  \
# 0                (NP (DT the) (NN suicide) (NN bombing))
# 1
# 2                                             NULL VALUE
# 3               (NP (NN credit) (NN card) (NNS details))
# 4
# 5                                             NULL VALUE
# 6                                             NULL VALUE
# 7                                             NULL VALUE
# 8
# 9                                             NULL VALUE
# 10                                            NULL VALUE
# 11     (NP  (NP (QP (RB as) (JJ many) (IN as) (CD 19)...
# 12                                    (NP (NN response))
# 13                           (NP (NNP Boko) (NNP Haram))
# 14                                   (NP (NNP Istanbul))
# 15     (NP (NP (DT the) (NNP Isle)) (PP (IN of) (NP (...
# 16                                            NULL VALUE
# 17     (NP (NP (CD eight)) (ADJP (JJ onboard) (VBG mi...
# 18                                            NULL VALUE
# 19                                            NULL VALUE
# 20                                            NULL VALUE
# 21                                            NULL VALUE
# 22                                            NULL VALUE
# 23                         (NP (JJ northern) (NNS Mali))
# 24
# 25                                            NULL VALUE
# 26
# 27                                            NULL VALUE
# 28                                            NULL VALUE
# 29                                      (NP (NNP Derna))
# ...                                                  ...
# 12787                                         NULL VALUE
# 12788                            (NP (NNP March) (CD 3))
# 12789                                         NULL VALUE
# 12790                                         NULL VALUE
# 12791  (NP  (NP (NN footage))  (SBAR    (WHNP (WDT wh...
# 12792                                         NULL VALUE
# 12793                                         NULL VALUE
# 12794                                         NULL VALUE
# 12795                                         NULL VALUE
# 12796                                         NULL VALUE
# 12797                                         NULL VALUE
# 12798  (NP  (NP (DT the) (CD 2011) (NNP Tōhoku) (NN e...
# 12799                                         NULL VALUE
# 12800  (NP  (DT the)  (NNP Parel)  (CC and)  (NNP Elp...
# 12801  (NP (JJ unauthorized) (NN construction) (NN wo...
# 12802                                         NULL VALUE
# 12803             (NP (JJ nonessential) (NNS personnel))
# 12804                                         NULL VALUE
# 12805                           (NP (DT the) (NN midst))
# 12806                        (NP (DT the) (NNS results))
# 12807                                         NULL VALUE
# 12808  (NP (NP (DT the) (NN use)) (PP (IN of) (NP (NN...
# 12809                                         NULL VALUE
# 12810
# 12811                                 (NP (NN take-off))
# 12812  (NP (NP (FW de) (FW la) (FW Licorne)) (PP (IN ...
# 12813                                     (NP (CD 2016))
# 12814                                  (NP (NNP Dublin))
# 12815                              (NP (NNP Gothenburg))
# 12816  (NP (DT the) (CD 2017) (NNP AFL) (NNP Grand) (...
#
#                                             Nounphrases6  \
# 0                                         (NP (NNP Ibb))
# 1                                             NULL VALUE
# 2                                             NULL VALUE
# 3                                            (NP (CD 9))
# 4                                             NULL VALUE
# 5                                             NULL VALUE
# 6                                             NULL VALUE
# 7                                             NULL VALUE
# 8                                             NULL VALUE
# 9                                             NULL VALUE
# 10                                            NULL VALUE
# 11     (NP (QP (RB as) (JJ many) (IN as) (CD 19)) (NN...
# 12     (NP  (NP (PRP$ their) (JJ alleged) (NN involve...
# 13                            (NP (CD three) (NNS days))
# 14
# 15                              (NP (DT the) (NNP Isle))
# 16                                            NULL VALUE
# 17                                       (NP (CD eight))
# 18                                            NULL VALUE
# 19                                            NULL VALUE
# 20                                            NULL VALUE
# 21                                            NULL VALUE
# 22                                            NULL VALUE
# 23
# 24                                            NULL VALUE
# 25                                            NULL VALUE
# 26                                            NULL VALUE
# 27                                            NULL VALUE
# 28                                            NULL VALUE
# 29
# ...                                                  ...
# 12787                                         NULL VALUE
# 12788
# 12789                                         NULL VALUE
# 12790                                         NULL VALUE
# 12791                                  (NP (NN footage))
# 12792                                         NULL VALUE
# 12793                                         NULL VALUE
# 12794                                         NULL VALUE
# 12795                                         NULL VALUE
# 12796                                         NULL VALUE
# 12797                                         NULL VALUE
# 12798  (NP (DT the) (CD 2011) (NNP Tōhoku) (NN earthq...
# 12799                                         NULL VALUE
# 12800  (NP  (NP (DT the) (JJ Indian) (NN city))  (PP ...
# 12801  (NP  (NP (DT the) (JJ structural) (NN integrit...
# 12802                                         NULL VALUE
# 12803  (NP  (NP (NNP Cuba))  (PP    (VBG following)  ...
# 12804                                         NULL VALUE
# 12805  (NP  (NP (DT a) (NN scandal))  (PP    (IN over...
# 12806  (NP (DT the) (JJ internal) (JJ disciplinary) (...
# 12807                                         NULL VALUE
# 12808                             (NP (DT the) (NN use))
# 12809                                         NULL VALUE
# 12810                                         NULL VALUE
# 12811  (NP  (NP (NNP N'djili) (NNP Airport))  (PP (IN...
# 12812                  (NP (FW de) (FW la) (FW Licorne))
# 12813                                  (NP (JJ present))
# 12814                                 (NP (NNP Ireland))
# 12815
# 12816  (NP (NP (CD 108) (NNS points)) (PP (TO to) (NP...
#
#                                             Nounphrases7  \
# 0
# 1                                             NULL VALUE
# 2                                             NULL VALUE
# 3
# 4                                             NULL VALUE
# 5                                             NULL VALUE
# 6                                             NULL VALUE
# 7                                             NULL VALUE
# 8                                             NULL VALUE
# 9                                             NULL VALUE
# 10                                            NULL VALUE
# 11
# 12       (NP (PRP$ their) (JJ alleged) (NN involvement))
# 13     (NP (NP (CD 40) (NNS boys)) (CC and) (NP (JJ y...
# 14                                            NULL VALUE
# 15                                      (NP (NNP Wight))
# 16                                            NULL VALUE
# 17
# 18                                            NULL VALUE
# 19                                            NULL VALUE
# 20                                            NULL VALUE
# 21                                            NULL VALUE
# 22                                            NULL VALUE
# 23                                            NULL VALUE
# 24                                            NULL VALUE
# 25                                            NULL VALUE
# 26                                            NULL VALUE
# 27                                            NULL VALUE
# 28                                            NULL VALUE
# 29                                            NULL VALUE
# ...                                                  ...
# 12787                                         NULL VALUE
# 12788                                         NULL VALUE
# 12789                                         NULL VALUE
# 12790                                         NULL VALUE
# 12791                        (NP (PRP$ its) (NN leader))
# 12792                                         NULL VALUE
# 12793                                         NULL VALUE
# 12794                                         NULL VALUE
# 12795                                         NULL VALUE
# 12796                                         NULL VALUE
# 12797                                         NULL VALUE
# 12798                                  (NP (NN tsunami))
# 12799                                         NULL VALUE
# 12800                (NP (DT the) (JJ Indian) (NN city))
# 12801       (NP (DT the) (JJ structural) (NN integrity))
# 12802                                         NULL VALUE
# 12803                                    (NP (NNP Cuba))
# 12804                                         NULL VALUE
# 12805                           (NP (DT a) (NN scandal))
# 12806  (NP  (NP (DT the) (NNP Central) (NNP Commissio...
# 12807                                         NULL VALUE
# 12808                        (NP (NN gene) (NN therapy))
# 12809                                         NULL VALUE
# 12810                                         NULL VALUE
# 12811                   (NP (NNP N'djili) (NNP Airport))
# 12812                                  (NP (NNP Amiens))
# 12813
# 12814           (NP (PRP$ its) (NN abortion) (NNS laws))
# 12815                                         NULL VALUE
# 12816                         (NP (CD 108) (NNS points))
#
#                                             Nounphrases8  \
# 0                                             NULL VALUE
# 1                                             NULL VALUE
# 2                                             NULL VALUE
# 3                                             NULL VALUE
# 4                                             NULL VALUE
# 5                                             NULL VALUE
# 6                                             NULL VALUE
# 7                                             NULL VALUE
# 8                                             NULL VALUE
# 9                                             NULL VALUE
# 10                                            NULL VALUE
# 11                                            NULL VALUE
# 12     (NP  (NP (DT the) (NN hacking) (NN attack))  (...
# 13                               (NP (CD 40) (NNS boys))
# 14                                            NULL VALUE
# 15
# 16                                            NULL VALUE
# 17                                            NULL VALUE
# 18                                            NULL VALUE
# 19                                            NULL VALUE
# 20                                            NULL VALUE
# 21                                            NULL VALUE
# 22                                            NULL VALUE
# 23                                            NULL VALUE
# 24                                            NULL VALUE
# 25                                            NULL VALUE
# 26                                            NULL VALUE
# 27                                            NULL VALUE
# 28                                            NULL VALUE
# 29                                            NULL VALUE
# ...                                                  ...
# 12787                                         NULL VALUE
# 12788                                         NULL VALUE
# 12789                                         NULL VALUE
# 12790                                         NULL VALUE
# 12791  (NP  (NP (NNP Abu) (NNP Bakr) (NNP al-Baghdadi...
# 12792                                         NULL VALUE
# 12793                                         NULL VALUE
# 12794                                         NULL VALUE
# 12795                                         NULL VALUE
# 12796                                         NULL VALUE
# 12797                                         NULL VALUE
# 12798  (NP  (NP (DT the) (NNP West) (NNP Coast))  (PP...
# 12799                                         NULL VALUE
# 12800                                  (NP (NNP Mumbai))
# 12801                  (NP (JJ several) (NNS buildings))
# 12802                                         NULL VALUE
# 12803  (NP  (NP (JJ apparent) (JJ sonic) (NNS attacks...
# 12804                                         NULL VALUE
# 12805  (NP  (NP (PRP$ his) (NN use))  (PP (IN of) (NP...
# 12806       (NP (DT the) (NNP Central) (NNP Commission))
# 12807                                         NULL VALUE
# 12808  (NP  (NP (DT the) (NN removal))  (PP    (IN of...
# 12809                                         NULL VALUE
# 12810                                         NULL VALUE
# 12811                                (NP (NNP Kinshasa))
# 12812
# 12813                                         NULL VALUE
# 12814
# 12815                                         NULL VALUE
# 12816                                       (NP (CD 60))
#
#                                       Nounphrases9  \
# 0                                       NULL VALUE
# 1                                       NULL VALUE
# 2                                       NULL VALUE
# 3                                       NULL VALUE
# 4                                       NULL VALUE
# 5                                       NULL VALUE
# 6                                       NULL VALUE
# 7                                       NULL VALUE
# 8                                       NULL VALUE
# 9                                       NULL VALUE
# 10                                      NULL VALUE
# 11                                      NULL VALUE
# 12          (NP (DT the) (NN hacking) (NN attack))
# 13                       (NP (JJ young) (NNS men))
# 14                                      NULL VALUE
# 15                                      NULL VALUE
# 16                                      NULL VALUE
# 17                                      NULL VALUE
# 18                                      NULL VALUE
# 19                                      NULL VALUE
# 20                                      NULL VALUE
# 21                                      NULL VALUE
# 22                                      NULL VALUE
# 23                                      NULL VALUE
# 24                                      NULL VALUE
# 25                                      NULL VALUE
# 26                                      NULL VALUE
# 27                                      NULL VALUE
# 28                                      NULL VALUE
# 29                                      NULL VALUE
# ...                                            ...
# 12787                                   NULL VALUE
# 12788                                   NULL VALUE
# 12789                                   NULL VALUE
# 12790                                   NULL VALUE
# 12791  (NP (NNP Abu) (NNP Bakr) (NNP al-Baghdadi))
# 12792                                   NULL VALUE
# 12793                                   NULL VALUE
# 12794                                   NULL VALUE
# 12795                                   NULL VALUE
# 12796                                   NULL VALUE
# 12797                                   NULL VALUE
# 12798         (NP (DT the) (NNP West) (NNP Coast))
# 12799                                   NULL VALUE
# 12800
# 12801                      (NP (DT the) (NN city))
# 12802                                   NULL VALUE
# 12803  (NP (JJ apparent) (JJ sonic) (NNS attacks))
# 12804                                   NULL VALUE
# 12805                     (NP (PRP$ his) (NN use))
# 12806       (NP (NNP Discipline) (NNP Inspection))
# 12807                                   NULL VALUE
# 12808                   (NP (DT the) (NN removal))
# 12809                                   NULL VALUE
# 12810                                   NULL VALUE
# 12811
# 12812                                   NULL VALUE
# 12813                                   NULL VALUE
# 12814                                   NULL VALUE
# 12815                                   NULL VALUE
# 12816
#
#                                            Nounphrases10  \
# 0                                             NULL VALUE
# 1                                             NULL VALUE
# 2                                             NULL VALUE
# 3                                             NULL VALUE
# 4                                             NULL VALUE
# 5                                             NULL VALUE
# 6                                             NULL VALUE
# 7                                             NULL VALUE
# 8                                             NULL VALUE
# 9                                             NULL VALUE
# 10                                            NULL VALUE
# 11                                            NULL VALUE
# 12                                       (NP (NNP Sony))
# 13
# 14                                            NULL VALUE
# 15                                            NULL VALUE
# 16                                            NULL VALUE
# 17                                            NULL VALUE
# 18                                            NULL VALUE
# 19                                            NULL VALUE
# 20                                            NULL VALUE
# 21                                            NULL VALUE
# 22                                            NULL VALUE
# 23                                            NULL VALUE
# 24                                            NULL VALUE
# 25                                            NULL VALUE
# 26                                            NULL VALUE
# 27                                            NULL VALUE
# 28                                            NULL VALUE
# 29                                            NULL VALUE
# ...                                                  ...
# 12787                                         NULL VALUE
# 12788                                         NULL VALUE
# 12789                                         NULL VALUE
# 12790                                         NULL VALUE
# 12791                    (NP (PRP$ his) (NNS followers))
# 12792                                         NULL VALUE
# 12793                                         NULL VALUE
# 12794                                         NULL VALUE
# 12795                                         NULL VALUE
# 12796                                         NULL VALUE
# 12797                                         NULL VALUE
# 12798           (NP (DT the) (NNP United) (NNPS States))
# 12799                                         NULL VALUE
# 12800                                         NULL VALUE
# 12801
# 12802                                         NULL VALUE
# 12803                       (NP (CD 21) (NNS personnel))
# 12804                                         NULL VALUE
# 12805                     (NP (JJ private) (NNS planes))
# 12806
# 12807                                         NULL VALUE
# 12808  (NP  (NP (DT a) (NN version))  (PP    (IN of) ...
# 12809                                         NULL VALUE
# 12810                                         NULL VALUE
# 12811                                         NULL VALUE
# 12812                                         NULL VALUE
# 12813                                         NULL VALUE
# 12814                                         NULL VALUE
# 12815                                         NULL VALUE
# 12816                                         NULL VALUE
#
#                          Nounphrases11  \
# 0                           NULL VALUE
# 1                           NULL VALUE
# 2                           NULL VALUE
# 3                           NULL VALUE
# 4                           NULL VALUE
# 5                           NULL VALUE
# 6                           NULL VALUE
# 7                           NULL VALUE
# 8                           NULL VALUE
# 9                           NULL VALUE
# 10                          NULL VALUE
# 11                          NULL VALUE
# 12
# 13                          NULL VALUE
# 14                          NULL VALUE
# 15                          NULL VALUE
# 16                          NULL VALUE
# 17                          NULL VALUE
# 18                          NULL VALUE
# 19                          NULL VALUE
# 20                          NULL VALUE
# 21                          NULL VALUE
# 22                          NULL VALUE
# 23                          NULL VALUE
# 24                          NULL VALUE
# 25                          NULL VALUE
# 26                          NULL VALUE
# 27                          NULL VALUE
# 28                          NULL VALUE
# 29                          NULL VALUE
# ...                                ...
# 12787                       NULL VALUE
# 12788                       NULL VALUE
# 12789                       NULL VALUE
# 12790                       NULL VALUE
# 12791  (NP (PRP$ their) (NNS attacks))
# 12792                       NULL VALUE
# 12793                       NULL VALUE
# 12794                       NULL VALUE
# 12795                       NULL VALUE
# 12796                       NULL VALUE
# 12797                       NULL VALUE
# 12798
# 12799                       NULL VALUE
# 12800                       NULL VALUE
# 12801                       NULL VALUE
# 12802                       NULL VALUE
# 12803        (NP (DT the) (NN island))
# 12804                       NULL VALUE
# 12805
# 12806                       NULL VALUE
# 12807                       NULL VALUE
# 12808         (NP (DT a) (NN version))
# 12809                       NULL VALUE
# 12810                       NULL VALUE
# 12811                       NULL VALUE
# 12812                       NULL VALUE
# 12813                       NULL VALUE
# 12814                       NULL VALUE
# 12815                       NULL VALUE
# 12816                       NULL VALUE
#
#                                            Nounphrases12
# 0                                             NULL VALUE
# 1                                             NULL VALUE
# 2                                             NULL VALUE
# 3                                             NULL VALUE
# 4                                             NULL VALUE
# 5                                             NULL VALUE
# 6                                             NULL VALUE
# 7                                             NULL VALUE
# 8                                             NULL VALUE
# 9                                             NULL VALUE
# 10                                            NULL VALUE
# 11                                            NULL VALUE
# 12                                            NULL VALUE
# 13                                            NULL VALUE
# 14                                            NULL VALUE
# 15                                            NULL VALUE
# 16                                            NULL VALUE
# 17                                            NULL VALUE
# 18                                            NULL VALUE
# 19                                            NULL VALUE
# 20                                            NULL VALUE
# 21                                            NULL VALUE
# 22                                            NULL VALUE
# 23                                            NULL VALUE
# 24                                            NULL VALUE
# 25                                            NULL VALUE
# 26                                            NULL VALUE
# 27                                            NULL VALUE
# 28                                            NULL VALUE
# 29                                            NULL VALUE
# ...                                                  ...
# 12787                                         NULL VALUE
# 12788                                         NULL VALUE
# 12789                                         NULL VALUE
# 12790                                         NULL VALUE
# 12791      (NP (NNS crusaders) (CC and) (NNS apostates))
# 12792                                         NULL VALUE
# 12793                                         NULL VALUE
# 12794                                         NULL VALUE
# 12795                                         NULL VALUE
# 12796                                         NULL VALUE
# 12797                                         NULL VALUE
# 12798                                         NULL VALUE
# 12799                                         NULL VALUE
# 12800                                         NULL VALUE
# 12801                                         NULL VALUE
# 12802                                         NULL VALUE
# 12803
# 12804                                         NULL VALUE
# 12805                                         NULL VALUE
# 12806                                         NULL VALUE
# 12807                                         NULL VALUE
# 12808  (NP  (NP    (DT the)    (VBN inherited)    (NN...
# 12809                                         NULL VALUE
# 12810                                         NULL VALUE
# 12811                                         NULL VALUE
# 12812                                         NULL VALUE
# 12813                                         NULL VALUE
# 12814                                         NULL VALUE
# 12815                                         NULL VALUE
# 12816                                         NULL VALUE
#
# [12817 rows x 14 columns]
