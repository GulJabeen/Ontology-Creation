# %%
# %load_ext autoreload
# %autoreload 2
#Reload all modules (except those excluded by %aimport) automatically now.

# %%
import pandas as pd
import spacy
from spacy.displacy.render import EntityRenderer
from IPython.core.display import display, HTML
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt
import random

# %%
def custom_render(doc, df, column, options={}, page=False, minify=False, idx=0):
    """Overload the spaCy built-in rendering to allow custom part-of-speech (POS) tags.
    
    Keyword arguments:
    doc -- a spaCy nlp doc object
    df -- a pandas dataframe object
    column -- the name of of a column of interest in the dataframe
    options -- various options to feed into the spaCy renderer, including colors
    page -- rendering markup as full HTML page (default False)
    minify -- for compact HTML (default False)
    idx -- index for specific query or doc in dataframe (default 0)
    
    """
    renderer, converter = EntityRenderer, parse_custom_ents
    renderer = renderer(options=options)
    parsed = [converter(doc, df=df, idx=idx, column=column)]
    html = renderer.render(parsed, page=page, minify=minify).strip()  
    return display(HTML(html))

def parse_custom_ents(doc, df, idx, column):
    """Parse custom entity types that aren't in the original spaCy module.
    
    Keyword arguments:
    doc -- a spaCy nlp doc object
    df -- a pandas dataframe object
    idx -- index for specific query or doc in dataframe
    column -- the name of of a column of interest in the dataframe
    
    """
    if column in df.columns:
        entities = df[column][idx]
        ents = [{'start': ent[1], 'end': ent[2], 'label': ent[3]} 
                for ent in entities]
    else:
        ents = [{'start': ent.start_char, 'end': ent.end_char, 'label': ent.label_}
            for ent in doc.ents]
    return {'text': doc.text, 'ents': ents, 'title': None}

def render_entities(idx, df, options={}, column='named_ents'):
    """A wrapper function to get text from a dataframe and render it visually in jupyter notebooks
    
    Keyword arguments:
    idx -- index for specific query or doc in dataframe (default 0)
    df -- a pandas dataframe object
    options -- various options to feed into the spaCy renderer, including colors
    column -- the name of of a column of interest in the dataframe (default 'named_ents')
    
    """
    text = df['event_summary'][idx]
    custom_render(nlp(text), df=df, column=column, options=options, idx=idx)

# %%
options = {
    'colors': {'COMPOUND': '#FE6BFE', 'PROPN': '#18CFE6', 'NOUN': '#18CFE6', 'NP': '#1EECA6', 'ENTITY': '#FF8800'}
}

# %%
pd.set_option('display.max_rows', 10) # edit how jupyter will render our pandas dataframes
pd.options.mode.chained_assignment = None # prevent warning about working on a copy of a dataframe

# %%
import csv
import sys, os, json, re, time
import subprocess

# %%
#file = './nips-2015-papers/Papers.csv'
#file = '/uci-news-aggregator.csv'
df = pd.read_csv('newsdataset1.csv')
df.event_summary=df.event_summary.astype(str)

# %%
df.describe()
# Out:
#                                                       _id  \
# count                                               12817
# unique                                              12814
# top     According to the Syrian Observatory for Human ...
# freq                                                    2
#
#                               date                     category event_title  \
# count                        12701                        12636       12601
# unique                        1869                          853        3259
# top     2016-04-22T00:00:00.000Z""  Armed conflicts and attacks       FALSE
# freq                            32                         2309        5216
#
#        event_summary entities person external_link Unnamed: 8 Unnamed: 9  ...  \
# count          12817    12299  12042         11786      11181       9783  ...
# unique         11220    10017   9611          8658       7958       6994  ...
# top         _2016"]"    FALSE  FALSE         FALSE      FALSE      FALSE  ...
# freq             311      123    572          1452       1879       1798  ...
#
#           Unnamed: 49    Unnamed: 50  \
# count               2              2
# unique              2              2
# top     /wiki/Holland  /wiki/Belgium
# freq                1              1
#
#                                               Unnamed: 51  \
# count                                                   2
# unique                                                  2
# top     http://www.msn.com/en-us/news/politics/media-s...
# freq                                                    1
#
#                      Unnamed: 52   Unnamed: 53     Unnamed: 54 Unnamed: 55  \
# count                          1             1               1           1
# unique                         1             1               1           1
# top     /wiki/State_of_Palestine  /wiki/Turkey  /wiki/Greece]"       False
# freq                           1             1               1           1
#
#                                               Unnamed: 56  \
# count                                                   1
# unique                                                  1
# top     [https://www.independent.co.uk/news/world/euro...
# freq                                                    1
#
#                                               Unnamed: 57  \
# count                                                   1
# unique                                                  1
# top     http://www.euronews.com/2016/03/20/at-least-14...
# freq                                                    1
#
#                                               Unnamed: 58
# count                                                   1
# unique                                                  1
# top     https://www.bloomberg.com/news/articles/2016-0...
# freq                                                    1
#
# [4 rows x 59 columns]

# %%
df.dropna(axis=0, how='any', thresh=None, subset=None, inplace=False)
# Out:
#                                        _id                        date  \
# 6014  ObjectId("5d056c69b5f3a01b25e87549")  2016-03-20T00:00:00.000Z""
#
#                      category                  event_title  \
# 6014  Disasters and accidents  [/wiki/Erasmus_bus_crash"]"
#
#                                           event_summary  \
# 6014  Thirteen are killed and 34 others injured afte...
#
#                      entities  \
# 6014   crashes near Freginals
#
#                                                  person  \
# 6014   Spain. The regional government of Catalonia s...
#
#                            external_link  \
# 6014   "... according to the latest data
#
#                                         Unnamed: 8 Unnamed: 9  ...  \
# 6014   the ill-fated bus had students from Hungary    Germany  ...
#
#         Unnamed: 49    Unnamed: 50   Unnamed: 51               Unnamed: 52  \
# 6014  /wiki/Holland  /wiki/Belgium  /wiki/France  /wiki/State_of_Palestine
#
#        Unnamed: 53     Unnamed: 54 Unnamed: 55  \
# 6014  /wiki/Turkey  /wiki/Greece]"       False
#
#                                             Unnamed: 56  \
# 6014  [https://www.independent.co.uk/news/world/euro...
#
#                                             Unnamed: 57  \
# 6014  http://www.euronews.com/2016/03/20/at-least-14...
#
#                                             Unnamed: 58
# 6014  https://www.bloomberg.com/news/articles/2016-0...
#
# [1 rows x 59 columns]

# %%
mini_df = df[:10]
mini_df.index = pd.RangeIndex(len(mini_df.index))

# comment this out to run on full dataset
df = mini_df

# %%
lower = lambda x: x.lower() # make everything lowercase

# %%
df = pd.DataFrame(df['event_summary'].apply(lower))
df.columns = ['event_summary']
display(df)
# Out:
#                                        event_summary
# 0       the death toll of the suicide bombing in ibb
# 1  a shooting kills one and injures six people in...
# 2  lithuania adopts the euro as its official curr...
# 3  u.s. fast-food restaurant chain chick-fil-a wa...
# 4  the palestine authority signs a treaty to join...
# 5         the eurasian economic union between russia
# 6        vietnam’s new marriage law goes into effect
# 7                                        mario cuomo
# 8  somali al-shabaab militants attack an army bas...
# 9          boko haram militants attack a bus in waza

# %%
 import spacy

# %%
nlp = spacy.load("en_core_web_sm")

# %%
def extract_named_ents(text):
    """Extract named entities, and beginning, middle and end idx using spaCy's out-of-the-box model. 
    
    Keyword arguments:
    text -- the actual text source from which to extract entities
    
    """
    return [(ent.text, ent.start_char, ent.end_char, ent.label_) for ent in nlp(text).ents]

def add_named_ents(df):
    """Create new column in data frame with named entity tuple extracted.
    
    Keyword arguments:
    df -- a dataframe object
    
    """
    df['named_ents'] = df['event_summary'].apply(extract_named_ents)

# %%
add_named_ents(df)

# %%
df['event_summary'].count()
# Out:
# 10

# %%
df
# Out:
#                                        event_summary  \
# 0       the death toll of the suicide bombing in ibb
# 1  a shooting kills one and injures six people in...
# 2  lithuania adopts the euro as its official curr...
# 3  u.s. fast-food restaurant chain chick-fil-a wa...
# 4  the palestine authority signs a treaty to join...
# 5         the eurasian economic union between russia
# 6        vietnam’s new marriage law goes into effect
# 7                                        mario cuomo
# 8  somali al-shabaab militants attack an army bas...
# 9          boko haram militants attack a bus in waza
#
#                                           named_ents
# 0                                                 []
# 1  [(one, 17, 20, CARDINAL), (six, 33, 36, CARDIN...
# 2                                                 []
# 3                          [(9, 112, 113, CARDINAL)]
# 4                                                 []
# 5                                                 []
# 6                                                 []
# 7                                                 []
# 8                                                 []
# 9                                                 []

# %%
column = 'named_ents'
render_entities(9, df, options=options, column=column) # take a look at one of the abstracts
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">boko haram militants attack a bus in waza</div>

# %%
def extract_nouns(text):
    """Extract a few types of nouns, and beginning, middle and end idx using spaCy's POS (part of speech) tagger. 
    
    Keyword arguments:
    text -- the actual text source from which to extract entities
    
    """
    keep_pos = ['PROPN', 'NOUN']
    return [(tok.text, tok.idx, tok.idx+len(tok.text), tok.pos_) for tok in nlp(text) if tok.pos_ in keep_pos]

def add_nouns(df):
    """Create new column in data frame with nouns extracted.
    
    Keyword arguments:
    df -- a dataframe object
    
    """
    df['nouns'] = df['event_summary'].apply(extract_nouns)

# %%
add_nouns(df)
display(df)
# Out:
#                                        event_summary  \
# 0       the death toll of the suicide bombing in ibb
# 1  a shooting kills one and injures six people in...
# 2  lithuania adopts the euro as its official curr...
# 3  u.s. fast-food restaurant chain chick-fil-a wa...
# 4  the palestine authority signs a treaty to join...
# 5         the eurasian economic union between russia
# 6        vietnam’s new marriage law goes into effect
# 7                                        mario cuomo
# 8  somali al-shabaab militants attack an army bas...
# 9          boko haram militants attack a bus in waza
#
#                                           named_ents  \
# 0                                                 []
# 1  [(one, 17, 20, CARDINAL), (six, 33, 36, CARDIN...
# 2                                                 []
# 3                          [(9, 112, 113, CARDINAL)]
# 4                                                 []
# 5                                                 []
# 6                                                 []
# 7                                                 []
# 8                                                 []
# 9                                                 []
#
#                                                nouns
# 0  [(death, 4, 9, NOUN), (toll, 10, 14, NOUN), (s...
# 1  [(shooting, 2, 10, NOUN), (people, 37, 43, NOU...
# 2  [(lithuania, 0, 9, PROPN), (euro, 21, 25, NOUN...
# 3  [(food, 10, 14, NOUN), (restaurant, 15, 25, NO...
# 4  [(palestine, 4, 13, NOUN), (authority, 14, 23,...
# 5    [(union, 22, 27, NOUN), (russia, 36, 42, NOUN)]
# 6  [(vietnam, 0, 7, PROPN), (’s, 7, 9, PROPN), (m...
# 7        [(mario, 0, 5, NOUN), (cuomo, 6, 11, NOUN)]
# 8  [(al, 7, 9, PROPN), (militants, 18, 27, NOUN),...
# 9  [(haram, 5, 10, NOUN), (militants, 11, 20, NOU...

# %%
column = 'nouns'
render_entities(0, df, options=options, column=column)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">the
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     death
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     toll
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  of the
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     suicide
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     bombing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  in
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     ibb
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
# </div>

# %%
def extract_named_nouns(row_series):
    """Combine nouns and non-numerical entities. 
    
    Keyword arguments:
    row_series -- a Pandas Series object
    
    """
    ents = set()
    idxs = set()
    # remove duplicates and merge two lists together
    for noun_tuple in row_series['nouns']:
        for named_ents_tuple in row_series['named_ents']:
            if noun_tuple[1] == named_ents_tuple[1]: 
                idxs.add(noun_tuple[1])
                ents.add(named_ents_tuple)
        if noun_tuple[1] not in idxs:
            ents.add(noun_tuple)
    
    return sorted(list(ents), key=lambda x: x[1])

def add_named_nouns(df):
    """Create new column in data frame with nouns and named ents.
    
    Keyword arguments:
    df -- a dataframe object
    
    """
    df['named_nouns'] = df.apply(extract_named_nouns, axis=1)

# %%
add_named_nouns(df)
display(df)
# Out:
#                                        event_summary  \
# 0       the death toll of the suicide bombing in ibb
# 1  a shooting kills one and injures six people in...
# 2  lithuania adopts the euro as its official curr...
# 3  u.s. fast-food restaurant chain chick-fil-a wa...
# 4  the palestine authority signs a treaty to join...
# 5         the eurasian economic union between russia
# 6        vietnam’s new marriage law goes into effect
# 7                                        mario cuomo
# 8  somali al-shabaab militants attack an army bas...
# 9          boko haram militants attack a bus in waza
#
#                                           named_ents  \
# 0                                                 []
# 1  [(one, 17, 20, CARDINAL), (six, 33, 36, CARDIN...
# 2                                                 []
# 3                          [(9, 112, 113, CARDINAL)]
# 4                                                 []
# 5                                                 []
# 6                                                 []
# 7                                                 []
# 8                                                 []
# 9                                                 []
#
#                                                nouns  \
# 0  [(death, 4, 9, NOUN), (toll, 10, 14, NOUN), (s...
# 1  [(shooting, 2, 10, NOUN), (people, 37, 43, NOU...
# 2  [(lithuania, 0, 9, PROPN), (euro, 21, 25, NOUN...
# 3  [(food, 10, 14, NOUN), (restaurant, 15, 25, NO...
# 4  [(palestine, 4, 13, NOUN), (authority, 14, 23,...
# 5    [(union, 22, 27, NOUN), (russia, 36, 42, NOUN)]
# 6  [(vietnam, 0, 7, PROPN), (’s, 7, 9, PROPN), (m...
# 7        [(mario, 0, 5, NOUN), (cuomo, 6, 11, NOUN)]
# 8  [(al, 7, 9, PROPN), (militants, 18, 27, NOUN),...
# 9  [(haram, 5, 10, NOUN), (militants, 11, 20, NOU...
#
#                                          named_nouns
# 0  [(death, 4, 9, NOUN), (toll, 10, 14, NOUN), (s...
# 1  [(shooting, 2, 10, NOUN), (people, 37, 43, NOU...
# 2  [(lithuania, 0, 9, PROPN), (euro, 21, 25, NOUN...
# 3  [(food, 10, 14, NOUN), (restaurant, 15, 25, NO...
# 4  [(palestine, 4, 13, NOUN), (authority, 14, 23,...
# 5    [(union, 22, 27, NOUN), (russia, 36, 42, NOUN)]
# 6  [(vietnam, 0, 7, PROPN), (’s, 7, 9, PROPN), (m...
# 7        [(mario, 0, 5, NOUN), (cuomo, 6, 11, NOUN)]
# 8  [(al, 7, 9, PROPN), (militants, 18, 27, NOUN),...
# 9  [(haram, 5, 10, NOUN), (militants, 11, 20, NOU...

# %%
column = 'named_nouns'
render_entities(1, df, options=options, column=column)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">a
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     shooting
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  kills one and injures six
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     people
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  in
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     killarney
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
# </div>

# %%
text = "Dr. Abraham is the primary author of this paper, and a physician in the specialty of internal medicine."

spacy.displacy.render(nlp(text), jupyter=True) # generating raw-markup using spacy's built-in renderer
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="b711215bff5b41f683b741ba2adaf248-0" class="displacy" width="3200" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Dr.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Abraham</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="400">is</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="400">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="575">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="575">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="750">primary</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="750">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="925">author</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="925">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1100">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1275">this</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1275">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1450">paper,</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1450">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1625">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1625">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1800">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1800">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="1975">physician</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1975">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2150">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2325">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2325">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2500">specialty</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2675">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2675">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="2850">internal</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2850">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="3025">medicine.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3025">NOUN</tspan>
# </text>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b711215bff5b41f683b741ba2adaf248-0-0" stroke-width="2px" d="M70,439.5 C70,352.0 205.0,352.0 205.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b711215bff5b41f683b741ba2adaf248-0-0" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">compound</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M70,441.5 L62,429.5 78,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b711215bff5b41f683b741ba2adaf248-0-1" stroke-width="2px" d="M245,439.5 C245,352.0 380.0,352.0 380.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b711215bff5b41f683b741ba2adaf248-0-1" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">nsubj</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M245,441.5 L237,429.5 253,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b711215bff5b41f683b741ba2adaf248-0-2" stroke-width="2px" d="M595,439.5 C595,264.5 910.0,264.5 910.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b711215bff5b41f683b741ba2adaf248-0-2" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">det</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M595,441.5 L587,429.5 603,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b711215bff5b41f683b741ba2adaf248-0-3" stroke-width="2px" d="M770,439.5 C770,352.0 905.0,352.0 905.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b711215bff5b41f683b741ba2adaf248-0-3" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">amod</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M770,441.5 L762,429.5 778,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b711215bff5b41f683b741ba2adaf248-0-4" stroke-width="2px" d="M420,439.5 C420,177.0 915.0,177.0 915.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b711215bff5b41f683b741ba2adaf248-0-4" class="displacy-label" startOffset="50%" side="left" fill="currentColor" text-anchor="middle">attr</textPath>
#     </text>
#     <path class="displacy-arrowhead" d="M915.0,441.5 L923.0,429.5 907.0,429.5" fill="currentColor"/>
# </g>
#
# <g class="displacy-arrow">
#     <path class="displacy-arc" id="arrow-b711215bff5b41f683b741ba2adaf248-0-5" stroke-width="2px" d="M945,439.5 C945,352.0 1080.0,352.0 1080.0,439.5" fill="none" stroke="currentColor"/>
#     <text dy="1.25em" style="font-size: 0.8em; letter-spacing: 1px">
#         <textPath xlink:href="#arrow-b711215bff5b41f

# %%
def extract_noun_phrases(text):
    """Combine noun phrases. 
    
    Keyword arguments:
    text -- the actual text source from which to extract entities
    
    """
    return [(chunk.text, chunk.start_char, chunk.end_char, chunk.label_) for chunk in nlp(text).noun_chunks]

def add_noun_phrases(df):
    """Create new column in data frame with noun phrases.
    
    Keyword arguments:
    df -- a dataframe object
    
    """
    df['noun_phrases'] = df['event_summary'].apply(extract_noun_phrases)

# %%
def visualize_noun_phrases(text):
    """Create a temporary dataframe to extract and visualize noun phrases. 
    
    Keyword arguments:
    text -- the actual text source from which to extract entities
    
    """
    df = pd.DataFrame([text]) 
    df.columns = ['event_summary']
    add_noun_phrases(df)
    column = 'noun_phrases'
    render_entities(0, df, options=options, column=column)

# %%
visualize_noun_phrases(text)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     Dr. Abraham
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  is
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the primary author
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  of
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     this paper
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
# , and
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     a physician
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  in
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the specialty
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  of
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     internal medicine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
# .</div>

# %%
add_noun_phrases(df)
display(df)
# Out:
#                                        event_summary  \
# 0       the death toll of the suicide bombing in ibb
# 1  a shooting kills one and injures six people in...
# 2  lithuania adopts the euro as its official curr...
# 3  u.s. fast-food restaurant chain chick-fil-a wa...
# 4  the palestine authority signs a treaty to join...
# 5         the eurasian economic union between russia
# 6        vietnam’s new marriage law goes into effect
# 7                                        mario cuomo
# 8  somali al-shabaab militants attack an army bas...
# 9          boko haram militants attack a bus in waza
#
#                                           named_ents  \
# 0                                                 []
# 1  [(one, 17, 20, CARDINAL), (six, 33, 36, CARDIN...
# 2                                                 []
# 3                          [(9, 112, 113, CARDINAL)]
# 4                                                 []
# 5                                                 []
# 6                                                 []
# 7                                                 []
# 8                                                 []
# 9                                                 []
#
#                                                nouns  \
# 0  [(death, 4, 9, NOUN), (toll, 10, 14, NOUN), (s...
# 1  [(shooting, 2, 10, NOUN), (people, 37, 43, NOU...
# 2  [(lithuania, 0, 9, PROPN), (euro, 21, 25, NOUN...
# 3  [(food, 10, 14, NOUN), (restaurant, 15, 25, NO...
# 4  [(palestine, 4, 13, NOUN), (authority, 14, 23,...
# 5    [(union, 22, 27, NOUN), (russia, 36, 42, NOUN)]
# 6  [(vietnam, 0, 7, PROPN), (’s, 7, 9, PROPN), (m...
# 7        [(mario, 0, 5, NOUN), (cuomo, 6, 11, NOUN)]
# 8  [(al, 7, 9, PROPN), (militants, 18, 27, NOUN),...
# 9  [(haram, 5, 10, NOUN), (militants, 11, 20, NOU...
#
#                                          named_nouns  \
# 0  [(death, 4, 9, NOUN), (toll, 10, 14, NOUN), (s...
# 1  [(shooting, 2, 10, NOUN), (people, 37, 43, NOU...
# 2  [(lithuania, 0, 9, PROPN), (euro, 21, 25, NOUN...
# 3  [(food, 10, 14, NOUN), (restaurant, 15, 25, NO...
# 4  [(palestine, 4, 13, NOUN), (authority, 14, 23,...
# 5    [(union, 22, 27, NOUN), (russia, 36, 42, NOUN)]
# 6  [(vietnam, 0, 7, PROPN), (’s, 7, 9, PROPN), (m...
# 7        [(mario, 0, 5, NOUN), (cuomo, 6, 11, NOUN)]
# 8  [(al, 7, 9, PROPN), (militants, 18, 27, NOUN),...
# 9  [(haram, 5, 10, NOUN), (militants, 11, 20, NOU...
#
#                                         noun_phrases
# 0  [(the death toll, 0, 14, NP), (the suicide bom...
# 1  [(six people, 33, 43, NP), (killarney, 47, 56,...
# 2  [(lithuania, 0, 9, NP), (the euro, 17, 25, NP)...
# 3  [(fast-food restaurant chain, 5, 31, NP), (a s...
# 4  [(the palestine authority, 0, 23, NP), (a trea...
# 5  [(the eurasian economic union, 0, 27, NP), (ru...
# 6  [(vietnam, 0, 7, NP), (new marriage law, 10, 2...
# 7                         [(mario cuomo, 0, 11, NP)]
# 8  [(somali al-shabaab militants, 0, 27, NP), (an...
# 9  [(boko haram militants, 0, 20, NP), (a bus, 28...

# %%
column = 'noun_phrases'
render_entities(0, df, options=options, column=column)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the death toll
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  of
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     the suicide bombing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
#  in
# <mark class="entity" style="background: #1EECA6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     ibb
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NP</span>
# </mark>
# </div>

# %%
def extract_compounds(text):
    """Extract compound noun phrases with beginning and end idxs. 
    
    Keyword arguments:
    text -- the actual text source from which to extract entities
    
    """
    comp_idx = 0
    compound = []
    compound_nps = []
    tok_idx = 0
    for idx, tok in enumerate(nlp(text)):
        if tok.dep_ == 'compound':

            # capture hyphenated compounds
            children = ''.join([c.text for c in tok.children])
            if '-' in children:
                compound.append(''.join([children, tok.text]))
            else:
                compound.append(tok.text)

            # remember starting index of first child in compound or word
            try:
                tok_idx = [c for c in tok.children][0].idx
            except IndexError:
                if len(compound) == 1:
                    tok_idx = tok.idx
            comp_idx = tok.i

        # append the last word in a compound phrase
        if tok.i - comp_idx == 1:
            compound.append(tok.text)
            if len(compound) > 1: 
                compound = ' '.join(compound)
                compound_nps.append((compound, tok_idx, tok_idx+len(compound), 'COMPOUND'))

            # reset parameters
            tok_idx = 0 
            compound = []

    return compound_nps

def add_compounds(df):
    """Create new column in data frame with compound noun phrases.
    
    Keyword arguments:
    df -- a dataframe object
    
    """
    df['compounds'] = df['event_summary'].apply(extract_compounds)

# %%
add_compounds(df)
display(df)
# Out:
#                                        event_summary  \
# 0       the death toll of the suicide bombing in ibb
# 1  a shooting kills one and injures six people in...
# 2  lithuania adopts the euro as its official curr...
# 3  u.s. fast-food restaurant chain chick-fil-a wa...
# 4  the palestine authority signs a treaty to join...
# 5         the eurasian economic union between russia
# 6        vietnam’s new marriage law goes into effect
# 7                                        mario cuomo
# 8  somali al-shabaab militants attack an army bas...
# 9          boko haram militants attack a bus in waza
#
#                                           named_ents  \
# 0                                                 []
# 1  [(one, 17, 20, CARDINAL), (six, 33, 36, CARDIN...
# 2                                                 []
# 3                          [(9, 112, 113, CARDINAL)]
# 4                                                 []
# 5                                                 []
# 6                                                 []
# 7                                                 []
# 8                                                 []
# 9                                                 []
#
#                                                nouns  \
# 0  [(death, 4, 9, NOUN), (toll, 10, 14, NOUN), (s...
# 1  [(shooting, 2, 10, NOUN), (people, 37, 43, NOU...
# 2  [(lithuania, 0, 9, PROPN), (euro, 21, 25, NOUN...
# 3  [(food, 10, 14, NOUN), (restaurant, 15, 25, NO...
# 4  [(palestine, 4, 13, NOUN), (authority, 14, 23,...
# 5    [(union, 22, 27, NOUN), (russia, 36, 42, NOUN)]
# 6  [(vietnam, 0, 7, PROPN), (’s, 7, 9, PROPN), (m...
# 7        [(mario, 0, 5, NOUN), (cuomo, 6, 11, NOUN)]
# 8  [(al, 7, 9, PROPN), (militants, 18, 27, NOUN),...
# 9  [(haram, 5, 10, NOUN), (militants, 11, 20, NOU...
#
#                                          named_nouns  \
# 0  [(death, 4, 9, NOUN), (toll, 10, 14, NOUN), (s...
# 1  [(shooting, 2, 10, NOUN), (people, 37, 43, NOU...
# 2  [(lithuania, 0, 9, PROPN), (euro, 21, 25, NOUN...
# 3  [(food, 10, 14, NOUN), (restaurant, 15, 25, NO...
# 4  [(palestine, 4, 13, NOUN), (authority, 14, 23,...
# 5    [(union, 22, 27, NOUN), (russia, 36, 42, NOUN)]
# 6  [(vietnam, 0, 7, PROPN), (’s, 7, 9, PROPN), (m...
# 7        [(mario, 0, 5, NOUN), (cuomo, 6, 11, NOUN)]
# 8  [(al, 7, 9, PROPN), (militants, 18, 27, NOUN),...
# 9  [(haram, 5, 10, NOUN), (militants, 11, 20, NOU...
#
#                                         noun_phrases  \
# 0  [(the death toll, 0, 14, NP), (the suicide bom...
# 1  [(six people, 33, 43, NP), (killarney, 47, 56,...
# 2  [(lithuania, 0, 9, NP), (the euro, 17, 25, NP)...
# 3  [(fast-food restaurant chain, 5, 31, NP), (a s...
# 4  [(the palestine authority, 0, 23, NP), (a trea...
# 5  [(the eurasian economic union, 0, 27, NP), (ru...
# 6  [(vietnam, 0, 7, NP), (new marriage law, 10, 2...
# 7                         [(mario cuomo, 0, 11, NP)]
# 8  [(somali al-shabaab militants, 0, 27, NP), (an...
# 9  [(boko haram militants, 0, 20, NP), (a bus, 28...
#
#                                            compounds
# 0  [(death toll, 4, 14, COMPOUND), (suicide bombi...
# 1                [(shooting kills, 2, 16, COMPOUND)]
# 2                                                 []
# 3  [(restaurant chain, 15, 31, COMPOUND), (-chick...
# 4  [(palestine authority, 4, 23, COMPOUND), (wall...
# 5                                                 []
# 6                 [(marriage law, 14, 26, COMPOUND)]
# 7                   [(mario cuomo, 0, 11, COMPOUND)]
# 8  [(al -, 7, 11, COMPOUND), (al-shabaab militant...
# 9          [(boko haram militants, 0, 20, COMPOUND)]

# %%
column = 'compounds'
render_entities(0, df, options=options, column=column)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">the
# <mark class="entity" style="background: #FE6BFE; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     death toll
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">COMPOUND</span>
# </mark>
#  of the
# <mark class="entity" style="background: #FE6BFE; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     suicide bombing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">COMPOUND</span>
# </mark>
#  in ibb</div>

# %%
def extract_comp_nouns(row_series, cols=[]):
    """Combine compound noun phrases and entities. 
    
    Keyword arguments:
    row_series -- a Pandas Series object
    
    """
    return {noun_tuple[0] for col in cols for noun_tuple in row_series[col]}

def add_comp_nouns(df, cols=[]):
    """Create new column in data frame with merged entities.
    
    Keyword arguments:
    df -- a dataframe object
    cols -- a list of column names that need to be merged
    
    """
    df['comp_nouns'] = df.apply(extract_comp_nouns, axis=1, cols=cols)

# %%
cols = ['nouns', 'compounds']
add_comp_nouns(df, cols=cols)
display(df)
# Out:
#                                        event_summary  \
# 0       the death toll of the suicide bombing in ibb
# 1  a shooting kills one and injures six people in...
# 2  lithuania adopts the euro as its official curr...
# 3  u.s. fast-food restaurant chain chick-fil-a wa...
# 4  the palestine authority signs a treaty to join...
# 5         the eurasian economic union between russia
# 6        vietnam’s new marriage law goes into effect
# 7                                        mario cuomo
# 8  somali al-shabaab militants attack an army bas...
# 9          boko haram militants attack a bus in waza
#
#                                           named_ents  \
# 0                                                 []
# 1  [(one, 17, 20, CARDINAL), (six, 33, 36, CARDIN...
# 2                                                 []
# 3                          [(9, 112, 113, CARDINAL)]
# 4                                                 []
# 5                                                 []
# 6                                                 []
# 7                                                 []
# 8                                                 []
# 9                                                 []
#
#                                                nouns  \
# 0  [(death, 4, 9, NOUN), (toll, 10, 14, NOUN), (s...
# 1  [(shooting, 2, 10, NOUN), (people, 37, 43, NOU...
# 2  [(lithuania, 0, 9, PROPN), (euro, 21, 25, NOUN...
# 3  [(food, 10, 14, NOUN), (restaurant, 15, 25, NO...
# 4  [(palestine, 4, 13, NOUN), (authority, 14, 23,...
# 5    [(union, 22, 27, NOUN), (russia, 36, 42, NOUN)]
# 6  [(vietnam, 0, 7, PROPN), (’s, 7, 9, PROPN), (m...
# 7        [(mario, 0, 5, NOUN), (cuomo, 6, 11, NOUN)]
# 8  [(al, 7, 9, PROPN), (militants, 18, 27, NOUN),...
# 9  [(haram, 5, 10, NOUN), (militants, 11, 20, NOU...
#
#                                          named_nouns  \
# 0  [(death, 4, 9, NOUN), (toll, 10, 14, NOUN), (s...
# 1  [(shooting, 2, 10, NOUN), (people, 37, 43, NOU...
# 2  [(lithuania, 0, 9, PROPN), (euro, 21, 25, NOUN...
# 3  [(food, 10, 14, NOUN), (restaurant, 15, 25, NO...
# 4  [(palestine, 4, 13, NOUN), (authority, 14, 23,...
# 5    [(union, 22, 27, NOUN), (russia, 36, 42, NOUN)]
# 6  [(vietnam, 0, 7, PROPN), (’s, 7, 9, PROPN), (m...
# 7        [(mario, 0, 5, NOUN), (cuomo, 6, 11, NOUN)]
# 8  [(al, 7, 9, PROPN), (militants, 18, 27, NOUN),...
# 9  [(haram, 5, 10, NOUN), (militants, 11, 20, NOU...
#
#                                         noun_phrases  \
# 0  [(the death toll, 0, 14, NP), (the suicide bom...
# 1  [(six people, 33, 43, NP), (killarney, 47, 56,...
# 2  [(lithuania, 0, 9, NP), (the euro, 17, 25, NP)...
# 3  [(fast-food restaurant chain, 5, 31, NP), (a s...
# 4  [(the palestine authority, 0, 23, NP), (a trea...
# 5  [(the eurasian economic union, 0, 27, NP), (ru...
# 6  [(vietnam, 0, 7, NP), (new marriage law, 10, 2...
# 7                         [(mario cuomo, 0, 11, NP)]
# 8  [(somali al-shabaab militants, 0, 27, NP), (an...
# 9  [(boko haram militants, 0, 20, NP), (a bus, 28...
#
#                                            compounds  \
# 0  [(death toll, 4, 14, COMPOUND), (suicide bombi...
# 1                [(shooting kills, 2, 16, COMPOUND)]
# 2                                                 []
# 3  [(restaurant chain, 15, 31, COMPOUND), (-chick...
# 4  [(palestine authority, 4, 23, COMPOUND), (wall...
# 5                                                 []
# 6                 [(marriage law, 14, 26, COMPOUND)]
# 7                   [(mario cuomo, 0, 11, COMPOUND)]
# 8  [(al -, 7, 11, COMPOUND), (al-shabaab militant...
# 9          [(boko haram militants, 0, 20, COMPOUND)]
#
#                                           comp_nouns
# 0  {suicide, death toll, ibb, death, toll, suicid...
# 1      {people, shooting kills, killarney, shooting}
# 2                        {lithuania, currency, euro}
# 3  {credit, credit card details, breach, restaura...
# 4  {palestine, wall, authority, palestine authori...
# 5                                    {union, russia}
# 6  {vietnam, marriage, law, effect, ’s, marriage ...
# 7                        {mario cuomo, cuomo, mario}
# 8  {al, outskirts, army, al -, al-shabaab militan...
# 9  {bus, boko haram militants, waza, haram, milit...

# %%
# take a look at all the nouns again
column = 'named_nouns'
render_entities(0, df, options=options, column=column)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">the
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     death
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     toll
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  of the
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     suicide
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     bombing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
#  in
# <mark class="entity" style="background: #18CFE6; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     ibb
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">NOUN</span>
# </mark>
# </div>

# %%
# take a look at all the compound noun phrases again
column = 'compounds'
render_entities(0, df, options=options, column=column)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">the
# <mark class="entity" style="background: #FE6BFE; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     death toll
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">COMPOUND</span>
# </mark>
#  of the
# <mark class="entity" style="background: #FE6BFE; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     suicide bombing
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">COMPOUND</span>
# </mark>
#  in ibb</div>

# %%
# take a look at combined entities
df['comp_nouns'][0]
# Out:
# {'bombing', 'death', 'death toll', 'ibb', 'suicide', 'suicide bombing', 'toll'}

# %%
df.head()
# Out:
#                                        event_summary  \
# 0       the death toll of the suicide bombing in ibb
# 1  a shooting kills one and injures six people in...
# 2  lithuania adopts the euro as its official curr...
# 3  u.s. fast-food restaurant chain chick-fil-a wa...
# 4  the palestine authority signs a treaty to join...
#
#                                           named_ents  \
# 0                                                 []
# 1  [(one, 17, 20, CARDINAL), (six, 33, 36, CARDIN...
# 2                                                 []
# 3                          [(9, 112, 113, CARDINAL)]
# 4                                                 []
#
#                                                nouns  \
# 0  [(death, 4, 9, NOUN), (toll, 10, 14, NOUN), (s...
# 1  [(shooting, 2, 10, NOUN), (people, 37, 43, NOU...
# 2  [(lithuania, 0, 9, PROPN), (euro, 21, 25, NOUN...
# 3  [(food, 10, 14, NOUN), (restaurant, 15, 25, NO...
# 4  [(palestine, 4, 13, NOUN), (authority, 14, 23,...
#
#                                          named_nouns  \
# 0  [(death, 4, 9, NOUN), (toll, 10, 14, NOUN), (s...
# 1  [(shooting, 2, 10, NOUN), (people, 37, 43, NOU...
# 2  [(lithuania, 0, 9, PROPN), (euro, 21, 25, NOUN...
# 3  [(food, 10, 14, NOUN), (restaurant, 15, 25, NO...
# 4  [(palestine, 4, 13, NOUN), (authority, 14, 23,...
#
#                                         noun_phrases  \
# 0  [(the death toll, 0, 14, NP), (the suicide bom...
# 1  [(six people, 33, 43, NP), (killarney, 47, 56,...
# 2  [(lithuania, 0, 9, NP), (the euro, 17, 25, NP)...
# 3  [(fast-food restaurant chain, 5, 31, NP), (a s...
# 4  [(the palestine authority, 0, 23, NP), (a trea...
#
#                                            compounds  \
# 0  [(death toll, 4, 14, COMPOUND), (suicide bombi...
# 1                [(shooting kills, 2, 16, COMPOUND)]
# 2                                                 []
# 3  [(restaurant chain, 15, 31, COMPOUND), (-chick...
# 4  [(palestine authority, 4, 23, COMPOUND), (wall...
#
#                                           comp_nouns
# 0  {suicide, death toll, ibb, death, toll, suicid...
# 1      {people, shooting kills, killarney, shooting}
# 2                        {lithuania, currency, euro}
# 3  {credit, credit card details, breach, restaura...
# 4  {palestine, wall, authority, palestine authori...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
# event_summary    10 non-null object
# named_ents       10 non-null object
# nouns            10 non-null object
# named_nouns      10 non-null object
# noun_phrases     10 non-null object
# compounds        10 non-null object
# comp_nouns       10 non-null object
# dtypes: object(7)
# memory usage: 640.0+ bytes

# %%
df.comp_nouns.value_counts()
# Out:
# {union, russia}                                                                                                                                1
# {bus, boko haram militants, waza, haram, militants}                                                                                            1
# {people, shooting kills, killarney, shooting}                                                                                                  1
# {suicide, death toll, ibb, death, toll, suicide bombing, bombing}                                                                              1
# {vietnam, marriage, law, effect, ’s, marriage law}                                                                                             1
# {al, outskirts, army, al -, al-shabaab militants, army base, baidoa, base, militants}                                                          1
# {palestine, wall, authority, palestine authority, treaty, court, wall street journal, journal, street}                                         1
# {credit, credit card details, breach, restaurant, food, details, chick, chain, card, restaurant chain, security breach, security, -chick -}    1
# {lithuania, currency, euro}                                                                                                                    1
# {mario cuomo, cuomo, mario}                                                                                                                    1
# Name: comp_nouns, dtype: int64

# %%
df.compounds.value_counts()
# Out:
# []                                                                                                                                                     2
# [(marriage law, 14, 26, COMPOUND)]                                                                                                                     1
# [(shooting kills, 2, 16, COMPOUND)]                                                                                                                    1
# [(death toll, 4, 14, COMPOUND), (suicide bombing, 22, 37, COMPOUND)]                                                                                   1
# [(mario cuomo, 0, 11, COMPOUND)]                                                                                                                       1
# [(boko haram militants, 0, 20, COMPOUND)]                                                                                                              1
# [(palestine authority, 4, 23, COMPOUND), (wall street journal, 101, 120, COMPOUND)]                                                                    1
# [(restaurant chain, 15, 31, COMPOUND), (-chick -, 37, 45, COMPOUND), (security breach, 57, 72, COMPOUND), (credit card details, 89, 108, COMPOUND)]    1
# [(al -, 7, 11, COMPOUND), (al-shabaab militants, 7, 27, COMPOUND), (army base, 38, 47, COMPOUND)]                                                      1
# Name: compounds, dtype: int64

# %%
from sklearn.feature_extraction.text import CountVectorizer
from nltk.tokenize import RegexpTokenizer
#tokenizer to remove unwanted elements from out data like symbols and numbers
token = RegexpTokenizer(r'[a-zA-Z0-9]+')
cv = CountVectorizer(lowercase=True,stop_words='english',ngram_range = (1,1),tokenizer = token.tokenize)
text_counts= cv.fit_transform(df['event_summary'])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(
    text_counts, df['compounds'], test_size=0.3, random_state=1)

# %%
# from __future__ import unicode_literals
# import spacy,en_core_web_sm
# import textacy
# nlp = en_core_web_sm.load()
# sentence = 'The author is writing a new book.'
# pattern = r'<VERB>?<ADV>*<VERB>+'
# doc = textacy.Doc(sentence, lang='en_core_web_sm')
# lists = textacy.extract.pos_regex_matches(doc, pattern)
# for list in lists:
#     print(list.text)

# %%
text=df['event_summary']
text1 = str(text)
doc = nlp(text1)

# %%
#df1=df.columns = ['event_summary']
for i, token in enumerate(doc):
    df.loc[i, 'text'] = token.text
    df.loc[i, 'pos'] = token.pos_
    df.loc[i, 'dep'] = token.dep_

# %%
df
# Out:
#                                          event_summary  \
# 0         the death toll of the suicide bombing in ibb
# 1    a shooting kills one and injures six people in...
# 2    lithuania adopts the euro as its official curr...
# 3    u.s. fast-food restaurant chain chick-fil-a wa...
# 4    the palestine authority signs a treaty to join...
# ..                                                 ...
# 117                                                NaN
# 118                                                NaN
# 119                                                NaN
# 120                                                NaN
# 121                                                NaN
#
#                                             named_ents  \
# 0                                                   []
# 1    [(one, 17, 20, CARDINAL), (six, 33, 36, CARDIN...
# 2                                                   []
# 3                            [(9, 112, 113, CARDINAL)]
# 4                                                   []
# ..                                                 ...
# 117                                                NaN
# 118                                                NaN
# 119                                                NaN
# 120                                                NaN
# 121                                                NaN
#
#                                                  nouns  \
# 0    [(death, 4, 9, NOUN), (toll, 10, 14, NOUN), (s...
# 1    [(shooting, 2, 10, NOUN), (people, 37, 43, NOU...
# 2    [(lithuania, 0, 9, PROPN), (euro, 21, 25, NOUN...
# 3    [(food, 10, 14, NOUN), (restaurant, 15, 25, NO...
# 4    [(palestine, 4, 13, NOUN), (authority, 14, 23,...
# ..                                                 ...
# 117                                                NaN
# 118                                                NaN
# 119                                                NaN
# 120                                                NaN
# 121                                                NaN
#
#                                            named_nouns  \
# 0    [(death, 4, 9, NOUN), (toll, 10, 14, NOUN), (s...
# 1    [(shooting, 2, 10, NOUN), (people, 37, 43, NOU...
# 2    [(lithuania, 0, 9, PROPN), (euro, 21, 25, NOUN...
# 3    [(food, 10, 14, NOUN), (restaurant, 15, 25, NO...
# 4    [(palestine, 4, 13, NOUN), (authority, 14, 23,...
# ..                                                 ...
# 117                                                NaN
# 118                                                NaN
# 119                                                NaN
# 120                                                NaN
# 121                                                NaN
#
#                                           noun_phrases  \
# 0    [(the death toll, 0, 14, NP), (the suicide bom...
# 1    [(six people, 33, 43, NP), (killarney, 47, 56,...
# 2    [(lithuania, 0, 9, NP), (the euro, 17, 25, NP)...
# 3    [(fast-food restaurant chain, 5, 31, NP), (a s...
# 4    [(the palestine authority, 0, 23, NP), (a trea...
# ..                                                 ...
# 117                                                NaN
# 118                                                NaN
# 119                                                NaN
# 120                                                NaN
# 121                                                NaN
#
#                                              compounds  \
# 0    [(death toll, 4, 14, COMPOUND), (suicide bombi...
# 1                  [(shooting kills, 2, 16, COMPOUND)]
# 2                                                   []
# 3    [(restaurant chain, 15, 31, COMPOUND), (-chick...
# 4    [(palestine authority, 4, 23, COMPOUND), (wall...
# ..                                                 ...
# 117                                                NaN
# 118                                                NaN
# 119                                                NaN
# 120                                                NaN
# 121                                                NaN
#
#                                             comp_nouns           text    pos  \
# 0    {suicide, death toll, ibb, death, toll, suicid...              0  PUNCT
# 1        {people, shooting kills, killarney, shooting}                 SPACE
# 2                          {lithuania, currency, euro}            the    DET
# 3    {credit, credit card details, breach, restaura...          death   NOUN
# 4    {palestine, wall, authority, palestine authori...           toll   NOUN
# ..                                                 ...            ...    ...
# 117                                                NaN  event_summary    ADJ
# 118                                                NaN              ,  PUNCT
# 119                                                NaN          dtype   NOUN
# 120                                                NaN              :  PUNCT
# 121                                                NaN         object   NOUN
#
#           dep
# 0      nummod
# 1
# 2         det
# 3    compound
# 4        ROOT
# ..        ...
# 117  npadvmod
# 118     punct
# 119      ROOT
# 120     punct
# 121      dobj
#
# [122 rows x 10 columns]

# %%
df1 = pd.DataFrame()
for i,token in enumerate(doc):
    df1.loc[i,'text'] = token.text

# %%
df1
# Out:
#               text
# 0                0
# 1
# 2              the
# 3            death
# 4             toll
# ..             ...
# 117  event_summary
# 118              ,
# 119          dtype
# 120              :
# 121         object
#
# [122 rows x 1 columns]

# %%
df3 = pd.DataFrame()
for i,token in enumerate(doc):
    df3.loc[i,'text'] = token.text
    df3.loc[i,'lemma_'] = token.lemma_
    df3.loc[i,'pos_'] = token.pos_
    df3.loc[i,'tag_'] = token.tag_
    df3.loc[i,'dep_'] = token.dep_
    df3.loc[i,'shape_'] = token.shape_
    df3.loc[i,'is_alpha'] = token.is_alpha
    df3.loc[i,'is_stop'] = token.is_stop

# %%
df3
# Out:
#               text         lemma_   pos_ tag_      dep_     shape_ is_alpha  \
# 0                0              0  PUNCT  NFP    nummod          d    False
# 1                                  SPACE  _SP                         False
# 2              the            the    DET   DT       det        xxx     True
# 3            death          death   NOUN   NN  compound       xxxx     True
# 4             toll           toll   NOUN   NN      ROOT       xxxx     True
# ..             ...            ...    ...  ...       ...        ...      ...
# 117  event_summary  event_summary    ADJ   JJ  npadvmod  xxxx_xxxx    False
# 118              ,              ,  PUNCT    ,     punct          ,    False
# 119          dtype          dtype   NOUN   NN      ROOT       xxxx     True
# 120              :              :  PUNCT    :     punct          :    False
# 121         object         object   NOUN   NN      dobj       xxxx     True
#
#     is_stop
# 0     False
# 1     False
# 2      True
# 3     False
# 4     False
# ..      ...
# 117   False
# 118   False
# 119   False
# 120   False
# 121   False
#
# [122 rows x 8 columns]

# %%
spacy.displacy.render(doc, style='ent',jupyter=True)
# Out:
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     0
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#          the death toll of the suicide bombing in ibb</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#     a shooting kills
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     one
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  and injures
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     six
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  people in...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#     lithuania adopts the euro as its official curr...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     3
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#     u.s. fast-food restaurant chain chick-fil-a wa...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     4
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#     the palestine authority signs a treaty to join...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     5
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#            the eurasian economic union between russia</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     6
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#           vietnam’s new marriage law goes into effect</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     7
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
# mario cuomo</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     8
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#     somali al-shabaab militants attack an army bas...</br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em; box-decoration-break: clone; -webkit-box-decoration-break: clone">
#     9
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; text-transform: uppercase; vertical-align: middle; margin-left: 0.5rem">QUANTITY</span>
# </mark>
# boko haram militants attack a bus in waza
# Name: event_summary, dtype: object</div>

# %%
spacy.displacy.render(doc, style='dep',jupyter=True,options = {'compact':60})
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="fe3b9877315b4d8c8cabbb4de48a3c21-0" class="displacy" width="16400" height="887.0" direction="ltr" style="max-width: none; height: 887.0px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">0</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PUNCT</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="200">        </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="200">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="350">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="350">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">death</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="650">toll</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="650">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="800">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="800">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="1100">suicide</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1100">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="1250">bombing</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1250">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="1550">ibb</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1550">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="1700">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1700">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">1</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="2000">   </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2000">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="2150">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2150">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">shooting</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="2450">kills</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2450">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="2600">one</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2600">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="2900">injures</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2900">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="3050">six</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3050">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="3200">people</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3200">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="3350">in...</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3350">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="3500">
# </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3500">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="3650">2</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3650">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="3800">   </tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3800">SPACE</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="3950">lithuania</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="3950">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="4100">adopts</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4100">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="4250">the</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4250">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="4400">euro</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4400">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="797.0">
#     <tspan class="displacy-word" fill="currentColor" x="4550">as</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="4550">ADP</tspan>
# </text>
#
# <text class="displacy-t

# %% [markdown]
# https://www.kaggle.com/ganeshn88/faster-nlp-with-spacy-in-python/code

# %%
# from __future__ import unicode_literals
# import spacy,en_core_web_sm
# import textacy
# from textacy import io

# nlp = en_core_web_sm.load()
# sentence = 'The author is writing a new book.'
# pattern = r'<VERB>?<ADV>*<VERB>+'
# doc = textacy.Doc.load(sentence, metadata=metadata, lang='en_core_web_sm')
# # doc = textacy.corpus.Corpus(sentence, lang='en_core_web_sm')
# lists = textacy.extract.pos_regex_matches(doc, pattern)
# for list in lists:
#     print(list.text)
